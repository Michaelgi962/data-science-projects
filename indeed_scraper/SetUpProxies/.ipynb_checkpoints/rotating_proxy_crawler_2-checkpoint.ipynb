# %% [markdown]
# # Ref: https://codelike.pro/create-a-crawler-with-rotating-ip-proxy-in-python/

# %% [markdown]
# # Import Libraries

# %%
# Get the text data from the first job posting
import pandas as pd
import requests # For website connections
from bs4 import BeautifulSoup # For HTML parsing
import time
from fake_useragent import UserAgent
import random

# %% [markdown]
# # Import the Data

# %%
try:
    Https_txt_file = 'proxyLists/https_proxys_US_part_2.txt'
    #Download New HTTPS IPs .txt file from https://www.proxy-list.download/HTTPS
    https_proxys = pd.read_csv(Https_txt_file, sep=" ", header=None)
    #Convert to array
    https_proxys = https_proxys[0].values
    #Convert to list
    https_proxys = list(https_proxys)
except:
    print('There are no https proxies to import')

try:
    Http_txt_file = 'proxyLists/http_proxys_US_part_2.txt'
    #Download New HTTPS IPs .txt file from https://www.proxy-list.download/HTTP
    http_proxys = pd.read_csv(Http_txt_file, sep=" ", header=None)
    #Convert to array
    http_proxys = http_proxys[0].values
    #Convert to list
    http_proxys = list(http_proxys)
except:
    print('There are no http proxies to import')

# %%
# Make a dictionary for the proxies to test
testProxies = {'https':https_proxys,'http':http_proxys}

# %%
# Retrieve a random user-agent
header = {}
def randHeader():
    ua = UserAgent()
    header['User-Agent'] = ua.random

# %%
# Retrieve a random index for the https proxy
def randomIndex(conn_type):
    num = random.randint(0, len(testProxies[conn_type]) - 1)
    return num

# %%
proxyDict = {}
def randProx(conn_type):
    # Choose a single random proxy to use
    proxy_index = randomIndex(conn_type)
    proxy = testProxies[conn_type][proxy_index]
    proxyDict[conn_type] = conn_type +'://'+ proxy
    return proxy_index

# %%
# Initialize Dictionary for good proxies 
good_http_proxy = []
good_https_proxy = []
conn_time_http = []
conn_time_https = []
goodProxy = {'https':{'proxy':good_https_proxy,'time':conn_time_https},
             'http':{'proxy':good_http_proxy,'time':conn_time_http}}

# %%
def filterProxys(url):
    timer = 0
    count = 0
    if url[0:5] == 'http:':
        conn_type = 'http'
        
    elif url[0:5] == 'https':
        conn_type = 'https'

    total_proxies = len(testProxies[conn_type])
    for n in range(len(testProxies[conn_type])):
        time.sleep(1)
        print(str(total_proxies-n)+' proxies left to filter')
            
        try:
            # Choose a random header
            randHeader()
            
        except:
            # Sometimes the header reassignment function returns an error
            pass
            
        # Choose a random proxy
        proxy_index = randProx(conn_type)

        try:
            # Try to connect to the url
            t1 = time.time()
            soup = requests.get(url,headers=header,proxies=proxyDict,timeout=5)
            t2 = time.time()
            t = t2-t1
                
            if  str(soup) == '<Response [200]>': # the connection is successful when <Response [200]> is returned
                print(str(testProxies[conn_type][proxy_index])+' is good')
                del testProxies[conn_type][proxy_index]
                timer += t
                count += 1
                print('average conn time: '+str(timer/count)+'\n')
                #Add to the good proxy and its connection time
                goodProxy[conn_type]['proxy'].append(proxyDict[conn_type])
                goodProxy[conn_type]['time'].append(t)
                    
            elif str(soup) != '<Response [200]>': #The connection was bad
                print(str(testProxies[conn_type][proxy_index])+' is bad'+'\n')
                del testProxies[conn_type][proxy_index]
                    
                    
        except: # The connection took too long 
            print(str(testProxies[conn_type][proxy_index])+' is slow'+'\n')
            del testProxies[conn_type][proxy_index]
    try:
        print('average proxy time:'+str(timer/count))
    except:
        print('No proxies to text')

# %% [markdown]
# # Filter the Https proxies

# %%
url = 'https://www.proxy-list.download/HTTPS'
filterProxys(url)
# Out:
# 2062 proxies left to filter
# 91.202.72.105:8080 is good
# average conn time: 2.60721087456
#
# 2061 proxies left to filter
# 35.242.218.63:3128 is good
# average conn time: 1.67341089249
#
# 2060 proxies left to filter
# 85.105.132.22:8080 is slow
#
# 2059 proxies left to filter
# 59.152.11.26:8080 is slow
#
# 2058 proxies left to filter
# 212.94.116.34:1920 is slow
#
# 2057 proxies left to filter
# 212.122.61.160:80 is slow
#
# 2056 proxies left to filter
# 203.135.22.82:8080 is good
# average conn time: 3.52954657873
#
# 2055 proxies left to filter
# 94.112.20.33:8080 is slow
#
# 2054 proxies left to filter
# 69.63.73.171:53281 is slow
#
# 2053 proxies left to filter
# 94.73.202.65:8081 is slow
#
# 2052 proxies left to filter
# 36.74.72.76:41437 is slow
#
# 2051 proxies left to filter
# 202.72.208.214:8080 is slow
#
# 2050 proxies left to filter
# 203.150.150.32:8080 is good
# average conn time: 4.740419209
#
# 2049 proxies left to filter
# 5.8.207.160:57192 is bad
#
# 2048 proxies left to filter
# 90.178.157.55:46051 is slow
#
# 2047 proxies left to filter
# 91.230.199.174:42277 is bad
#
# 2046 proxies left to filter
# 31.133.57.134:41258 is bad
#
# 2045 proxies left to filter
# 89.27.165.167:8080 is good
# average conn time: 4.61333093643
#
# 2044 proxies left to filter
# 202.166.202.29:58794 is bad
#
# 2043 proxies left to filter
# 85.112.77.11:80 is slow
#
# 2042 proxies left to filter
# 62.33.207.201:80 is slow
#
# 2041 proxies left to filter
# 36.66.127.99:8080 is slow
#
# 2040 proxies left to filter
# 202.166.205.78:58431 is good
# average conn time: 5.29092729092
#
# 2039 proxies left to filter
# 91.211.245.12:80 is slow
#
# 2038 proxies left to filter
# 202.63.242.20:56610 is slow
#
# 2037 proxies left to filter
# 212.28.237.131:47108 is bad
#
# 2036 proxies left to filter
# 91.144.139.93:3128 is good
# average conn time: 4.82266667911
#
# 2035 proxies left to filter
# 85.163.235.11:8081 is good
# average conn time: 4.90174919367
#
# 2034 proxies left to filter
# 221.7.255.168:8080 is slow
#
# 2033 proxies left to filter
# 96.9.90.83:30351 is good
# average conn time: 4.63273183505
#
# 2032 proxies left to filter
# 200.35.43.105:42353 is bad
#
# 2031 proxies left to filter
# 41.220.114.154:8080 is good
# average conn time: 4.46837143898
#
# 2030 proxies left to filter
# 212.129.2.166:54321 is slow
#
# 2029 proxies left to filter
# 82.147.120.8:30174 is slow
#
# 2028 proxies left to filter
# 78.186.140.120:38072 is bad
#
# 2027 proxies left to filter
# 206.189.144.195:8080 is slow
#
# 2026 proxies left to filter
# 81.163.40.63:8081 is slow
#
# 2025 proxies left to filter
# 68.183.200.61:8080 is good
# average conn time: 4.08253940669
#
# 2024 proxies left to filter
# 213.222.244.150:34425 is slow
#
# 2023 proxies left to filter
# 212.129.4.144:54321 is slow
#
# 2022 proxies left to filter
# 36.67.27.189:44255 is good
# average conn time: 4.31021287044
#
# 2021 proxies left to filter
# 45.228.254.166:8080 is good
# average conn time: 4.80362573037
#
# 2020 proxies left to filter
# 202.179.3.14:43151 is slow
#
# 2019 proxies left to filter
# 36.74.244.2:8080 is slow
#
# 2018 proxies left to filter
# 46.36.37.14:8080 is slow
#
# 2017 proxies left to filter
# 222.135.31.69:8060 is slow
#
# 2016 proxies left to filter
# 47.94.105.1:3128 is good
# average conn time: 5.12580968652
#
# 2015 proxies left to filter
# 223.19.141.26:8197 is slow
#
# 2014 proxies left to filter
# 202.91.68.186:60259 is bad
#
# 2013 proxies left to filter
# 83.246.139.24:8080 is slow
#
# 2012 proxies left to filter
# 213.6.64.18:8080 is good
# average conn time: 5.22608536084
#
# 2011 proxies left to filter
# 66.70.167.120:3128 is slow
#
# 2010 proxies left to filter
# 93.190.137.26:8080 is slow
#
# 2009 proxies left to filter
# 217.91.227.43:3128 is bad
#
# 2008 proxies left to filter
# 203.81.71.83:8080 is good
# average conn time: 5.19164739549
#
# 2007 proxies left to filter
# 91.235.247.252:8081 is slow
#
# 2006 proxies left to filter
# 79.111.119.213:49650 is bad
#
# 2005 proxies left to filter
# 31.173.211.114:43873 is bad
#
# 2004 proxies left to filter
# 41.211.123.203:8080 is slow
#
# 2003 proxies left to filter
# 207.148.71.188:3128 is slow
#
# 2002 proxies left to filter
# 212.112.115.253:46457 is bad
#
# 2001 proxies left to filter
# 217.210.157.135:54015 is slow
#
# 2000 proxies left to filter
# 45.164.166.30:8080 is good
# average conn time: 5.26903566192
#
# 1999 proxies left to filter
# 83.168.85.35:8090 is good
# average conn time: 5.11821917693
#
# 1998 proxies left to filter
# 207.180.242.44:8080 is slow
#
# 1997 proxies left to filter
# 81.88.198.166:49444 is slow
#
# 1996 proxies left to filter
# 50.195.207.133:47593 is good
# average conn time: 4.95942148409
#
# 1995 proxies left to filter
# 93.190.139.153:8080 is slow
#
# 1994 proxies left to filter
# 220.175.132.157:8060 is slow
#
# 1993 proxies left to filter
# 80.151.181.110:80 is slow
#
# 1992 proxies left to filter
# 93.190.137.122:8080 is slow
#
# 1991 proxies left to filter
# 95.65.1.200:58768 is bad
#
# 1990 proxies left to filter
# 82.117.215.14:8088 is slow
#
# 1989 proxies left to filter
# 74.113.169.129:47208 is good
# average conn time: 4.82426606417
#
# 1988 proxies left to filter
# 74.85.156.94:8080 is slow
#
# 1987 proxies left to filter
# 36.67.76.234:8080 is slow
#
# 1986 proxies left to filter
# 46.44.50.246:8081 is slow
#
# 1985 proxies left to filter
# 202.79.53.190:46734 is slow
#
# 1984 proxies left to filter
# 43.252.18.140:30351 is slow
#
# 1983 proxies left to filter
# 36.37.201.230:8080 is slow
#
# 1982 proxies left to filter
# 41.216.163.230:8080 is good
# average conn time: 4.86744549161
#
# 1981 proxies left to filter
# 36.72.97.157:8080 is slow
#
# 1980 proxies left to filter
# 42.115.39.70:49236 is bad
#
# 1979 proxies left to filter
# 41.170.33.4:8080 is slow
#
# 1978 proxies left to filter
# 54.37.30.206:8080 is slow
#
# 1977 proxies left to filter
# 51.255.161.222:80 is slow
#
# 1976 proxies left to filter
# 77.50.254.115:34688 is good
# average conn time: 4.81453315778
#
# 1975 proxies left to filter
# 88.102.13.246:32868 is slow
#
# 1974 proxies left to filter
# 78.186.98.48:34457 is slow
#
# 1973 proxies left to filter
# 36.89.180.169:8080 is slow
#
# 1972 proxies left to filter
# 51.68.84.215:80 is slow
#
# 1971 proxies left to filter
# 213.216.48.7:42370 is bad
#
# 1970 proxies left to filter
# 217.182.120.162:1080 is slow
#
# 1969 proxies left to filter
# 202.70.74.37:8080 is slow
#
# 1968 proxies left to filter
# 36.74.102.133:8080 is slow
#
# 1967 proxies left to filter
# 5.228.38.53:8081 is slow
#
# 1966 proxies left to filter
# 59.153.84.93:8080 is good
# average conn time: 4.99575601453
#
# 1965 proxies left to filter
# 222.135.29.242:8060 is slow
#
# 1964 proxies left to filter
# 212.172.74.14:443 is good
# average conn time: 4.96038425962
#
# 1963 proxies left to filter
# 36.89.119.149:8080 is slow
#
# 1962 proxies left to filter
# 54.37.204.119:80 is slow
#
# 1961 proxies left to filter
# 217.182.120.161:1080 is slow
#
# 1960 proxies left to filter
# 41.164.31.154:59565 is slow
#
# 1959 proxies left to filter
# 198.23.143.59:8080 is good
# average conn time: 4.96307265282
#
# 1958 proxies left to filter
# 62.152.43.152:8080 is slow
#
# 1957 proxies left to filter
# 222.88.158.34:8060 is slow
#
# 1956 proxies left to filter
# 80.211.36.44:80 is slow
#
# 1955 proxies left to filter
# 79.135.194.127:8080 is slow
#
# 1954 proxies left to filter
# 85.105.132.22:3128 is slow
#
# 1953 proxies left to filter
# 92.126.205.63:53281 is slow
#
# 1952 proxies left to filter
# 27.147.176.110:8080 is good
# average conn time: 4.9048072008
#
# 1951 proxies left to filter
# 91.207.27.142:4550 is good
# average conn time: 4.81057075218
#
# 1950 proxies left to filter
# 81.62.231.180:80 is slow
#
# 1949 proxies left to filter
# 77.93.27.92:8080 is slow
#
# 1948 proxies left to filter
# 41.177.122.111:37904 is slow
#
# 1947 proxies left to filter
# 36.66.152.126:3128 is slow
#
# 1946 proxies left to filter
# 68.183.99.96:8080 is slow
#
# 1945 proxies left to filter
# 43.249.226.225:53281 is good
# average conn time: 4.79997172526
#
# 1944 proxies left to filter
# 91.194.247.247:31337 is good
# average conn time: 4.89582080677
#
# 1943 proxies left to filter
# 202.79.43.76:35208 is slow
#
# 1942 proxies left to filter
# 36.85.121.118:8080 is slow
#
# 1941 proxies left to filter
# 201.148.238.222:34646 is good
# average conn time: 4.92550470829
#
# 1940 proxies left to filter
# 96.9.69.133:50693 is good
# average conn time: 5.0128114608
#
# 1939 proxies left to filter
# 79.253.201.179:8080 is good
# average conn time: 4.98343663663
#
# 1938 proxies left to filter
# 46.219.80.142:54874 is bad
#
# 1937 proxies left to filter
# 95.180.225.7:8080 is slow
#
# 1936 proxies left to filter
# 63.246.49.104:8080 is good
# average conn time: 4.91350313389
# 1935 proxies left to filter
# 95.71.166.93:8081 is slow
#
# 1934 proxies left to filter
# 85.196.147.146:52566 is slow
#
# 1933 proxies left to filter
# 217.12.54.4:42471 is slow
#
# 1932 proxies left to filter
# 54.39.24.40:3128 is good
# average conn time: 4.7780841028
#
# 1931 proxies left to filter
# 54.39.215.247:8080 is slow
#
# 1930 proxies left to filter
# 202.148.2.254:8000 is good
# average conn time: 4.82296061516
#
# 1929 proxies left to filter
# 52.39.101.98:80 is slow
#
# 1928 proxies left to filter
# 27.147.217.154:43252 is bad
#
# 1927 proxies left to filter
# 43.229.74.193:23500 is slow
#
# 1926 proxies left to filter
# 36.67.2.119:34853 is bad
#
# 1925 proxies left to filter
# 77.119.245.150:50815 is slow
#
# 1924 proxies left to filter
# 36.82.88.235:8080 is good
# average conn time: 4.95133050945
#
# 1923 proxies left to filter
# 36.91.194.25:8080 is good
# average conn time: 5.10181631269
#
# 1922 proxies left to filter
# 46.151.156.198:56013 is slow
#
# 1921 proxies left to filter
# 39.137.69.10:8080 is slow
#
# 1920 proxies left to filter
# 223.206.60.237:8080 is good
# average conn time: 5.09672011827
#
# 1919 proxies left to filter
# 77.120.246.243:46343 is bad
#
# 1918 proxies left to filter
# 85.198.133.19:43157 is bad
#
# 1917 proxies left to filter
# 47.254.38.195:443 is slow
#
# 1916 proxies left to filter
# 212.237.36.238:3128 is good
# average conn time: 4.99829775248
#
# 1915 proxies left to filter
# 36.66.57.213:21867 is slow
#
# 1914 proxies left to filter
# 68.183.129.232:3128 is good
# average conn time: 4.87964648008
#
# 1913 proxies left to filter
# 202.62.86.94:83 is slow
#
# 1912 proxies left to filter
# 62.8.65.33:3128 is good
# average conn time: 4.80745256819
#
# 1911 proxies left to filter
# 212.34.254.34:33523 is bad
#
# 1910 proxies left to filter
# 91.219.56.221:8080 is slow
#
# 1909 proxies left to filter
# 41.191.205.219:8080 is slow
#
# 1908 proxies left to filter
# 35.247.188.247:80 is slow
#
# 1907 proxies left to filter
# 212.24.105.100:3128 is good
# average conn time: 4.71830443541
#
# 1906 proxies left to filter
# 203.190.10.170:8080 is good
# average conn time: 4.77396400585
#
# 1905 proxies left to filter
# 64.17.30.238:63141 is bad
#
# 1904 proxies left to filter
# 86.110.129.234:8080 is good
# average conn time: 4.68987062303
#
# 1903 proxies left to filter
# 94.191.6.62:1080 is slow
#
# 1902 proxies left to filter
# 93.190.139.143:8080 is slow
#
# 1901 proxies left to filter
# 37.187.116.199:80 is slow
#
# 1900 proxies left to filter
# 85.232.248.9:8080 is bad
#
# 1899 proxies left to filter
# 91.109.198.57:8080 is good
# average conn time: 4.69765590032
#
# 1898 proxies left to filter
# 212.129.7.24:54321 is slow
#
# 1897 proxies left to filter
# 41.65.43.181:8080 is good
# average conn time: 4.70686816651
#
# 1896 proxies left to filter
# 52.60.34.6:8080 is slow
#
# 1895 proxies left to filter
# 82.200.164.194:8080 is bad
#
# 1894 proxies left to filter
# 87.227.204.114:56847 is slow
#
# 1893 proxies left to filter
# 212.237.36.238:8000 is good
# average conn time: 4.63983988762
#
# 1892 proxies left to filter
# 54.39.98.135:8080 is slow
#
# 1891 proxies left to filter
# 52.68.127.244:80 is good
# average conn time: 4.63599434992
#
# 1890 proxies left to filter
# 95.85.25.124:4444 is good
# average conn time: 4.55553964693
#
# 1889 proxies left to filter
# 80.82.55.71:80 is good
# average conn time: 4.51445849419
#
# 1888 proxies left to filter
# 58.137.62.133:80 is bad
#
# 1887 proxies left to filter
# 60.10.2.52:3128 is slow
#
# 1886 proxies left to filter
# 37.59.35.174:1080 is slow
#
# 1885 proxies left to filter
# 87.117.3.129:3128 is bad
#
# 1884 proxies left to filter
# 72.139.29.114:51306 is slow
#
# 1883 proxies left to filter
# 37.252.67.184:50616 is slow
#
# 1882 proxies left to filter
# 217.17.98.93:45838 is good
# average conn time: 4.46963176073
#
# 1881 proxies left to filter
# 41.87.29.130:8080 is good
# average conn time: 4.54435749696
#
# 1880 proxies left to filter
# 202.79.27.185:36124 is slow
#
# 1879 proxies left to filter
# 203.84.156.125:53281 is slow
#
# 1878 proxies left to filter
# 3.212.137.96:80 is slow
#
# 1877 proxies left to filter
# 50.252.127.53:53304 is good
# average conn time: 4.59188778895
#
# 1876 proxies left to filter
# 205.169.145.130:39438 is good
# average conn time: 4.5931800339
#
# 1875 proxies left to filter
# 212.147.41.102:80 is slow
#
# 1874 proxies left to filter
# 60.10.2.69:3128 is slow
#
# 1873 proxies left to filter
# 40.114.109.214:3128 is good
# average conn time: 4.51499877843
#
# 1872 proxies left to filter
# 69.70.25.172:31881 is bad
#
# 1871 proxies left to filter
# 96.75.42.213:3128 is slow
#
# 1870 proxies left to filter
# 59.152.238.123:80 is slow
#
# 1869 proxies left to filter
# 27.147.255.74:8080 is good
# average conn time: 4.48024717399
#
# 1868 proxies left to filter
# 220.247.168.163:53281 is bad
#
# 1867 proxies left to filter
# 212.147.41.101:80 is slow
#
# 1866 proxies left to filter
# 41.215.74.234:52163 is bad
#
# 1865 proxies left to filter
# 202.72.233.18:8080 is good
# average conn time: 4.51046901418
#
# 1864 proxies left to filter
# 77.34.33.44:8181 is good
# average conn time: 4.48329601206
#
# 1863 proxies left to filter
# 212.90.169.173:8081 is bad
#
# 1862 proxies left to filter
# 41.60.220.84:8080 is slow
#
# 1861 proxies left to filter
# 54.177.78.30:80 is slow
#
# 1860 proxies left to filter
# 202.144.201.134:44091 is bad
#
# 1859 proxies left to filter
# 93.190.139.150:8080 is slow
#
# 1858 proxies left to filter
# 213.6.156.113:80 is slow
#
# 1857 proxies left to filter
# 50.73.137.241:3128 is slow
#
# 1856 proxies left to filter
# 213.251.243.98:53147 is bad
#
# 1855 proxies left to filter
# 46.229.187.169:53281 is bad
#
# 1854 proxies left to filter
# 5.20.196.90:80 is slow
#
# 1853 proxies left to filter
# 45.232.224.80:42369 is bad
#
# 1852 proxies left to filter
# 69.171.68.90:8080 is slow
#
# 1851 proxies left to filter
# 94.73.217.125:40858 is slow
#
# 1850 proxies left to filter
# 36.90.86.27:8080 is slow
#
# 1849 proxies left to filter
# 5.83.125.116:8080 is good
# average conn time: 4.5208124872
#
# 1848 proxies left to filter
# 49.49.106.59:8080 is slow
#
# 1847 proxies left to filter
# 85.15.211.89:8080 is good
# average conn time: 4.47711666028
#
# 1846 proxies left to filter
# 49.231.140.117:3128 is good
# average conn time: 4.43824269732
#
# 1845 proxies left to filter
# 31.192.109.4:3128 is slow
#
# 1844 proxies left to filter
# 50.239.245.105:80 is slow
#
# 1843 proxies left to filter
# 221.7.255.168:80 is bad
#
# 1842 proxies left to filter
# 202.93.227.14:53281 is slow
#
# 1841 proxies left to filter
# 36.255.86.226:83 is good
# average conn time: 4.41386008647
#
# 1840 proxies left to filter
# 37.187.149.234:1080 is slow
#
# 1839 proxies left to filter
# 46.0.125.140:3128 is bad
#
# 1838 proxies left to filter
# 46.242.75.200:8081 is slow
#
# 1837 proxies left to filter
# 81.91.32.90:8080 is good
# average conn time: 4.37469679969
#
# 1836 proxies left to filter
# 201.182.120.230:8080 is good
# average conn time: 4.38993145898
#
# 1835 proxies left to filter
# 212.19.22.237:39959 is bad
#
# 1834 proxies left to filter
# 94.177.218.166:80 is slow
#
# 1833 proxies left to filter
# 45.115.174.234:8080 is good
# average conn time: 4.45097502195
#
# 1832 proxies left to filter
# 88.84.223.1:33519 is slow
#
# 1831 proxies left to filter
# 96.9.73.79:36360 is good
# average conn time: 4.52405135559
#
# 1830 proxies left to filter
# 45.125.66.227:54321 is slow
#
# 1829 proxies left to filter
# 217.182.120.160:1080 is slow
#
# 1828 proxies left to filter
# 36.89.148.117:56385 is bad
#
# 1827 proxies left to filter
# 213.244.84.65:8080 is good
# average conn time: 4.50351827536
#
# 1826 proxies left to filter
# 54.39.102.232:8080 is slow
#
# 1825 proxies left to filter
# 64.183.32.218:48712 is bad
#
# 1824 proxies left to filter
# 41.190.95.20:52842 is good
# average conn time: 4.58389525904
#
# 1823 proxies left to filter
# 91.195.156.241:3128 is slow
#
# 1822 proxies left to filter
# 68.183.156.72:80 is slow
#
# 1821 proxies left to filter
# 46.49.86.230:40362 is slow
#
# 1820 proxies left to filter
# 88.21.192.216:8080 is slow
#
# 1819 proxies left to filter
# 95.158.238.197:53281 is good
# average conn time: 4.61270064547
#
# 1818 proxies left to filter
# 35.227.253.47:80 is slow
#
# 1817 proxies left to filter
# 212.129.5.248:54321 is slow
#
# 1816 proxies left to filter
# 36.78.131.182:60442 is good
# average conn time: 4.67414272172
#
# 1815 proxies left to filter
# 47.254.83.176:8080 is slow
#
# 1814 proxies left to filter
# 60.10.2.70:3128 is slow
#
# 1813 proxies left to filter
# 68.183.231.47:3128 is slow
#
# 1812 proxies left to filter
# 91.209.11.132:80 is slow
#
# 1811 proxies left to filter
# 85.187.17.39:53281 is good
# average conn time: 4.6621342612
# 1810 proxies left to filter
# 51.75.109.84:3128 is slow
#
# 1809 proxies left to filter
# 51.68.70.211:3128 is good
# average conn time: 4.64028639595
#
# 1808 proxies left to filter
# 93.100.9.74:32620 is good
# average conn time: 4.69705685524
#
# 1807 proxies left to filter
# 85.29.136.212:8080 is slow
#
# 1806 proxies left to filter
# 207.182.135.52:3128 is slow
#
# 1805 proxies left to filter
# 203.76.220.226:42221 is slow
#
# 1804 proxies left to filter
# 95.28.216.102:31944 is bad
#
# 1803 proxies left to filter
# 200.37.246.19:8080 is slow
#
# 1802 proxies left to filter
# 36.81.38.238:8080 is slow
#
# 1801 proxies left to filter
# 94.23.49.201:80 is good
# average conn time: 4.6856255628
#
# 1800 proxies left to filter
# 80.232.242.107:50719 is slow
#
# 1799 proxies left to filter
# 94.130.187.8:3128 is slow
#
# 1798 proxies left to filter
# 202.79.43.33:35258 is good
# average conn time: 4.70247555415
#
# 1797 proxies left to filter
# 41.206.57.242:8080 is good
# average conn time: 4.69811154667
#
# 1796 proxies left to filter
# 41.160.114.37:12354 is good
# average conn time: 4.66351068175
#
# 1795 proxies left to filter
# 80.76.240.168:35627 is bad
#
# 1794 proxies left to filter
# 43.229.24.37:37073 is slow
#
# 1793 proxies left to filter
# 93.99.179.233:8080 is good
# average conn time: 4.69378682589
#
# 1792 proxies left to filter
# 80.245.125.21:45335 is good
# average conn time: 4.69385352618
#
# 1791 proxies left to filter
# 27.72.61.48:48455 is bad
#
# 1790 proxies left to filter
# 62.240.53.234:8080 is slow
#
# 1789 proxies left to filter
# 43.248.213.228:38299 is slow
#
# 1788 proxies left to filter
# 47.100.237.242:8080 is good
# average conn time: 4.69976865649
#
# 1787 proxies left to filter
# 203.115.97.106:31070 is good
# average conn time: 4.72031222744
#
# 1786 proxies left to filter
# 217.23.176.215:40242 is good
# average conn time: 4.74000540885
#
# 1785 proxies left to filter
# 36.67.23.117:8888 is bad
#
# 1784 proxies left to filter
# 36.68.181.204:8080 is good
# average conn time: 4.71585751154
#
# 1783 proxies left to filter
# 202.51.103.82:8080 is good
# average conn time: 4.73640845787
#
# 1782 proxies left to filter
# 211.43.189.223:80 is good
# average conn time: 4.71777513448
#
# 1781 proxies left to filter
# 49.49.210.76:8080 is slow
#
# 1780 proxies left to filter
# 36.90.25.207:8080 is good
# average conn time: 4.70579858436
#
# 1779 proxies left to filter
# 46.8.28.17:8080 is good
# average conn time: 4.66978248783
#
# 1778 proxies left to filter
# 3.213.81.24:3128 is slow
#
# 1777 proxies left to filter
# 213.244.84.97:8080 is good
# average conn time: 4.69488300519
#
# 1776 proxies left to filter
# 202.138.229.73:59701 is bad
#
# 1775 proxies left to filter
# 59.152.97.222:8080 is good
# average conn time: 4.67360464643
#
# 1774 proxies left to filter
# 94.236.199.216:35602 is slow
#
# 1773 proxies left to filter
# 80.254.125.236:8080 is slow
#
# 1772 proxies left to filter
# 217.73.192.11:50890 is good
# average conn time: 4.68235647413
#
# 1771 proxies left to filter
# 45.70.194.193:8080 is slow
#
# 1770 proxies left to filter
# 46.219.104.160:33652 is bad
#
# 1769 proxies left to filter
# 212.22.86.114:3130 is good
# average conn time: 4.67222779662
#
# 1768 proxies left to filter
# 46.175.70.69:61506 is bad
#
# 1767 proxies left to filter
# 82.117.244.85:31280 is slow
#
# 1766 proxies left to filter
# 203.150.147.56:8080 is slow
#
# 1765 proxies left to filter
# 54.39.98.135:80 is slow
#
# 1764 proxies left to filter
# 200.37.54.10:52276 is bad
#
# 1763 proxies left to filter
# 212.9.133.142:443 is slow
#
# 1762 proxies left to filter
# 45.234.68.4:54111 is good
# average conn time: 4.64504029699
#
# 1761 proxies left to filter
# 212.237.7.173:8118 is slow
#
# 1760 proxies left to filter
# 93.81.241.241:80 is good
# average conn time: 4.6394767351
#
# 1759 proxies left to filter
# 41.73.97.215:80 is slow
#
# 1758 proxies left to filter
# 88.206.50.148:8081 is slow
#
# 1757 proxies left to filter
# 27.72.75.227:8080 is good
# average conn time: 4.61781230379
#
# 1756 proxies left to filter
# 36.66.126.79:31238 is slow
#
# 1755 proxies left to filter
# 36.89.99.98:44030 is good
# average conn time: 4.66338684684
#
# 1754 proxies left to filter
# 202.137.10.179:57338 is bad
#
# 1753 proxies left to filter
# 43.225.21.104:34549 is slow
#
# 1752 proxies left to filter
# 35.181.36.31:3128 is good
# average conn time: 4.62184079488
#
# 1751 proxies left to filter
# 202.159.40.43:80 is slow
#
# 1750 proxies left to filter
# 51.75.65.79:8080 is good
# average conn time: 4.58268391226
#
# 1749 proxies left to filter
# 94.242.59.135:1448 is good
# average conn time: 4.54573204566
#
# 1748 proxies left to filter
# 47.44.215.166:80 is slow
#
# 1747 proxies left to filter
# 91.235.42.20:3130 is slow
#
# 1746 proxies left to filter
# 46.151.108.6:45908 is bad
#
# 1745 proxies left to filter
# 202.84.79.11:47021 is bad
#
# 1744 proxies left to filter
# 89.102.2.149:8080 is bad
#
# 1743 proxies left to filter
# 27.147.216.36:48194 is bad
#
# 1742 proxies left to filter
# 54.71.152.195:80 is slow
#
# 1741 proxies left to filter
# 207.148.71.188:8080 is good
# average conn time: 4.5369338339
#
# 1740 proxies left to filter
# 209.97.180.250:8080 is good
# average conn time: 4.49827760458
#
# 1739 proxies left to filter
# 202.169.107.234:3128 is slow
#
# 1738 proxies left to filter
# 46.10.229.248:8080 is bad
#
# 1737 proxies left to filter
# 91.109.192.217:8080 is good
# average conn time: 4.62286493566
#
# 1736 proxies left to filter
# 41.73.3.206:8080 is slow
#
# 1735 proxies left to filter
# 202.169.226.230:8080 is good
# average conn time: 4.64961646585
#
# 1734 proxies left to filter
# 222.135.92.105:8060 is slow
#
# 1733 proxies left to filter
# 52.124.6.146:40834 is good
# average conn time: 4.61527955879
#
# 1732 proxies left to filter
# 35.245.181.166:3128 is good
# average conn time: 4.57425727523
#
# 1731 proxies left to filter
# 27.147.255.12:32589 is slow
#
# 1730 proxies left to filter
# 66.7.113.39:3128 is good
# average conn time: 4.53489158721
#
# 1729 proxies left to filter
# 70.35.213.229:36127 is good
# average conn time: 4.54621979875
#
# 1728 proxies left to filter
# 202.134.180.50:8080 is good
# average conn time: 4.57062357831
#
# 1727 proxies left to filter
# 49.156.42.188:8080 is good
# average conn time: 4.575546832
#
# 1726 proxies left to filter
# 80.240.25.63:1080 is slow
#
# 1725 proxies left to filter
# 41.60.239.43:8080 is good
# average conn time: 4.57937831179
#
# 1724 proxies left to filter
# 95.87.220.19:15600 is good
# average conn time: 4.54647354429
#
# 1723 proxies left to filter
# 202.70.82.253:23500 is bad
#
# 1722 proxies left to filter
# 23.20.214.120:3128 is good
# average conn time: 4.56058639449
#
# 1721 proxies left to filter
# 210.120.247.60:80 is good
# average conn time: 4.53944930221
#
# 1720 proxies left to filter
# 93.186.251.135:3128 is bad
#
# 1719 proxies left to filter
# 36.255.87.234:83 is bad
#
# 1718 proxies left to filter
# 52.79.128.193:80 is slow
#
# 1717 proxies left to filter
# 221.229.252.98:9797 is bad
#
# 1716 proxies left to filter
# 93.171.241.18:45781 is slow
#
# 1715 proxies left to filter
# 27.74.247.140:42977 is bad
#
# 1714 proxies left to filter
# 89.218.22.178:8080 is bad
#
# 1713 proxies left to filter
# 84.214.150.146:8080 is bad
#
# 1712 proxies left to filter
# 5.1.104.98:38144 is good
# average conn time: 4.51506635362
#
# 1711 proxies left to filter
# 78.228.165.215:80 is slow
#
# 1710 proxies left to filter
# 79.106.35.253:8080 is good
# average conn time: 4.52344251725
#
# 1709 proxies left to filter
# 213.226.227.173:44439 is slow
#
# 1708 proxies left to filter
# 5.141.81.124:8081 is slow
#
# 1707 proxies left to filter
# 89.79.124.160:8081 is good
# average conn time: 4.53350889372
#
# 1706 proxies left to filter
# 23.237.22.82:3128 is good
# average conn time: 4.49741829058
#
# 1705 proxies left to filter
# 36.67.27.29:56125 is good
# average conn time: 4.52320278404
#
# 1704 proxies left to filter
# 62.234.123.99:1080 is slow
#
# 1703 proxies left to filter
# 223.19.212.30:8380 is slow
#
# 1702 proxies left to filter
# 36.37.160.253:53480 is bad
#
# 1701 proxies left to filter
# 91.82.108.222:32961 is good
# average conn time: 4.55894788645
#
# 1700 proxies left to filter
# 31.202.30.118:54547 is bad
#
# 1699 proxies left to filter
# 212.72.137.73:3128 is slow
#
# 1698 proxies left to filter
# 219.120.3.219:80 is slow
#
# 1697 proxies left to filter
# 5.133.24.117:8080 is good
# average conn time: 4.55989307315
#
# 1696 proxies left to filter
# 77.85.206.34:44663 is bad
#
# 1695 proxies left to filter
# 203.110.84.178:32486 is good
# average conn time: 4.55134989619
#
# 1694 proxies left to filter
# 46.16.225.236:8080 is good
# average conn time: 4.57539901261
#
# 1693 proxies left to filter
# 27.147.216.140:80 is good
# average conn time: 4.5952323812
#
# 1692 proxies left to filter
# 201.217.4.101:53281 is slow
#
# 1691 proxies left to filter
# 35.195.186.241:3128 is good
# average conn time: 4.56511528705
#
# 1690 proxies left to filter
# 36.89.226.254:8081 is bad
#
# 1689 proxies left to filter
# 51.158.96.122:3128 is good
# average conn time: 4.53373895537
#
# 1688 proxies left to filter
# 213.6.87.158:55295 is bad
#
# 1687 proxies left to filter
# 35.193.0.225:80 is slow
#
# 1686 proxies left to filter
# 45.125.66.122:54321 is slow
#
# 1685 proxies left to filter
# 84.22.199.14:8080 is good
# average conn time: 4.52969816399
#
# 1684 proxies left to filter
# 5.58.131.2:44852 is bad
#
# 1683 proxies left to filter
# 203.81.70.178:80 is slow
#
# 1682 proxies left to filter
# 212.184.186.146:8080 is slow
#
# 1681 proxies left to filter
# 202.5.37.96:63141 is good
# average conn time: 4.53008338383
#
# 1680 proxies left to filter
# 49.87.102.6:9999 is slow
#
# 1679 proxies left to filter
# 46.36.37.14:80 is slow
#
# 1678 proxies left to filter
# 213.247.192.131:41258 is bad
#
# 1677 proxies left to filter
# 88.255.213.234:8080 is good
# average conn time: 4.53181162594
#
# 1676 proxies left to filter
# 37.53.217.44:8081 is slow
#
# 1675 proxies left to filter
# 75.128.209.158:8080 is bad
#
# 1674 proxies left to filter
# 36.81.245.69:80 is slow
#
# 1673 proxies left to filter
# 31.214.138.207:8080 is slow
#
# 1672 proxies left to filter
# 36.91.148.35:8080 is slow
#
# 1671 proxies left to filter
# 93.91.162.17:59457 is good
# average conn time: 4.52770465985
#
# 1670 proxies left to filter
# 49.156.39.102:56511 is slow
#
# 1669 proxies left to filter
# 222.165.249.43:23500 is slow
#
# 1668 proxies left to filter
# 24.172.82.94:53281 is good
# average conn time: 4.52554008757
#
# 1667 proxies left to filter
# 43.226.12.234:8080 is slow
#
# 1666 proxies left to filter
# 88.210.71.234:46626 is slow
#
# 1665 proxies left to filter
# 77.95.96.174:80 is slow
#
# 1664 proxies left to filter
# 43.230.157.150:49072 is bad
#
# 1663 proxies left to filter
# 93.190.137.11:8080 is slow
#
# 1662 proxies left to filter
# 202.124.38.230:8080 is slow
#
# 1661 proxies left to filter
# 41.170.12.92:37444 is slow
#
# 1660 proxies left to filter
# 89.218.170.58:60685 is good
# average conn time: 4.53562497176
#
# 1659 proxies left to filter
# 36.67.8.27:53281 is slow
#
# 1658 proxies left to filter
# 5.58.11.215:43222 is bad
#
# 1657 proxies left to filter
# 58.243.186.179:55405 is bad
#
# 1656 proxies left to filter
# 80.211.181.248:8080 is slow
#
# 1655 proxies left to filter
# 5.249.141.14:80 is slow
#
# 1654 proxies left to filter
# 46.45.146.213:8080 is bad
#
# 1653 proxies left to filter
# 42.115.62.26:8080 is good
# average conn time: 4.53601478984
#
# 1652 proxies left to filter
# 85.214.103.72:8080 is good
# average conn time: 4.50799166253
#
# 1651 proxies left to filter
# 202.93.229.99:8080 is slow
#
# 1650 proxies left to filter
# 31.130.91.37:44679 is good
# average conn time: 4.51670073925
#
# 1649 proxies left to filter
# 45.237.240.200:8080 is good
# average conn time: 4.52664614435
#
# 1648 proxies left to filter
# 95.179.224.10:80 is slow
#
# 1647 proxies left to filter
# 89.248.244.182:8080 is good
# average conn time: 4.52166304058
#
# 1646 proxies left to filter
# 203.150.129.128:8080 is good
# average conn time: 4.50467267983
#
# 1645 proxies left to filter
# 77.74.79.25:8080 is good
# average conn time: 4.48090212014
#
# 1644 proxies left to filter
# 77.95.96.170:80 is slow
#
# 1643 proxies left to filter
# 217.150.47.117:3128 is good
# average conn time: 4.46997408245
#
# 1642 proxies left to filter
# 91.203.115.11:44107 is slow
#
# 1641 proxies left to filter
# 213.226.255.24:46870 is bad
#
# 1640 proxies left to filter
# 45.32.105.49:80 is slow
#
# 1639 proxies left to filter
# 63.134.172.12:80 is slow
#
# 1638 proxies left to filter
# 81.18.34.98:53596 is bad
#
# 1637 proxies left to filter
# 203.153.222.127:8080 is slow
#
# 1636 proxies left to filter
# 46.0.126.134:3128 is good
# average conn time: 4.47001879335
#
# 1635 proxies left to filter
# 43.245.35.186:8080 is good
# average conn time: 4.48853291614
#
# 1634 proxies left to filter
# 91.209.11.131:80 is slow
#
# 1633 proxies left to filter
# 212.43.123.18:41258 is bad
#
# 1632 proxies left to filter
# 45.5.147.4:36296 is slow
#
# 1631 proxies left to filter
# 47.75.229.228:3128 is good
# average conn time: 4.48555699477
#
# 1630 proxies left to filter
# 94.41.0.163:53281 is good
# average conn time: 4.47594797443
#
# 1629 proxies left to filter
# 91.205.218.32:80 is slow
#
# 1628 proxies left to filter
# 5.165.176.115:8080 is good
# average conn time: 4.45450618384
#
# 1627 proxies left to filter
# 66.96.237.253:8080 is slow
#
# 1626 proxies left to filter
# 85.43.127.116:80 is slow
#
# 1625 proxies left to filter
# 45.227.164.14:999 is good
# average conn time: 4.44820478062
#
# 1624 proxies left to filter
# 27.147.233.28:8080 is good
# average conn time: 4.43453034861
#
# 1623 proxies left to filter
# 51.83.47.73:3128 is good
# average conn time: 4.40958303131
#
# 1622 proxies left to filter
# 221.126.249.100:8080 is bad
#
# 1621 proxies left to filter
# 66.70.188.148:3128 is slow
#
# 1620 proxies left to filter
# 207.148.72.216:8080 is slow
#
# 1619 proxies left to filter
# 45.78.22.85:8888 is slow
#
# 1618 proxies left to filter
# 212.93.110.42:51887 is slow
#
# 1617 proxies left to filter
# 91.211.193.31:53281 is slow
#
# 1616 proxies left to filter
# 209.80.12.183:80 is slow
#
# 1615 proxies left to filter
# 3.16.134.28:3128 is good
# average conn time: 4.38297594323
#
# 1614 proxies left to filter
# 81.90.188.154:80 is slow
#
# 1613 proxies left to filter
# 70.123.192.150:3128 is slow
#
# 1612 proxies left to filter
# 36.89.134.161:3128 is slow
#
# 1611 proxies left to filter
# 36.67.197.53:3128 is good
# average conn time: 4.39226176127
#
# 1610 proxies left to filter
# 74.84.255.88:53281 is good
# average conn time: 4.40677044056
#
# 1609 proxies left to filter
# 52.9.244.23:3128 is good
# average conn time: 4.40681467056
#
# 1608 proxies left to filter
# 212.72.142.50:32827 is slow
#
# 1607 proxies left to filter
# 66.251.168.146:8080 is slow
#
# 1606 proxies left to filter
# 68.183.190.208:8080 is good
# average conn time: 4.39470981762
#
# 1605 proxies left to filter
# 50.239.245.102:80 is slow
#
# 1604 proxies left to filter
# 36.91.194.229:80 is good
# average conn time: 4.40369624056
#
# 1603 proxies left to filter
# 222.124.7.69:8080 is good
# average conn time: 4.40861894414
#
# 1602 proxies left to filter
# 23.102.224.85:80 is slow
#
# 1601 proxies left to filter
# 207.180.240.231:8000 is slow
#
# 1600 proxies left to filter
# 39.137.69.6:8080 is slow
#
# 1599 proxies left to filter
# 5.53.119.186:30333 is good
# average conn time: 4.40543671088
#
# 1598 proxies left to filter
# 85.204.49.90:54321 is good
# average conn time: 4.38668624816
#
# 1597 proxies left to filter
# 27.129.50.242:3128 is bad
#
# 1596 proxies left to filter
# 87.244.176.213:45553 is bad
#
# 1595 proxies left to filter
# 217.21.146.105:8080 is slow
#
# 1594 proxies left to filter
# 68.183.53.127:80 is slow
#
# 1593 proxies left to filter
# 41.76.44.76:3128 is good
# average conn time: 4.45835716296
#
# 1592 proxies left to filter
# 78.189.86.14:23500 is slow
#
# 1591 proxies left to filter
# 61.8.68.238:42956 is good
# average conn time: 4.47843556951
#
# 1590 proxies left to filter
# 80.240.253.112:46600 is slow
#
# 1589 proxies left to filter
# 201.184.233.179:8080 is good
# average conn time: 4.48533657231
#
# 1588 proxies left to filter
# 36.67.71.207:48406 is slow
#
# 1587 proxies left to filter
# 54.37.136.149:3128 is good
# average conn time: 4.46440819075
#
# 1586 proxies left to filter
# 36.91.49.26:8080 is good
# average conn time: 4.47610528916
#
# 1585 proxies left to filter
# 42.115.221.58:3128 is slow
#
# 1584 proxies left to filter
# 220.158.236.40:3128 is slow
#
# 1583 proxies left to filter
# 202.150.136.213:3128 is good
# average conn time: 4.48127038731
#
# 1582 proxies left to filter
# 213.184.226.166:38807 is good
# average conn time: 4.49217444732
#
# 1581 proxies left to filter
# 36.66.171.217:8080 is slow
#
# 1580 proxies left to filter
# 59.48.237.6:8060 is slow
#
# 1579 proxies left to filter
# 41.216.230.154:48705 is slow
#
# 1578 proxies left to filter
# 202.131.241.10:54433 is slow
#
# 1577 proxies left to filter
# 80.68.121.217:61091 is bad
#
# 1576 proxies left to filter
# 51.255.161.78:80 is slow
#
# 1575 proxies left to filter
# 79.106.226.210:8080 is good
# average conn time: 4.50798156803
#
# 1574 proxies left to filter
# 82.79.150.221:3128 is slow
#
# 1573 proxies left to filter
# 77.119.242.147:35778 is slow
#
# 1572 proxies left to filter
# 54.204.53.203:80 is slow
#
# 1571 proxies left to filter
# 84.52.110.36:38674 is bad
# 1570 proxies left to filter
# 80.78.72.152:39172 is slow
#
# 1569 proxies left to filter
# 62.33.210.34:44786 is slow
#
# 1568 proxies left to filter
# 37.79.244.120:3128 is bad
#
# 1567 proxies left to filter
# 61.219.134.55:11999 is slow
#
# 1566 proxies left to filter
# 41.204.87.90:8080 is good
# average conn time: 4.50029016268
#
# 1565 proxies left to filter
# 95.82.251.187:30418 is bad
#
# 1564 proxies left to filter
# 79.142.82.70:55269 is good
# average conn time: 4.4892026829
#
# 1563 proxies left to filter
# 83.96.109.247:80 is slow
#
# 1562 proxies left to filter
# 36.74.68.161:8080 is good
# average conn time: 4.47982935302
#
# 1561 proxies left to filter
# 85.214.117.156:3128 is slow
#
# 1560 proxies left to filter
# 51.254.195.132:3128 is slow
#
# 1559 proxies left to filter
# 202.150.132.98:63141 is good
# average conn time: 4.50742270989
#
# 1558 proxies left to filter
# 41.190.139.46:8080 is slow
#
# 1557 proxies left to filter
# 201.182.223.16:37492 is bad
#
# 1556 proxies left to filter
# 81.62.231.182:80 is slow
#
# 1555 proxies left to filter
# 36.91.59.218:8080 is slow
#
# 1554 proxies left to filter
# 80.152.210.221:3128 is good
# average conn time: 4.48733089651
#
# 1553 proxies left to filter
# 202.57.62.170:32760 is bad
#
# 1552 proxies left to filter
# 217.173.18.238:8080 is slow
#
# 1551 proxies left to filter
# 213.128.162.118:8080 is good
# average conn time: 4.46856015815
#
# 1550 proxies left to filter
# 34.85.22.18:80 is good
# average conn time: 4.45041066899
#
# 1549 proxies left to filter
# 206.189.155.32:3128 is slow
#
# 1548 proxies left to filter
# 62.122.140.30:56932 is slow
#
# 1547 proxies left to filter
# 91.142.167.71:8080 is good
# average conn time: 4.43872153689
#
# 1546 proxies left to filter
# 37.194.50.174:8080 is good
# average conn time: 4.42261123103
#
# 1545 proxies left to filter
# 95.168.225.77:8080 is good
# average conn time: 4.42293921234
#
# 1544 proxies left to filter
# 45.117.74.174:8080 is good
# average conn time: 4.4215125791
#
# 1543 proxies left to filter
# 202.152.142.18:808 is slow
#
# 1542 proxies left to filter
# 36.67.239.23:8080 is good
# average conn time: 4.43208425522
#
# 1541 proxies left to filter
# 203.114.106.253:8080 is slow
#
# 1540 proxies left to filter
# 62.234.54.114:1080 is slow
#
# 1539 proxies left to filter
# 209.97.165.158:31330 is good
# average conn time: 4.41924286837
#
# 1538 proxies left to filter
# 203.190.13.129:8080 is slow
#
# 1537 proxies left to filter
# 212.175.0.201:42913 is bad
#
# 1536 proxies left to filter
# 91.206.19.193:8081 is slow
#
# 1535 proxies left to filter
# 89.20.135.204:80 is slow
#
# 1534 proxies left to filter
# 89.218.25.209:8080 is good
# average conn time: 4.42510580208
#
# 1533 proxies left to filter
# 36.91.44.243:49082 is good
# average conn time: 4.42776514573
#
# 1532 proxies left to filter
# 45.79.148.252:80 is slow
#
# 1531 proxies left to filter
# 202.40.183.250:45241 is slow
#
# 1530 proxies left to filter
# 36.67.134.165:46093 is slow
#
# 1529 proxies left to filter
# 27.147.173.53:57363 is good
# average conn time: 4.42312522307
#
# 1528 proxies left to filter
# 221.126.249.102:8080 is bad
#
# 1527 proxies left to filter
# 58.87.123.1:1080 is slow
#
# 1526 proxies left to filter
# 89.43.38.22:37860 is good
# average conn time: 4.41616235044
#
# 1525 proxies left to filter
# 42.115.21.105:53281 is good
# average conn time: 4.42909536968
#
# 1524 proxies left to filter
# 45.125.66.42:54321 is slow
#
# 1523 proxies left to filter
# 80.91.116.233:8080 is slow
#
# 1522 proxies left to filter
# 95.79.55.196:53281 is good
# average conn time: 4.43539013705
#
# 1521 proxies left to filter
# 50.233.42.98:51696 is bad
#
# 1520 proxies left to filter
# 36.66.47.4:52944 is slow
#
# 1519 proxies left to filter
# 201.212.222.70:8080 is good
# average conn time: 4.44695109227
#
# 1518 proxies left to filter
# 203.76.115.90:8080 is good
# average conn time: 4.44758485193
#
# 1517 proxies left to filter
# 200.35.53.117:32628 is slow
#
# 1516 proxies left to filter
# 80.241.34.122:8081 is slow
#
# 1515 proxies left to filter
# 222.152.106.155:80 is slow
#
# 1514 proxies left to filter
# 87.244.181.136:8080 is good
# average conn time: 4.43553467441
#
# 1513 proxies left to filter
# 60.217.153.100:8060 is slow
#
# 1512 proxies left to filter
# 212.34.53.150:53281 is good
# average conn time: 4.42234685472
#
# 1511 proxies left to filter
# 31.132.145.19:8081 is slow
#
# 1510 proxies left to filter
# 45.32.124.247:8080 is slow
#
# 1509 proxies left to filter
# 40.74.243.24:80 is slow
#
# 1508 proxies left to filter
# 47.99.113.175:8118 is slow
#
# 1507 proxies left to filter
# 51.77.162.148:3128 is slow
#
# 1506 proxies left to filter
# 36.71.150.113:80 is good
# average conn time: 4.42378136946
#
# 1505 proxies left to filter
# 47.254.21.23:80 is slow
#
# 1504 proxies left to filter
# 91.203.236.226:52688 is bad
#
# 1503 proxies left to filter
# 212.64.75.204:1080 is slow
#
# 1502 proxies left to filter
# 221.4.172.162:3128 is bad
#
# 1501 proxies left to filter
# 96.9.79.199:44387 is slow
#
# 1500 proxies left to filter
# 37.115.244.245:8080 is slow
#
# 1499 proxies left to filter
# 52.60.109.69:3128 is slow
#
# 1498 proxies left to filter
# 49.84.223.156:9000 is good
# average conn time: 4.42581887829
#
# 1497 proxies left to filter
# 36.67.246.50:31869 is slow
#
# 1496 proxies left to filter
# 222.124.168.170:46848 is slow
#
# 1495 proxies left to filter
# 77.46.146.252:53281 is slow
#
# 1494 proxies left to filter
# 43.239.73.99:8080 is good
# average conn time: 4.46608003233
#
# 1493 proxies left to filter
# 81.196.41.75:41092 is good
# average conn time: 4.46811214372
#
# 1492 proxies left to filter
# 201.220.140.6:8080 is good
# average conn time: 4.4770862482
#
# 1491 proxies left to filter
# 212.32.213.170:8080 is slow
#
# 1490 proxies left to filter
# 212.67.0.150:33171 is bad
#
# 1489 proxies left to filter
# 52.233.190.21:80 is slow
#
# 1488 proxies left to filter
# 31.220.59.89:3128 is slow
#
# 1487 proxies left to filter
# 93.91.112.247:41258 is good
# average conn time: 4.46047003816
#
# 1486 proxies left to filter
# 23.83.226.119:3128 is slow
#
# 1485 proxies left to filter
# 35.198.147.143:80 is slow
#
# 1484 proxies left to filter
# 31.223.73.107:50838 is good
# average conn time: 4.48973673736
#
# 1483 proxies left to filter
# 89.24.126.164:80 is slow
#
# 1482 proxies left to filter
# 49.48.137.124:8080 is slow
#
# 1481 proxies left to filter
# 41.67.135.4:8080 is good
# average conn time: 4.50490544014
#
# 1480 proxies left to filter
# 52.13.171.28:80 is slow
#
# 1479 proxies left to filter
# 31.193.124.70:53281 is good
# average conn time: 4.50971923853
#
# 1478 proxies left to filter
# 80.211.68.29:8080 is slow
#
# 1477 proxies left to filter
# 78.186.194.45:8080 is good
# average conn time: 4.51422525304
#
# 1476 proxies left to filter
# 45.119.133.225:8080 is good
# average conn time: 4.50798507995
#
# 1475 proxies left to filter
# 47.89.48.178:80 is slow
#
# 1474 proxies left to filter
# 37.53.86.57:8081 is slow
#
# 1473 proxies left to filter
# 212.21.157.74:53281 is bad
#
# 1472 proxies left to filter
# 36.66.98.6:53281 is bad
#
# 1471 proxies left to filter
# 79.111.81.82:8080 is good
# average conn time: 4.49254705448
#
# 1470 proxies left to filter
# 95.211.213.240:3129 is slow
#
# 1469 proxies left to filter
# 45.4.237.72:33847 is good
# average conn time: 4.49601187299
#
# 1468 proxies left to filter
# 80.241.254.86:50621 is slow
#
# 1467 proxies left to filter
# 39.45.183.197:3128 is good
# average conn time: 4.51482281804
#
# 1466 proxies left to filter
# 54.38.110.35:47640 is good
# average conn time: 4.50812666926
#
# 1465 proxies left to filter
# 62.182.110.19:41258 is slow
#
# 1464 proxies left to filter
# 206.189.114.94:8080 is good
# average conn time: 4.48925190279
#
# 1463 proxies left to filter
# 27.147.129.228:8080 is good
# average conn time: 4.47912892685
#
# 1462 proxies left to filter
# 202.59.171.174:58567 is slow
#
# 1461 proxies left to filter
# 43.229.73.129:8080 is slow
#
# 1460 proxies left to filter
# 206.221.177.131:3128 is slow
#
# 1459 proxies left to filter
# 43.248.24.158:51166 is bad
#
# 1458 proxies left to filter
# 221.120.163.250:58088 is slow
#
# 1457 proxies left to filter
# 36.72.199.86:8080 is slow
#
# 1456 proxies left to filter
# 212.75.217.42:40479 is bad
#
# 1455 proxies left to filter
# 43.225.21.98:34549 is slow
#
# 1454 proxies left to filter
# 213.135.131.109:8081 is slow
#
# 1453 proxies left to filter
# 31.193.90.243:8080 is bad
#
# 1452 proxies left to filter
# 203.81.70.178:8080 is slow
#
# 1451 proxies left to filter
# 50.239.245.106:80 is slow
#
# 1450 proxies left to filter
# 84.52.74.194:8080 is good
# average conn time: 4.46883349091
#
# 1449 proxies left to filter
# 222.124.127.84:8080 is slow
#
# 1448 proxies left to filter
# 36.66.116.15:34616 is good
# average conn time: 4.49327420025
#
# 1447 proxies left to filter
# 209.141.32.12:80 is slow
#
# 1446 proxies left to filter
# 85.29.136.212:8085 is slow
#
# 1445 proxies left to filter
# 89.175.129.145:55653 is slow
#
# 1444 proxies left to filter
# 36.37.208.50:8080 is good
# average conn time: 4.50357320471
#
# 1443 proxies left to filter
# 41.79.169.82:8080 is slow
#
# 1442 proxies left to filter
# 41.60.236.40:8080 is slow
#
# 1441 proxies left to filter
# 93.99.104.108:80 is slow
#
# 1440 proxies left to filter
# 83.215.180.178:32759 is slow
#
# 1439 proxies left to filter
# 46.170.36.226:21231 is slow
#
# 1438 proxies left to filter
# 35.182.54.53:3128 is slow
#
# 1437 proxies left to filter
# 27.147.183.49:8080 is good
# average conn time: 4.49905122305
#
# 1436 proxies left to filter
# 45.114.182.185:55049 is good
# average conn time: 4.51258708766
#
# 1435 proxies left to filter
# 45.4.183.88:53281 is slow
#
# 1434 proxies left to filter
# 41.170.48.74:57797 is slow
#
# 1433 proxies left to filter
# 5.9.232.179:3128 is slow
#
# 1432 proxies left to filter
# 222.252.6.55:33270 is slow
#
# 1431 proxies left to filter
# 93.174.125.45:80 is slow
#
# 1430 proxies left to filter
# 27.203.219.215:8060 is slow
#
# 1429 proxies left to filter
# 79.137.73.163:8080 is good
# average conn time: 4.49555502554
#
# 1428 proxies left to filter
# 35.245.104.103:3128 is good
# average conn time: 4.50354567255
#
# 1427 proxies left to filter
# 84.242.188.162:38182 is bad
#
# 1426 proxies left to filter
# 43.240.103.228:40188 is slow
#
# 1425 proxies left to filter
# 5.149.205.141:8080 is slow
#
# 1424 proxies left to filter
# 41.254.41.230:8080 is slow
#
# 1423 proxies left to filter
# 84.244.90.179:46387 is good
# average conn time: 4.48953048991
#
# 1422 proxies left to filter
# 202.40.182.115:39122 is slow
#
# 1421 proxies left to filter
# 77.104.219.82:30635 is slow
#
# 1420 proxies left to filter
# 200.115.48.20:30758 is slow
#
# 1419 proxies left to filter
# 202.91.90.77:55278 is slow
#
# 1418 proxies left to filter
# 212.156.149.38:53100 is slow
#
# 1417 proxies left to filter
# 45.64.132.137:80 is good
# average conn time: 4.48467690652
#
# 1416 proxies left to filter
# 35.236.253.12:3128 is good
# average conn time: 4.46518178949
#
# 1415 proxies left to filter
# 62.234.27.103:1080 is slow
#
# 1414 proxies left to filter
# 62.74.99.97:8080 is slow
#
# 1413 proxies left to filter
# 96.9.74.160:39305 is slow
#
# 1412 proxies left to filter
# 203.142.74.171:8888 is slow
#
# 1411 proxies left to filter
# 91.89.29.235:80 is slow
#
# 1410 proxies left to filter
# 217.182.51.229:1080 is slow
#
# 1409 proxies left to filter
# 91.192.5.73:8080 is slow
#
# 1408 proxies left to filter
# 202.49.183.168:40689 is bad
#
# 1407 proxies left to filter
# 89.39.108.202:47283 is good
# average conn time: 4.44993851898
#
# 1406 proxies left to filter
# 202.153.226.10:53281 is good
# average conn time: 4.48320116331
#
# 1405 proxies left to filter
# 36.67.237.146:3128 is good
# average conn time: 4.50904975556
#
# 1404 proxies left to filter
# 50.239.245.110:80 is slow
#
# 1403 proxies left to filter
# 36.255.189.38:8080 is slow
#
# 1402 proxies left to filter
# 89.212.180.104:8080 is bad
#
# 1401 proxies left to filter
# 37.59.35.174:8080 is slow
#
# 1400 proxies left to filter
# 36.89.89.239:50472 is good
# average conn time: 4.51176334197
#
# 1399 proxies left to filter
# 41.60.236.185:8080 is slow
#
# 1398 proxies left to filter
# 24.226.159.195:43987 is slow
#
# 1397 proxies left to filter
# 202.56.186.146:80 is slow
#
# 1396 proxies left to filter
# 223.96.95.229:3128 is slow
#
# 1395 proxies left to filter
# 203.82.45.161:8090 is good
# average conn time: 4.52206516157
#
# 1394 proxies left to filter
# 221.6.32.214:41816 is slow
#
# 1393 proxies left to filter
# 27.131.7.162:53281 is slow
#
# 1392 proxies left to filter
# 202.125.74.6:32403 is good
# average conn time: 4.51936624801
#
# 1391 proxies left to filter
# 91.226.140.71:33199 is bad
#
# 1390 proxies left to filter
# 41.33.22.186:8080 is good
# average conn time: 4.53364751556
#
# 1389 proxies left to filter
# 31.148.22.110:57812 is good
# average conn time: 4.52606016047
#
# 1388 proxies left to filter
# 223.130.16.66:8080 is good
# average conn time: 4.52255243868
#
# 1387 proxies left to filter
# 80.251.48.215:45157 is bad
#
# 1386 proxies left to filter
# 201.20.89.126:8080 is good
# average conn time: 4.52303355264
#
# 1385 proxies left to filter
# 45.227.211.250:8080 is good
# average conn time: 4.5153374789
#
# 1384 proxies left to filter
# 37.58.160.75:80 is slow
#
# 1383 proxies left to filter
# 36.66.121.111:41608 is bad
#
# 1382 proxies left to filter
# 206.81.11.75:80 is slow
#
# 1381 proxies left to filter
# 27.147.180.93:8080 is good
# average conn time: 4.50611326747
#
# 1380 proxies left to filter
# 45.32.63.123:3128 is good
# average conn time: 4.49150623473
#
# 1379 proxies left to filter
# 81.93.78.162:49739 is good
# average conn time: 4.47743144434
#
# 1378 proxies left to filter
# 36.66.211.81:52724 is slow
#
# 1377 proxies left to filter
# 94.242.58.142:1448 is good
# average conn time: 4.46626538979
#
# 1376 proxies left to filter
# 41.190.95.92:47720 is slow
#
# 1375 proxies left to filter
# 36.91.203.207:8080 is good
# average conn time: 4.47868009113
#
# 1374 proxies left to filter
# 36.90.97.75:8080 is good
# average conn time: 4.51366681223
#
# 1373 proxies left to filter
# 51.77.211.175:3128 is slow
#
# 1372 proxies left to filter
# 41.243.7.251:43245 is slow
#
# 1371 proxies left to filter
# 80.211.234.18:80 is slow
#
# 1370 proxies left to filter
# 54.39.102.232:80 is good
# average conn time: 4.51404454904
#
# 1369 proxies left to filter
# 212.8.249.113:3128 is good
# average conn time: 4.49884799534
#
# 1368 proxies left to filter
# 27.147.236.140:63141 is slow
#
# 1367 proxies left to filter
# 83.150.10.201:50886 is slow
#
# 1366 proxies left to filter
# 60.10.2.51:3128 is slow
#
# 1365 proxies left to filter
# 79.134.4.188:60952 is bad
#
# 1364 proxies left to filter
# 213.6.166.166:8080 is slow
#
# 1363 proxies left to filter
# 206.189.81.146:31330 is good
# average conn time: 4.48911347614
#
# 1362 proxies left to filter
# 221.6.32.206:41816 is slow
#
# 1361 proxies left to filter
# 35.221.38.90:80 is good
# average conn time: 4.47140761522
#
# 1360 proxies left to filter
# 45.70.194.242:8080 is good
# average conn time: 4.47092584245
#
# 1359 proxies left to filter
# 36.89.242.130:49517 is slow
#
# 1358 proxies left to filter
# 83.103.212.159:44800 is bad
#
# 1357 proxies left to filter
# 93.171.27.99:53281 is good
# average conn time: 4.46956473286
#
# 1356 proxies left to filter
# 41.170.83.205:33925 is bad
#
# 1355 proxies left to filter
# 74.85.156.70:8888 is good
# average conn time: 4.46193400013
#
# 1354 proxies left to filter
# 61.247.184.186:63141 is slow
#
# 1353 proxies left to filter
# 213.58.202.70:54214 is bad
#
# 1352 proxies left to filter
# 45.227.115.181:53281 is good
# average conn time: 4.45590835659
#
# 1351 proxies left to filter
# 27.203.219.255:8060 is slow
#
# 1350 proxies left to filter
# 54.214.255.114:80 is slow
#
# 1349 proxies left to filter
# 58.245.202.11:8080 is slow
#
# 1348 proxies left to filter
# 37.59.32.112:8080 is slow
#
# 1347 proxies left to filter
# 95.158.40.131:51739 is bad
#
# 1346 proxies left to filter
# 62.182.114.164:41766 is bad
#
# 1345 proxies left to filter
# 45.224.86.78:56075 is bad
#
# 1344 proxies left to filter
# 212.129.1.240:54321 is slow
#
# 1343 proxies left to filter
# ...
# 94.199.96.87:32454 is good
# average conn time: 4.64467586963
#
# 249 proxies left to filter
# 58.187.77.36:32675 is bad
#
# 248 proxies left to filter
# 79.190.145.143:3128 is slow
#
# 247 proxies left to filter
# 213.145.137.102:39364 is slow
#
# 246 proxies left to filter
# 99.79.99.135:8080 is slow
#
# 245 proxies left to filter
# 41.60.228.187:41125 is good
# average conn time: 4.64177927858
#
# 244 proxies left to filter
# 203.81.93.193:8080 is slow
#
# 243 proxies left to filter
# 54.39.209.44:3128 is slow
#
# 242 proxies left to filter
# 85.214.209.9:3128 is slow
#
# 241 proxies left to filter
# 68.183.89.240:3128 is good
# average conn time: 4.63791007738
#
# 240 proxies left to filter
# 80.211.36.44:3128 is slow
#
# 239 proxies left to filter
# 54.39.147.31:80 is slow
#
# 238 proxies left to filter
# 36.91.169.119:8080 is good
# average conn time: 4.64690069679
#
# 237 proxies left to filter
# 217.182.51.230:1080 is slow
#
# 236 proxies left to filter
# 201.62.125.229:8080 is good
# average conn time: 4.64507189238
#
# 235 proxies left to filter
# 3.212.137.96:8080 is slow
#
# 234 proxies left to filter
# 41.57.125.110:8080 is good
# average conn time: 4.64498220154
#
# 233 proxies left to filter
# 51.38.162.2:32231 is slow
#
# 232 proxies left to filter
# 85.90.166.35:55135 is bad
#
# 231 proxies left to filter
# 202.93.240.18:53281 is slow
#
# 230 proxies left to filter
# 202.166.211.48:45084 is slow
#
# 229 proxies left to filter
# 93.99.6.158:55555 is slow
#
# 228 proxies left to filter
# 94.180.108.102:54022 is bad
#
# 227 proxies left to filter
# 62.244.156.2:35540 is slow
#
# 226 proxies left to filter
# 202.60.227.209:50413 is bad
#
# 225 proxies left to filter
# 77.120.40.54:43889 is slow
#
# 224 proxies left to filter
# 95.47.116.73:63141 is good
# average conn time: 4.64082980595
#
# 223 proxies left to filter
# 94.23.196.68:3128 is slow
#
# 222 proxies left to filter
# 206.189.82.93:31330 is slow
#
# 221 proxies left to filter
# 47.52.231.140:8080 is slow
#
# 220 proxies left to filter
# 78.140.56.194:8080 is good
# average conn time: 4.6417164671
#
# 219 proxies left to filter
# 43.228.221.171:61267 is slow
#
# 218 proxies left to filter
# 45.113.66.41:8080 is slow
#
# 217 proxies left to filter
# 202.93.229.98:8080 is good
# average conn time: 4.64801198055
#
# 216 proxies left to filter
# 36.78.222.198:8080 is good
# average conn time: 4.65742979209
#
# 215 proxies left to filter
# 92.242.254.99:8080 is slow
#
# 214 proxies left to filter
# 59.108.125.241:8080 is slow
#
# 213 proxies left to filter
# 212.237.56.83:80 is good
# average conn time: 4.65263197386
#
# 212 proxies left to filter
# 94.187.213.251:44701 is slow
#
# 211 proxies left to filter
# 27.147.225.2:36745 is slow
#
# 210 proxies left to filter
# 27.203.213.130:8060 is slow
#
# 209 proxies left to filter
# 41.78.247.252:8080 is good
# average conn time: 4.65174962159
#
# 208 proxies left to filter
# 41.217.219.53:55175 is slow
#
# 207 proxies left to filter
# 79.175.57.77:55477 is slow
#
# 206 proxies left to filter
# 85.9.131.73:8080 is good
# average conn time: 4.65018015635
#
# 205 proxies left to filter
# 36.91.194.229:8080 is good
# average conn time: 4.6531746048
#
# 204 proxies left to filter
# 54.205.117.212:80 is slow
#
# 203 proxies left to filter
# 66.82.22.79:80 is slow
#
# 202 proxies left to filter
# 35.182.54.53:8080 is slow
#
# 201 proxies left to filter
# 223.93.145.186:8060 is slow
#
# 200 proxies left to filter
# 208.67.183.240:80 is slow
#
# 199 proxies left to filter
# 31.211.130.169:23500 is bad
#
# 198 proxies left to filter
# 45.121.43.14:8080 is slow
#
# 197 proxies left to filter
# 213.6.156.113:8080 is slow
#
# 196 proxies left to filter
# 91.214.61.221:49567 is good
# average conn time: 4.64866415607
#
# 195 proxies left to filter
# 35.247.241.28:80 is good
# average conn time: 4.64264627455
#
# 194 proxies left to filter
# 45.117.77.41:80 is slow
#
# 193 proxies left to filter
# 47.52.153.167:443 is slow
#
# 192 proxies left to filter
# 45.76.111.184:443 is slow
#
# 191 proxies left to filter
# 59.152.96.138:8080 is slow
#
# 190 proxies left to filter
# 202.138.249.244:39896 is slow
#
# 189 proxies left to filter
# 202.52.11.206:35744 is slow
#
# 188 proxies left to filter
# 34.235.25.119:3128 is slow
#
# 187 proxies left to filter
# 221.2.174.3:8060 is slow
#
# 186 proxies left to filter
# 85.237.57.198:47240 is good
# average conn time: 4.63983531682
#
# 185 proxies left to filter
# 88.87.79.20:8080 is slow
#
# 184 proxies left to filter
# 31.200.229.104:56471 is slow
#
# 183 proxies left to filter
# 35.234.10.46:8080 is slow
#
# 182 proxies left to filter
# 213.32.254.89:52645 is slow
#
# 181 proxies left to filter
# 52.60.145.10:8080 is slow
#
# 180 proxies left to filter
# 95.80.98.41:8080 is slow
#
# 179 proxies left to filter
# 41.160.136.66:8080 is bad
#
# 178 proxies left to filter
# 222.124.173.146:53281 is good
# average conn time: 4.64681958956
#
# 177 proxies left to filter
# 36.89.181.155:60165 is good
# average conn time: 4.65221009779
#
# 176 proxies left to filter
# 213.32.58.10:80 is slow
#
# 175 proxies left to filter
# 202.70.84.194:8080 is slow
#
# 174 proxies left to filter
# 37.77.135.126:44497 is good
# average conn time: 4.65001100908
#
# 173 proxies left to filter
# 220.247.171.138:8080 is good
# average conn time: 4.64668413816
#
# 172 proxies left to filter
# 54.190.198.139:80 is slow
#
# 171 proxies left to filter
# 213.6.144.38:8080 is slow
#
# 170 proxies left to filter
# 47.94.89.87:3128 is slow
#
# 169 proxies left to filter
# 206.221.177.135:3128 is slow
#
# 168 proxies left to filter
# 217.182.51.228:1080 is slow
#
# 167 proxies left to filter
# 88.87.81.217:33678 is slow
#
# 166 proxies left to filter
# 36.73.16.46:8080 is good
# average conn time: 4.64661628475
#
# 165 proxies left to filter
# 77.247.89.254:8080 is slow
#
# 164 proxies left to filter
# 221.2.155.35:8060 is slow
#
# 163 proxies left to filter
# 88.131.213.111:80 is slow
#
# 162 proxies left to filter
# 220.247.164.53:8080 is slow
#
# 161 proxies left to filter
# 36.89.148.47:41668 is good
# average conn time: 4.64850409696
#
# 160 proxies left to filter
# 5.128.73.158:8081 is slow
#
# 159 proxies left to filter
# 61.142.72.154:54971 is slow
#
# 158 proxies left to filter
# 27.147.167.98:60510 is good
# average conn time: 4.64637293567
#
# 157 proxies left to filter
# 95.47.136.185:51010 is bad
#
# 156 proxies left to filter
# 23.95.225.173:3128 is good
# average conn time: 4.63972952579
#
# 155 proxies left to filter
# 95.0.226.84:30439 is bad
#
# 154 proxies left to filter
# 46.201.249.7:59661 is good
# average conn time: 4.63687714702
#
# 153 proxies left to filter
# 3.19.19.238:8080 is slow
#
# 152 proxies left to filter
# 93.99.179.51:8080 is good
# average conn time: 4.63474707047
#
# 151 proxies left to filter
# 36.89.165.89:57269 is slow
#
# 150 proxies left to filter
# 36.79.202.107:8080 is good
# average conn time: 4.63860531146
#
# 149 proxies left to filter
# 212.129.1.152:54321 is slow
#
# 148 proxies left to filter
# 93.190.137.116:8080 is slow
#
# 147 proxies left to filter
# 217.73.131.219:8080 is good
# average conn time: 4.63728551757
#
# 146 proxies left to filter
# 202.62.11.106:8080 is slow
#
# 145 proxies left to filter
# 202.169.239.66:8080 is good
# average conn time: 4.63890365055
#
# 144 proxies left to filter
# 77.70.115.103:8080 is slow
#
# 143 proxies left to filter
# 202.131.234.142:43803 is slow
#
# 142 proxies left to filter
# 212.129.6.141:54321 is slow
#
# 141 proxies left to filter
# 37.99.213.212:8888 is slow
#
# 140 proxies left to filter
# 80.83.231.111:8081 is slow
#
# 139 proxies left to filter
# 89.207.111.61:41258 is good
# average conn time: 4.63977682341
#
# 138 proxies left to filter
# 77.95.96.161:80 is slow
#
# 137 proxies left to filter
# 78.189.167.147:49629 is good
# average conn time: 4.65117015141
#
# 136 proxies left to filter
# 45.228.96.34:52431 is good
# average conn time: 4.65018182046
#
# 135 proxies left to filter
# 89.29.100.225:3128 is bad
#
# 134 proxies left to filter
# 202.162.200.67:41448 is good
# average conn time: 4.64829975672
#
# 133 proxies left to filter
# 89.39.108.90:8080 is good
# average conn time: 4.64349218292
#
# 132 proxies left to filter
# 68.183.174.187:3128 is slow
#
# 131 proxies left to filter
# 93.190.139.104:8080 is slow
#
# 130 proxies left to filter
# 202.162.222.154:49659 is bad
#
# 129 proxies left to filter
# 85.117.56.3:61874 is slow
#
# 128 proxies left to filter
# 79.98.212.14:3128 is good
# average conn time: 4.64289336806
#
# 127 proxies left to filter
# 202.125.94.139:1234 is slow
#
# 126 proxies left to filter
# 202.159.40.43:3128 is slow
#
# 125 proxies left to filter
# 210.22.176.146:44870 is slow
#
# 124 proxies left to filter
# 217.23.69.146:8080 is slow
#
# 123 proxies left to filter
# 79.165.200.116:49253 is slow
#
# 122 proxies left to filter
# 62.196.125.132:39036 is slow
#
# 121 proxies left to filter
# 197.149.138.202:8080 is good
# average conn time: 4.64612128632
#
# 120 proxies left to filter
# 202.147.194.146:8080 is slow
#
# 119 proxies left to filter
# 46.40.3.115:8082 is slow
#
# 118 proxies left to filter
# 36.89.249.25:4550 is slow
#
# 117 proxies left to filter
# 200.5.203.58:52116 is slow
#
# 116 proxies left to filter
# 94.242.59.135:10010 is good
# average conn time: 4.64061402971
#
# 115 proxies left to filter
# 36.89.180.35:35748 is slow
#
# 114 proxies left to filter
# 202.166.198.118:8080 is slow
#
# 113 proxies left to filter
# 61.7.174.209:8080 is slow
#
# 112 proxies left to filter
# 217.182.51.225:8080 is slow
#
# 111 proxies left to filter
# 36.72.111.89:80 is good
# average conn time: 4.63765026958
#
# 110 proxies left to filter
# 90.157.19.31:8081 is slow
#
# 109 proxies left to filter
# 95.129.97.146:33434 is slow
#
# 108 proxies left to filter
# 89.111.105.87:41258 is good
# average conn time: 4.6424965533
#
# 107 proxies left to filter
# 82.114.78.82:45449 is slow
#
# 106 proxies left to filter
# 50.239.245.104:80 is slow
#
# 105 proxies left to filter
# 41.191.223.144:8080 is slow
#
# 104 proxies left to filter
# 36.255.87.231:84 is slow
#
# 103 proxies left to filter
# 201.77.131.100:3128 is good
# average conn time: 4.63897850018
#
# 102 proxies left to filter
# 78.10.44.10:8080 is good
# average conn time: 4.64050912744
#
# 101 proxies left to filter
# 212.129.2.188:54321 is slow
#
# 100 proxies left to filter
# 95.134.195.78:38173 is bad
#
# 99 proxies left to filter
# 60.211.218.78:53281 is slow
#
# 98 proxies left to filter
# 45.235.87.158:8080 is good
# average conn time: 4.6398043689
#
# 97 proxies left to filter
# 89.148.195.90:45820 is bad
#
# 96 proxies left to filter
# 203.170.69.234:8080 is slow
#
# 95 proxies left to filter
# 5.189.133.231:80 is slow
#
# 94 proxies left to filter
# 50.244.252.166:8081 is good
# average conn time: 4.63513046597
#
# 93 proxies left to filter
# 80.94.229.172:3128 is good
# average conn time: 4.63686196447
#
# 92 proxies left to filter
# 202.21.110.38:57526 is good
# average conn time: 4.6389099457
#
# 91 proxies left to filter
# 80.211.31.89:8888 is slow
#
# 90 proxies left to filter
# 79.106.224.212:8080 is good
# average conn time: 4.64321170871
#
# 89 proxies left to filter
# 41.65.146.248:8080 is slow
#
# 88 proxies left to filter
# 36.255.87.231:83 is good
# average conn time: 4.64019451956
#
# 87 proxies left to filter
# 36.255.87.241:83 is bad
#
# 86 proxies left to filter
# 212.42.104.74:3128 is bad
#
# 85 proxies left to filter
# 36.89.189.239:53281 is bad
#
# 84 proxies left to filter
# 78.187.159.161:8080 is good
# average conn time: 4.64662015718
#
# 83 proxies left to filter
# 78.187.50.200:58763 is slow
#
# 82 proxies left to filter
# 27.203.241.98:8060 is slow
#
# 81 proxies left to filter
# 46.44.39.208:8081 is slow
#
# 80 proxies left to filter
# 94.247.122.19:3128 is good
# average conn time: 4.64523368813
#
# 79 proxies left to filter
# 91.237.123.201:41258 is slow
#
# 78 proxies left to filter
# 222.124.221.179:53281 is good
# average conn time: 4.64275672916
#
# 77 proxies left to filter
# 45.231.30.225:8080 is slow
#
# 76 proxies left to filter
# 213.6.49.114:54565 is bad
#
# 75 proxies left to filter
# 37.187.113.222:80 is slow
#
# 74 proxies left to filter
# 83.167.119.230:63141 is good
# average conn time: 4.63774627317
#
# 73 proxies left to filter
# 62.249.140.198:39780 is bad
#
# 72 proxies left to filter
# 46.4.175.196:3128 is slow
#
# 71 proxies left to filter
# 35.247.224.186:80 is slow
#
# 70 proxies left to filter
# 95.31.4.125:53025 is slow
#
# 69 proxies left to filter
# 95.31.130.96:56771 is bad
#
# 68 proxies left to filter
# 80.240.252.237:56964 is slow
#
# 67 proxies left to filter
# 46.33.253.29:55574 is slow
#
# 66 proxies left to filter
# 35.200.132.30:3128 is slow
#
# 65 proxies left to filter
# 88.84.209.69:30819 is slow
#
# 64 proxies left to filter
# 36.89.180.25:61087 is good
# average conn time: 4.6360902434
#
# 63 proxies left to filter
# 66.70.167.117:3128 is slow
#
# 62 proxies left to filter
# 68.183.231.47:8080 is bad
#
# 61 proxies left to filter
# 45.55.45.80:80 is slow
#
# 60 proxies left to filter
# 218.60.8.98:3129 is bad
#
# 59 proxies left to filter
# 36.67.89.179:65205 is slow
#
# 58 proxies left to filter
# 36.65.208.70:8080 is slow
#
# 57 proxies left to filter
# 45.116.106.109:8080 is slow
#
# 56 proxies left to filter
# 220.247.173.154:53281 is good
# average conn time: 4.63497528008
#
# 55 proxies left to filter
# 206.221.177.134:3128 is slow
#
# 54 proxies left to filter
# 31.214.153.86:8080 is good
# average conn time: 4.6330603618
#
# 53 proxies left to filter
# 35.235.75.244:3128 is good
# average conn time: 4.62863975745
#
# 52 proxies left to filter
# 27.123.223.47:8080 is slow
#
# 51 proxies left to filter
# 36.89.182.189:61482 is slow
#
# 50 proxies left to filter
# 27.145.100.22:8080 is bad
#
# 49 proxies left to filter
# 213.100.168.84:34173 is good
# average conn time: 4.62604383965
#
# 48 proxies left to filter
# 217.61.15.193:8080 is slow
#
# 47 proxies left to filter
# 80.179.157.80:80 is bad
#
# 46 proxies left to filter
# 47.74.46.193:3128 is slow
#
# 45 proxies left to filter
# 54.193.23.30:80 is slow
#
# 44 proxies left to filter
# 36.255.87.243:83 is slow
#
# 43 proxies left to filter
# 43.227.129.193:83 is good
# average conn time: 4.62844103428
#
# 42 proxies left to filter
# 36.66.220.173:53850 is good
# average conn time: 4.6277844454
#
# 41 proxies left to filter
# 45.123.26.146:53281 is slow
#
# 40 proxies left to filter
# 36.67.93.220:80 is slow
#
# 39 proxies left to filter
# 89.29.100.210:3128 is bad
#
# 38 proxies left to filter
# 49.140.236.210:8118 is slow
#
# 37 proxies left to filter
# 27.111.38.235:39850 is slow
#
# 36 proxies left to filter
# 95.67.45.234:8080 is good
# average conn time: 4.62276087064
#
# 35 proxies left to filter
# 36.37.114.34:41454 is bad
#
# 34 proxies left to filter
# 91.202.240.208:51678 is good
# average conn time: 4.62433332525
#
# 33 proxies left to filter
# 207.180.226.111:3128 is slow
#
# 32 proxies left to filter
# 45.125.66.156:54321 is slow
#
# 31 proxies left to filter
# 54.37.74.251:80 is slow
#
# 30 proxies left to filter
# 203.81.76.188:8080 is good
# average conn time: 4.62263556419
#
# 29 proxies left to filter
# 68.183.41.217:8080 is good
# average conn time: 4.61710027568
#
# 28 proxies left to filter
# 92.255.182.248:56169 is good
# average conn time: 4.61881755507
#
# 27 proxies left to filter
# 36.66.83.111:8080 is slow
#
# 26 proxies left to filter
# 206.253.165.161:80 is slow
#
# 25 proxies left to filter
# 36.67.139.27:50466 is slow
#
# 24 proxies left to filter
# 91.205.131.110:32518 is bad
#
# 23 proxies left to filter
# 217.21.124.72:80 is good
# average conn time: 4.62034311295
#
# 22 proxies left to filter
# 85.187.21.78:52007 is slow
#
# 21 proxies left to filter
# 213.154.20.240:45931 is bad
#
# 20 proxies left to filter
# 212.46.214.38:32075 is slow
#
# 19 proxies left to filter
# 216.10.242.231:80 is slow
#
# 18 proxies left to filter
# 92.245.114.118:35866 is good
# average conn time: 4.61958925426
#
# 17 proxies left to filter
# 212.8.249.110:3128 is good
# average conn time: 4.61375173949
#
# 16 proxies left to filter
# 223.19.212.30:8197 is slow
#
# 15 proxies left to filter
# 61.128.208.94:3128 is slow
#
# 14 proxies left to filter
# 46.198.141.82:31870 is good
# average conn time: 4.61550863825
#
# 13 proxies left to filter
# 27.147.216.35:48194 is bad
#
# 12 proxies left to filter
# 202.57.37.197:43094 is good
# average conn time: 4.61518461751
#
# 11 proxies left to filter
# 62.152.85.158:31156 is bad
#
# 10 proxies left to filter
# 46.101.37.48:3128 is slow
#
# 9 proxies left to filter
# 5.9.233.85:8080 is slow
#
# 8 proxies left to filter
# 46.52.232.183:41858 is slow
#
# 7 proxies left to filter
# 77.79.187.74:8080 is good
# average conn time: 4.62251566937
#
# 6 proxies left to filter
# 41.169.15.99:48736 is slow
#
# 5 proxies left to filter
# 45.226.50.253:8080 is slow
#
# 4 proxies left to filter
# 203.192.193.225:8080 is good
# average conn time: 4.61996970775
#
# 3 proxies left to filter
# 93.190.137.108:8080 is slow
#
# 2 proxies left to filter
# 202.54.169.235:8080 is slow
#
# 1 proxies left to filter
# 212.112.116.194:3128 is slow
#
# average proxy time:4.61996970775

# %% [markdown]
# # Filter the Http proxies

# %%
url = 'https://www.proxy-list.download/HTTP'
filterProxys(url)
# Out:
# No proxies to text

# %% [markdown]
# # Overwrite the source text file with partially filtered or empty ip list

# %%
# overwrite the existing source of https proxy data with the filtered data
with open('proxyLists/https_proxys_US_part_2.txt', "w") as output:
    for line in testProxies['https']:
        output.write("%s\n" % line)

# %%
# overwrite the existing source of http proxy data with the filtered data
with open('proxyLists/http_proxys_US_part_2.txt', "w") as output:
    for line in testProxies['http']:
        output.write("%s\n" % line)

# %% [markdown]
# # Get all proxys that had connections times less than one second

# %%
df = pd.DataFrame(goodProxy['https'])
fast_proxies_https = list(df['proxy'][df['time']<1])

# %%
df = pd.DataFrame(goodProxy['http'])
fast_proxies_http = list(df['proxy'][df['time']<1])

# %% [markdown]
# # Import the single filtered files of proxys that had connections times less than one second and combine with the new filtered proxys

# %%
# Import
try:
    existing_https_proxies = list(pd.read_csv('../filtered_https_proxys_US.txt', header = None)[0])
except: #If the file is empty
    existing_https_proxies = []
try:
    existing_http_proxies = list(pd.read_csv('../filtered_http_proxys_US.txt', header = None)[0])
except: #If the file is empty
    existing_http_proxies = []

# %%
# add the new proxys to the existing ones if they are not already there
[existing_https_proxies.append(x) 
 for x in fast_proxies_https 
 if x not in existing_https_proxies]

[existing_http_proxies.append(x) 
 for x in fast_proxies_http 
 if x not in existing_http_proxies]
# Out:
# []

# %% [markdown]
# # Rewrite the final proxys text file with the new and old filtered proxies

# %%
#append filtered http proxys to existing .txt file
with open('../filtered_http_proxys_US.txt', "w") as output:
    for line in existing_http_proxies:
        output.write("%s\n" % line)

# %%
# append filtered https proxies to existing text file
with open('../filtered_https_proxys_US.txt', "w") as output:
    for line in existing_https_proxies:
        output.write("%s\n" % line)
