# %% [markdown]
# # Ref: https://codelike.pro/create-a-crawler-with-rotating-ip-proxy-in-python/

# %% [markdown]
# # Import Libraries

# %%
# Get the text data from the first job posting
import pandas as pd
import requests # For website connections
from bs4 import BeautifulSoup # For HTML parsing
import time
from fake_useragent import UserAgent
import random

# %% [markdown]
# # Import the Data

# %%
try:
    Https_txt_file = 'proxyLists/https_proxys_US_part_0.txt'
    #Download New HTTPS IPs .txt file from https://www.proxy-list.download/HTTPS
    https_proxys = pd.read_csv(Https_txt_file, sep=" ", header=None)
    #Convert to array
    https_proxys = https_proxys[0].values
    #Convert to list
    https_proxys = list(https_proxys)
except:
    print('There are no https proxies to import')

try:
    Http_txt_file = 'proxyLists/http_proxys_US_part_0.txt'
    #Download New HTTPS IPs .txt file from https://www.proxy-list.download/HTTP
    http_proxys = pd.read_csv(Http_txt_file, sep=" ", header=None)
    #Convert to array
    http_proxys = http_proxys[0].values
    #Convert to list
    http_proxys = list(http_proxys)
except:
    print('There are no http proxies to import')

# %%
# Make a dictionary for the proxies to test
testProxies = {'https':https_proxys,'http':http_proxys}

# %%
# Retrieve a random user-agent
header = {}
def randHeader():
    ua = UserAgent()
    header['User-Agent'] = ua.random

# %%
# Retrieve a random index for the https proxy
def randomIndex(conn_type):
    num = random.randint(0, len(testProxies[conn_type]) - 1)
    return num

# %%
proxyDict = {}
def randProx(conn_type):
    # Choose a single random proxy to use
    proxy_index = randomIndex(conn_type)
    proxy = testProxies[conn_type][proxy_index]
    proxyDict[conn_type] = conn_type +'://'+ proxy
    return proxy_index

# %%
# Initialize Dictionary for good proxies 
good_http_proxy = []
good_https_proxy = []
conn_time_http = []
conn_time_https = []
goodProxy = {'https':{'proxy':good_https_proxy,'time':conn_time_https},
             'http':{'proxy':good_http_proxy,'time':conn_time_http}}

# %%
def filterProxys(url):
    timer = 0
    count = 0
    if url[0:5] == 'http:':
        conn_type = 'http'
        
    elif url[0:5] == 'https':
        conn_type = 'https'

    total_proxies = len(testProxies[conn_type])
    for n in range(len(testProxies[conn_type])):
        time.sleep(1)
        print(str(total_proxies-n)+' proxies left to filter')
            
        try:
            # Choose a random header
            randHeader()
            
        except:
            # Sometimes the header reassignment function returns an error
            pass
            
        # Choose a random proxy
        proxy_index = randProx(conn_type)

        try:
            # Try to connect to the url
            t1 = time.time()
            soup = requests.get(url,headers=header,proxies=proxyDict,timeout=5)
            t2 = time.time()
            t = t2-t1
                
            if  str(soup) == '<Response [200]>': # the connection is successful when <Response [200]> is returned
                print(str(testProxies[conn_type][proxy_index])+' is good')
                del testProxies[conn_type][proxy_index]
                timer += t
                count += 1
                print('average conn time: '+str(timer/count)+'\n')
                #Add to the good proxy and its connection time
                goodProxy[conn_type]['proxy'].append(proxyDict[conn_type])
                goodProxy[conn_type]['time'].append(t)
                    
            elif str(soup) != '<Response [200]>': #The connection was bad
                print(str(testProxies[conn_type][proxy_index])+' is bad'+'\n')
                del testProxies[conn_type][proxy_index]
                    
                    
        except: # The connection took too long 
            print(str(testProxies[conn_type][proxy_index])+' is slow'+'\n')
            del testProxies[conn_type][proxy_index]
    try:
        print('average proxy time:'+str(timer/count))
    except:
        print('No proxies to text')

# %% [markdown]
# # Filter the Https proxies

# %%
url = 'https://www.proxy-list.download/HTTPS'
filterProxys(url)
# Out:
# 2061 proxies left to filter
# 94.242.59.135:10010 is good
# average conn time: 0.985936880112
#
# 2060 proxies left to filter
# 128.14.134.174:1080 is slow
#
# 2059 proxies left to filter
# 103.94.121.27:33546 is slow
#
# 2058 proxies left to filter
# 34.227.77.200:3128 is slow
#
# 2057 proxies left to filter
# 134.119.205.242:8080 is slow
#
# 2056 proxies left to filter
# 114.32.10.182:80 is slow
#
# 2055 proxies left to filter
# 117.255.220.58:8080 is slow
#
# 2054 proxies left to filter
# 134.175.247.17:1080 is slow
#
# 2053 proxies left to filter
# 116.114.19.211:443 is slow
#
# 2052 proxies left to filter
# 118.175.244.21:8080 is slow
#
# 2051 proxies left to filter
# 118.175.93.107:38176 is good
# average conn time: 3.19144594669
#
# 2050 proxies left to filter
# 134.119.207.13:8080 is slow
#
# 2049 proxies left to filter
# 138.201.223.250:31288 is slow
#
# 2048 proxies left to filter
# 115.124.75.228:3128 is good
# average conn time: 3.83550699552
#
# 2047 proxies left to filter
# 121.58.231.75:3128 is slow
#
# 2046 proxies left to filter
# 115.127.92.234:41258 is slow
#
# 2045 proxies left to filter
# 114.129.9.57:8080 is good
# average conn time: 4.47023922205
#
# 2044 proxies left to filter
# 103.12.164.38:80 is slow
#
# 2043 proxies left to filter
# 124.41.211.239:23500 is bad
#
# 2042 proxies left to filter
# 148.70.214.225:1080 is slow
#
# 2041 proxies left to filter
# 115.68.14.247:3128 is slow
#
# 2040 proxies left to filter
# 125.24.2.167:8080 is slow
#
# 2039 proxies left to filter
# 142.93.52.63:8080 is good
# average conn time: 3.62810878754
#
# 2038 proxies left to filter
# 116.0.5.66:33006 is bad
#
# 2037 proxies left to filter
# 145.239.169.43:8080 is slow
#
# 2036 proxies left to filter
# 117.196.230.214:8080 is good
# average conn time: 4.14298780759
#
# 2035 proxies left to filter
# 134.119.214.203:1080 is slow
#
# 2034 proxies left to filter
# 1.20.100.168:34135 is bad
#
# 2033 proxies left to filter
# 118.89.61.194:1080 is slow
#
# 2032 proxies left to filter
# 13.234.169.74:3128 is slow
#
# 2031 proxies left to filter
# 103.59.178.252:55923 is good
# average conn time: 3.94852910723
#
# 2030 proxies left to filter
# 1.20.103.135:31128 is slow
#
# 2029 proxies left to filter
# 124.158.175.170:8080 is slow
#
# 2028 proxies left to filter
# 118.174.232.92:45759 is slow
#
# 2027 proxies left to filter
# 132.232.252.120:1080 is slow
#
# 2026 proxies left to filter
# 122.138.51.64:8080 is slow
#
# 2025 proxies left to filter
# 109.123.4.12:3128 is good
# average conn time: 3.6780821085
#
# 2024 proxies left to filter
# 134.209.170.62:8080 is slow
#
# 2023 proxies left to filter
# 14.207.24.119:8080 is good
# average conn time: 3.49952732192
#
# 2022 proxies left to filter
# 124.158.168.22:8080 is good
# average conn time: 3.96907680035
#
# 2021 proxies left to filter
# 1.20.102.54:8080 is good
# average conn time: 4.06374900991
#
# 2020 proxies left to filter
# 103.198.167.139:41319 is bad
#
# 2019 proxies left to filter
# 121.101.131.93:8080 is slow
#
# 2018 proxies left to filter
# 122.154.97.188:8080 is bad
#
# 2017 proxies left to filter
# 118.175.175.236:8080 is slow
#
# 2016 proxies left to filter
# 103.73.225.193:53889 is good
# average conn time: 4.25761874517
#
# 2015 proxies left to filter
# 145.239.169.44:1080 is slow
#
# 2014 proxies left to filter
# 134.119.188.155:1080 is good
# average conn time: 4.03182862355
#
# 2013 proxies left to filter
# 103.106.237.103:30513 is slow
#
# 2012 proxies left to filter
# 103.94.6.69:3128 is good
# average conn time: 3.9000893661
#
# 2011 proxies left to filter
# 118.21.57.94:80 is slow
#
# 2010 proxies left to filter
# 95.87.220.19:15600 is good
# average conn time: 3.72793227832
#
# 2009 proxies left to filter
# 106.75.211.89:8080 is slow
#
# 2008 proxies left to filter
# 117.196.238.82:47848 is slow
#
# 2007 proxies left to filter
# 141.0.179.221:53281 is bad
#
# 2006 proxies left to filter
# 153.127.78.219:3128 is good
# average conn time: 3.60095438361
#
# 2005 proxies left to filter
# 116.197.155.214:35634 is bad
#
# 2004 proxies left to filter
# 124.202.166.171:82 is slow
#
# 2003 proxies left to filter
# 125.27.126.3:8080 is slow
#
# 2002 proxies left to filter
# 148.70.222.115:1080 is slow
#
# 2001 proxies left to filter
# 14.139.120.232:80 is slow
#
# 2000 proxies left to filter
# 114.113.222.144:80 is slow
#
# 1999 proxies left to filter
# 134.119.205.164:1080 is good
# average conn time: 3.51770518808
#
# 1998 proxies left to filter
# 103.194.192.80:37227 is slow
#
# 1997 proxies left to filter
# 103.16.61.134:8080 is slow
#
# 1996 proxies left to filter
# 139.228.49.245:8080 is slow
#
# 1995 proxies left to filter
# 132.232.229.209:1080 is slow
#
# 1994 proxies left to filter
# 123.207.226.203:1080 is slow
#
# 1993 proxies left to filter
# 148.70.203.210:8888 is slow
#
# 1992 proxies left to filter
# 109.188.132.86:8080 is slow
#
# 1991 proxies left to filter
# 134.119.222.254:1080 is slow
#
# 1990 proxies left to filter
# 118.69.205.208:4624 is slow
#
# 1989 proxies left to filter
# 123.200.5.6:8080 is good
# average conn time: 3.57837396198
#
# 1988 proxies left to filter
# 103.217.72.211:3128 is slow
#
# 1987 proxies left to filter
# 134.209.64.132:8118 is slow
#
# 1986 proxies left to filter
# 103.84.245.61:8080 is bad
#
# 1985 proxies left to filter
# 103.66.178.43:65205 is slow
#
# 1984 proxies left to filter
# 128.199.101.175:8181 is slow
#
# 1983 proxies left to filter
# 150.95.151.68:8286 is good
# average conn time: 3.74659518192
#
# 1982 proxies left to filter
# 109.226.213.125:53666 is slow
#
# 1981 proxies left to filter
# 138.94.162.120:20183 is good
# average conn time: 3.78207197189
#
# 1980 proxies left to filter
# 148.243.240.155:30304 is slow
#
# 1979 proxies left to filter
# 138.0.188.101:8080 is good
# average conn time: 3.95810478074
#
# 1978 proxies left to filter
# 148.70.80.21:1080 is slow
#
# 1977 proxies left to filter
# 1.10.188.140:43327 is slow
#
# 1976 proxies left to filter
# 119.180.169.247:8060 is slow
#
# 1975 proxies left to filter
# 104.245.228.65:8080 is good
# average conn time: 3.85791502216
#
# 1974 proxies left to filter
# 151.106.10.56:8080 is slow
#
# 1973 proxies left to filter
# 110.78.155.98:8080 is slow
#
# 1972 proxies left to filter
# 67.205.151.211:3128 is good
# average conn time: 3.70029588368
#
# 1971 proxies left to filter
# 134.119.188.147:1080 is slow
#
# 1970 proxies left to filter
# 1.10.189.68:60400 is slow
#
# 1969 proxies left to filter
# 134.119.205.254:8080 is slow
#
# 1968 proxies left to filter
# 152.136.73.48:1080 is slow
#
# 1967 proxies left to filter
# 105.112.84.91:8080 is good
# average conn time: 3.78314517935
#
# 1966 proxies left to filter
# 14.207.147.144:8213 is good
# average conn time: 3.70757069588
#
# 1965 proxies left to filter
# 125.32.175.5:8080 is slow
#
# 1964 proxies left to filter
# 110.74.195.54:60132 is good
# average conn time: 3.82446270723
#
# 1963 proxies left to filter
# 103.194.192.37:44931 is good
# average conn time: 3.9783553459
#
# 1962 proxies left to filter
# 118.89.23.6:1080 is slow
#
# 1961 proxies left to filter
# 118.172.201.141:47923 is slow
#
# 1960 proxies left to filter
# 103.116.48.97:8080 is good
# average conn time: 3.95141911507
#
# 1959 proxies left to filter
# 109.87.45.248:55590 is bad
#
# 1958 proxies left to filter
# 14.140.9.166:8080 is good
# average conn time: 4.109964938
#
# 1957 proxies left to filter
# 108.61.220.77:3128 is slow
#
# 1956 proxies left to filter
# 134.209.123.111:8090 is slow
#
# 1955 proxies left to filter
# 118.172.176.61:8080 is slow
#
# 1954 proxies left to filter
# 103.198.137.97:44533 is bad
#
# 1953 proxies left to filter
# 139.0.6.36:63141 is good
# average conn time: 4.18449734052
#
# 1952 proxies left to filter
# 138.36.106.251:42651 is slow
#
# 1951 proxies left to filter
# 167.99.6.105:8080 is good
# average conn time: 4.06005649413
#
# 1950 proxies left to filter
# 118.175.93.73:59897 is slow
#
# 1949 proxies left to filter
# 103.194.249.251:40657 is bad
#
# 1948 proxies left to filter
# 103.70.204.1:46351 is slow
#
# 1947 proxies left to filter
# 104.244.75.218:8080 is slow
#
# 1946 proxies left to filter
# 167.114.255.85:3128 is good
# average conn time: 3.95837984979
#
# 1945 proxies left to filter
# 125.25.57.40:8080 is slow
#
# 1944 proxies left to filter
# 1.34.120.197:51873 is slow
#
# 1943 proxies left to filter
# 118.172.51.170:38070 is good
# average conn time: 4.05503207265
#
# 1942 proxies left to filter
# 123.108.200.110:82 is slow
#
# 1941 proxies left to filter
# 111.231.217.1:1080 is slow
#
# 1940 proxies left to filter
# 111.231.117.150:1080 is slow
#
# 1939 proxies left to filter
# 144.217.229.152:1080 is slow
#
# 1938 proxies left to filter
# 142.234.201.107:80 is slow
#
# 1937 proxies left to filter
# 1.10.189.20:43754 is good
# average conn time: 4.01016081081
# 1936 proxies left to filter
# 101.51.59.195:8080 is slow
#
# 1935 proxies left to filter
# 111.231.31.210:1080 is slow
#
# 1934 proxies left to filter
# 144.217.68.210:1080 is slow
#
# 1933 proxies left to filter
# 35.212.155.228:3128 is good
# average conn time: 3.91335875647
#
# 1932 proxies left to filter
# 134.119.207.13:1080 is good
# average conn time: 3.85364720556
#
# 1931 proxies left to filter
# 134.209.99.199:3128 is slow
#
# 1930 proxies left to filter
# 134.209.24.138:8080 is good
# average conn time: 3.76754625424
#
# 1929 proxies left to filter
# 134.119.207.7:8080 is slow
#
# 1928 proxies left to filter
# 104.248.123.136:21 is slow
#
# 1927 proxies left to filter
# 1.32.59.217:34709 is good
# average conn time: 3.80049958982
#
# 1926 proxies left to filter
# 111.231.248.100:1080 is slow
#
# 1925 proxies left to filter
# 134.119.214.203:8080 is slow
#
# 1924 proxies left to filter
# 185.22.174.69:10010 is good
# average conn time: 3.72671221464
#
# 1923 proxies left to filter
# 138.121.32.133:23492 is good
# average conn time: 3.71750320792
#
# 1922 proxies left to filter
# 110.44.122.215:8080 is good
# average conn time: 3.78095929797
#
# 1921 proxies left to filter
# 116.209.58.137:9999 is slow
#
# 1920 proxies left to filter
# 104.233.226.238:3128 is slow
#
# 1919 proxies left to filter
# 138.68.166.224:8080 is bad
#
# 1918 proxies left to filter
# 104.248.124.35:8080 is good
# average conn time: 3.69758267062
#
# 1917 proxies left to filter
# 103.87.171.106:31773 is good
# average conn time: 3.75556100247
#
# 1916 proxies left to filter
# 103.253.168.99:8080 is bad
#
# 1915 proxies left to filter
# 103.216.48.83:8080 is slow
#
# 1914 proxies left to filter
# 117.254.217.228:8080 is good
# average conn time: 3.83294986595
#
# 1913 proxies left to filter
# 134.209.20.2:3128 is slow
#
# 1912 proxies left to filter
# 119.180.167.51:8060 is slow
#
# 1911 proxies left to filter
# 138.0.89.144:32715 is good
# average conn time: 3.83131480217
#
# 1910 proxies left to filter
# 46.101.37.48:3128 is slow
#
# 1909 proxies left to filter
# 115.124.85.6:8080 is good
# average conn time: 3.79883806602
#
# 1908 proxies left to filter
# 148.70.245.60:1080 is slow
#
# 1907 proxies left to filter
# 122.117.190.229:57876 is slow
#
# 1906 proxies left to filter
# 1.10.141.220:55654 is bad
#
# 1905 proxies left to filter
# 23.237.22.82:3128 is good
# average conn time: 3.72604055608
#
# 1904 proxies left to filter
# 128.199.241.226:31330 is slow
#
# 1903 proxies left to filter
# 150.48.6.114:80 is bad
#
# 1902 proxies left to filter
# 118.173.233.149:45160 is good
# average conn time: 3.72515058517
#
# 1901 proxies left to filter
# 1.20.102.167:30163 is good
# average conn time: 3.70637487879
#
# 1900 proxies left to filter
# 118.175.93.171:32866 is good
# average conn time: 3.69998151779
#
# 1899 proxies left to filter
# 119.28.73.207:3128 is good
# average conn time: 3.66371528775
#
# 1898 proxies left to filter
# 130.105.131.165:8080 is good
# average conn time: 3.64825970851
#
# 1897 proxies left to filter
# 148.70.231.198:1080 is slow
#
# 1896 proxies left to filter
# 125.25.54.65:38903 is good
# average conn time: 3.6656815106
#
# 1895 proxies left to filter
# 119.82.253.165:59778 is slow
#
# 1894 proxies left to filter
# 118.172.201.118:54351 is slow
#
# 1893 proxies left to filter
# 103.194.90.178:44487 is bad
#
# 1892 proxies left to filter
# 139.99.18.179:80 is slow
#
# 1891 proxies left to filter
# 109.199.133.161:23500 is good
# average conn time: 3.6979768497
#
# 1890 proxies left to filter
# 120.210.219.104:80 is slow
#
# 1889 proxies left to filter
# 118.175.93.179:47826 is slow
#
# 1888 proxies left to filter
# 140.143.10.164:8888 is slow
#
# 1887 proxies left to filter
# 103.53.110.55:44164 is good
# average conn time: 3.7615433086
#
# 1886 proxies left to filter
# 109.167.141.137:8080 is bad
#
# 1885 proxies left to filter
# 152.136.121.125:1080 is slow
#
# 1884 proxies left to filter
# 1.20.101.77:44440 is good
# average conn time: 3.80435678363
#
# 1883 proxies left to filter
# 118.174.196.174:23500 is slow
#
# 1882 proxies left to filter
# 142.93.248.9:3128 is slow
#
# 1881 proxies left to filter
# 116.212.154.4:8080 is good
# average conn time: 3.78492087649
#
# 1880 proxies left to filter
# 118.174.232.95:45004 is good
# average conn time: 3.75989520961
#
# 1879 proxies left to filter
# 138.121.186.91:8080 is slow
#
# 1878 proxies left to filter
# 124.158.167.26:8080 is slow
#
# 1877 proxies left to filter
# 110.5.110.100:42346 is slow
#
# 1876 proxies left to filter
# 118.175.240.205:36123 is good
# average conn time: 3.796322273
#
# 1875 proxies left to filter
# 150.129.250.28:36266 is slow
#
# 1874 proxies left to filter
# 134.209.64.132:8118 is good
# average conn time: 3.73803415298
#
# 1873 proxies left to filter
# 157.230.212.53:3128 is slow
#
# 1872 proxies left to filter
# 121.12.85.2:80 is slow
#
# 1871 proxies left to filter
# 125.26.7.124:61642 is slow
#
# 1870 proxies left to filter
# 109.235.51.110:54321 is slow
#
# 1869 proxies left to filter
# 103.25.195.2:80 is good
# average conn time: 3.77713569266
#
# 1868 proxies left to filter
# 118.175.93.148:33320 is bad
#
# 1867 proxies left to filter
# 124.41.211.40:55324 is good
# average conn time: 3.81477269434
#
# 1866 proxies left to filter
# 120.28.192.137:31649 is good
# average conn time: 3.89849020564
#
# 1865 proxies left to filter
# 103.99.176.32:8080 is good
# average conn time: 3.96186601371
#
# 1864 proxies left to filter
# 142.93.203.194:8080 is good
# average conn time: 3.90535261081
#
# 1863 proxies left to filter
# 115.159.76.142:1080 is slow
#
# 1862 proxies left to filter
# 151.106.8.233:8080 is good
# average conn time: 3.85934670766
#
# 1861 proxies left to filter
# 119.18.147.211:58367 is slow
#
# 1860 proxies left to filter
# 1.179.144.41:8080 is good
# average conn time: 3.91046635428
#
# 1859 proxies left to filter
# 114.30.75.207:52944 is good
# average conn time: 4.01161268529
#
# 1858 proxies left to filter
# 134.119.188.147:8080 is slow
#
# 1857 proxies left to filter
# 1.10.188.202:8080 is good
# average conn time: 3.98818371607
#
# 1856 proxies left to filter
# 134.119.214.206:8080 is slow
#
# 1855 proxies left to filter
# 119.235.27.56:8080 is slow
#
# 1854 proxies left to filter
# 108.61.245.115:3128 is good
# average conn time: 3.93485236168
#
# 1853 proxies left to filter
# 117.240.135.28:63141 is slow
#
# 1852 proxies left to filter
# 103.31.251.202:8080 is good
# average conn time: 3.95924192079
#
# 1851 proxies left to filter
# 103.216.173.1:50031 is bad
#
# 1850 proxies left to filter
# 134.119.214.197:1080 is slow
#
# 1849 proxies left to filter
# 103.108.120.20:52241 is good
# average conn time: 3.98904925585
#
# 1848 proxies left to filter
# 104.248.8.35:8080 is slow
#
# 1847 proxies left to filter
# 142.93.96.177:8080 is slow
#
# 1846 proxies left to filter
# 206.81.2.158:8080 is good
# average conn time: 3.93827191118
#
# 1845 proxies left to filter
# 113.200.56.13:8010 is bad
#
# 1844 proxies left to filter
# 104.248.169.170:8080 is good
# average conn time: 3.89423523722
#
# 1843 proxies left to filter
# 13.210.72.190:53281 is good
# average conn time: 3.88953732808
#
# 1842 proxies left to filter
# 109.123.4.12:3128 is good
# average conn time: 3.85491024507
#
# 1841 proxies left to filter
# 103.225.95.1:55419 is good
# average conn time: 3.87373977513
#
# 1840 proxies left to filter
# 112.78.38.165:63141 is good
# average conn time: 3.94009211125
#
# 1839 proxies left to filter
# 148.70.245.230:1080 is slow
#
# 1838 proxies left to filter
# 119.153.149.170:3128 is slow
#
# 1837 proxies left to filter
# 134.119.205.163:8080 is slow
#
# 1836 proxies left to filter
# 138.121.25.16:55780 is bad
#
# 1835 proxies left to filter
# 148.70.204.210:8888 is slow
#
# 1834 proxies left to filter
# 125.27.10.202:46824 is slow
#
# 1833 proxies left to filter
# 13.233.195.181:80 is slow
#
# 1832 proxies left to filter
# 101.109.27.229:8080 is good
# average conn time: 3.94419636304
#
# 1831 proxies left to filter
# 1.10.187.55:41337 is bad
#
# 1830 proxies left to filter
# 125.163.227.234:8080 is good
# average conn time: 3.96964280605
#
# 1829 proxies left to filter
# 115.127.62.34:8080 is good
# average conn time: 3.990083562
#
# 1828 proxies left to filter
# 14.207.32.96:8080 is slow
#
# 1827 proxies left to filter
# 122.160.36.7:80 is slow
#
# 1826 proxies left to filter
# 118.172.201.149:37662 is good
# average conn time: 3.98730322791
#
# 1825 proxies left to filter
# 102.177.194.26:59042 is bad
#
# 1824 proxies left to filter
# 138.197.128.221:3128 is slow
#
# 1823 proxies left to filter
# 117.102.78.42:8080 is good
# average conn time: 4.00448202225
#
# 1822 proxies left to filter
# 122.129.108.107:46454 is good
# average conn time: 3.99942533175
#
# 1821 proxies left to filter
# 103.46.233.27:81 is slow
# 1820 proxies left to filter
# 112.118.159.150:8380 is slow
#
# 1819 proxies left to filter
# 1.10.188.214:42594 is slow
#
# 1818 proxies left to filter
# 118.175.93.24:37038 is slow
#
# 1817 proxies left to filter
# 139.255.19.29:8080 is slow
#
# 1816 proxies left to filter
# 117.191.11.113:80 is slow
#
# 1815 proxies left to filter
# 112.199.95.106:8080 is slow
#
# 1814 proxies left to filter
# 103.75.225.34:80 is slow
#
# 1813 proxies left to filter
# 109.86.213.138:47432 is slow
#
# 1812 proxies left to filter
# 1.10.187.13:51064 is good
# average conn time: 3.97863336451
#
# 1811 proxies left to filter
# 114.129.23.26:8080 is good
# average conn time: 4.00327117221
#
# 1810 proxies left to filter
# 129.204.222.243:1080 is slow
#
# 1809 proxies left to filter
# 110.235.201.156:8080 is slow
#
# 1808 proxies left to filter
# 111.230.113.92:1080 is slow
#
# 1807 proxies left to filter
# 103.28.226.125:32862 is good
# average conn time: 4.03735200838
#
# 1806 proxies left to filter
# 124.81.99.30:3128 is good
# average conn time: 4.05470776016
#
# 1805 proxies left to filter
# 125.73.220.18:49128 is good
# average conn time: 4.06102234594
#
# 1804 proxies left to filter
# 134.119.205.170:1080 is good
# average conn time: 4.06316097313
#
# 1803 proxies left to filter
# 105.28.102.9:56679 is slow
#
# 1802 proxies left to filter
# 150.95.151.68:8288 is slow
#
# 1801 proxies left to filter
# 103.20.204.104:80 is good
# average conn time: 4.08437742506
#
# 1800 proxies left to filter
# 149.56.99.222:80 is slow
#
# 1799 proxies left to filter
# 117.191.11.104:8080 is slow
#
# 1798 proxies left to filter
# 114.57.33.214:8080 is slow
#
# 1797 proxies left to filter
# 128.199.147.208:31330 is slow
#
# 1796 proxies left to filter
# 103.58.251.179:55316 is good
# average conn time: 4.19988752966
#
# 1795 proxies left to filter
# 103.102.12.161:80 is good
# average conn time: 4.23948035189
#
# 1794 proxies left to filter
# 116.68.192.62:55133 is good
# average conn time: 4.23747042139
#
# 1793 proxies left to filter
# 142.4.204.85:8080 is slow
#
# 1792 proxies left to filter
# 148.70.25.92:8888 is slow
#
# 1791 proxies left to filter
# 118.136.92.109:8080 is good
# average conn time: 4.25085668062
#
# 1790 proxies left to filter
# 117.127.0.202:80 is slow
#
# 1789 proxies left to filter
# 118.172.211.37:58728 is good
# average conn time: 4.24282008906
#
# 1788 proxies left to filter
# 134.236.244.39:60100 is bad
#
# 1787 proxies left to filter
# 103.194.243.217:50407 is bad
#
# 1786 proxies left to filter
# 125.26.99.186:54193 is good
# average conn time: 4.26233295313
#
# 1785 proxies left to filter
# 103.47.94.67:23500 is bad
#
# 1784 proxies left to filter
# 103.61.153.100:53281 is slow
#
# 1783 proxies left to filter
# 117.206.148.209:8080 is good
# average conn time: 4.25068544368
#
# 1782 proxies left to filter
# 101.29.162.185:8080 is slow
#
# 1781 proxies left to filter
# 122.54.3.99:3128 is slow
#
# 1780 proxies left to filter
# 68.183.206.225:3128 is slow
#
# 1779 proxies left to filter
# 103.46.233.29:83 is slow
#
# 1778 proxies left to filter
# 150.242.182.98:80 is good
# average conn time: 4.23335047924
#
# 1777 proxies left to filter
# 103.250.152.22:52572 is good
# average conn time: 4.21550580263
#
# 1776 proxies left to filter
# 35.235.75.244:3128 is good
# average conn time: 4.17787302131
#
# 1775 proxies left to filter
# 111.201.96.181:8060 is slow
#
# 1774 proxies left to filter
# 103.9.188.230:60150 is slow
#
# 1773 proxies left to filter
# 134.119.222.252:1080 is slow
#
# 1772 proxies left to filter
# 111.231.232.168:8888 is slow
#
# 1771 proxies left to filter
# 103.196.233.167:8080 is good
# average conn time: 4.19200876414
#
# 1770 proxies left to filter
# 111.231.31.197:1080 is slow
#
# 1769 proxies left to filter
# 142.4.196.107:3128 is good
# average conn time: 4.16636706787
#
# 1768 proxies left to filter
# 138.68.166.138:3128 is good
# average conn time: 4.13297542242
#
# 1767 proxies left to filter
# 104.248.0.170:3128 is slow
#
# 1766 proxies left to filter
# 101.109.212.224:8080 is slow
#
# 1765 proxies left to filter
# 13.237.196.237:80 is slow
#
# 1764 proxies left to filter
# 122.154.103.68:8080 is good
# average conn time: 4.14013259979
#
# 1763 proxies left to filter
# 125.27.221.139:8080 is slow
#
# 1762 proxies left to filter
# 134.119.205.168:8080 is slow
#
# 1761 proxies left to filter
# 151.237.133.241:8080 is slow
#
# 1760 proxies left to filter
# 110.11.252.135:3128 is good
# average conn time: 4.12027433009
#
# 1759 proxies left to filter
# 104.248.67.19:3128 is slow
#
# 1758 proxies left to filter
# 103.206.112.75:51739 is slow
#
# 1757 proxies left to filter
# 109.73.184.39:8080 is good
# average conn time: 4.19196172073
#
# 1756 proxies left to filter
# 103.206.230.2:35144 is bad
#
# 1755 proxies left to filter
# 150.109.11.142:3128 is good
# average conn time: 4.17553233438
#
# 1754 proxies left to filter
# 110.52.235.172:9999 is slow
#
# 1753 proxies left to filter
# 103.231.218.126:53281 is bad
#
# 1752 proxies left to filter
# 122.252.178.26:8080 is good
# average conn time: 4.2726241208
#
# 1751 proxies left to filter
# 103.18.202.49:59024 is bad
#
# 1750 proxies left to filter
# 103.108.98.1:55207 is bad
#
# 1749 proxies left to filter
# 140.143.145.213:1080 is slow
#
# 1748 proxies left to filter
# 119.160.192.123:80 is good
# average conn time: 4.25364612883
#
# 1747 proxies left to filter
# 134.209.162.216:80 is slow
#
# 1746 proxies left to filter
# 114.31.5.34:52606 is bad
#
# 1745 proxies left to filter
# 132.255.22.162:8181 is slow
#
# 1744 proxies left to filter
# 125.27.10.195:38153 is good
# average conn time: 4.29546964061
#
# 1743 proxies left to filter
# 103.76.188.52:54533 is bad
#
# 1742 proxies left to filter
# 200.188.151.212:8080 is good
# average conn time: 4.2947686719
#
# 1741 proxies left to filter
# 117.212.90.17:8080 is slow
#
# 1740 proxies left to filter
# 128.199.169.60:80 is slow
#
# 1739 proxies left to filter
# 119.82.252.115:49085 is good
# average conn time: 4.30953302004
#
# 1738 proxies left to filter
# 138.186.22.117:8080 is bad
#
# 1737 proxies left to filter
# 117.247.254.67:3128 is good
# average conn time: 4.32507320245
#
# 1736 proxies left to filter
# 103.246.146.76:8080 is slow
#
# 1735 proxies left to filter
# 101.109.83.221:31860 is slow
#
# 1734 proxies left to filter
# 129.28.42.240:1080 is slow
#
# 1733 proxies left to filter
# 109.254.48.122:39568 is good
# average conn time: 4.33180267707
#
# 1732 proxies left to filter
# 109.86.199.155:51447 is good
# average conn time: 4.31912329896
#
# 1731 proxies left to filter
# 118.97.53.99:51469 is slow
#
# 1730 proxies left to filter
# 144.217.229.157:1080 is slow
#
# 1729 proxies left to filter
# 131.161.69.235:8080 is good
# average conn time: 4.30689962094
#
# 1728 proxies left to filter
# 103.239.145.121:8080 is good
# average conn time: 4.30995017593
#
# 1727 proxies left to filter
# 103.204.82.15:8080 is good
# average conn time: 4.32986946867
#
# 1726 proxies left to filter
# 103.108.144.12:63141 is slow
#
# 1725 proxies left to filter
# 113.11.136.98:8080 is slow
#
# 1724 proxies left to filter
# 117.204.254.17:8080 is good
# average conn time: 4.31440038085
#
# 1723 proxies left to filter
# 123.1.170.138:3128 is slow
#
# 1722 proxies left to filter
# 23.237.23.73:3128 is good
# average conn time: 4.28145203117
#
# 1721 proxies left to filter
# 103.78.254.82:8080 is slow
#
# 1720 proxies left to filter
# 121.79.131.58:8080 is good
# average conn time: 4.2913446954
#
# 1719 proxies left to filter
# 125.161.140.126:8080 is good
# average conn time: 4.27693151071
#
# 1718 proxies left to filter
# 103.41.122.14:53281 is good
# average conn time: 4.2814487488
#
# 1717 proxies left to filter
# 119.36.161.174:80 is slow
#
# 1716 proxies left to filter
# 123.56.21.171:3128 is slow
#
# 1715 proxies left to filter
# 104.238.250.67:8080 is slow
#
# 1714 proxies left to filter
# 117.62.16.87:9999 is slow
#
# 1713 proxies left to filter
# 103.253.73.148:8080 is good
# average conn time: 4.26181498146
#
# 1712 proxies left to filter
# 111.231.26.97:1080 is slow
#
# 1711 proxies left to filter
# 111.231.60.77:1080 is slow
#
# 1710 proxies left to filter
# 101.4.136.34:8080 is slow
#
# 1709 proxies left to filter
# 132.148.150.41:80 is slow
#
# 1708 proxies left to filter
# 68.183.118.181:8080 is good
# average conn time: 4.23021324286
#
# 1707 proxies left to filter
# 125.26.122.213:8080 is slow
#
# 1706 proxies left to filter
# 139.255.123.186:8080 is good
# average conn time: 4.25117886348
#
# 1705 proxies left to filter
# 131.100.79.44:8080 is good
# average conn time: 4.23250792734
#
# 1704 proxies left to filter
# 103.240.161.59:48809 is good
# average conn time: 4.22786635391
#
# 1703 proxies left to filter
# 115.159.5.84:8888 is slow
#
# 1702 proxies left to filter
# 117.206.148.192:8080 is good
# average conn time: 4.21533250442
# 1701 proxies left to filter
# 118.174.220.58:60547 is bad
#
# 1700 proxies left to filter
# 148.70.84.25:1080 is slow
#
# 1699 proxies left to filter
# 132.232.205.156:1080 is slow
#
# 1698 proxies left to filter
# 103.205.132.168:8080 is slow
#
# 1697 proxies left to filter
# 122.114.232.137:808 is slow
#
# 1696 proxies left to filter
# 14.63.82.13:3128 is good
# average conn time: 4.19862342427
#
# 1695 proxies left to filter
# 110.77.232.204:80 is good
# average conn time: 4.21711170132
#
# 1694 proxies left to filter
# 117.255.222.78:8080 is good
# average conn time: 4.20485128137
#
# 1693 proxies left to filter
# 13.233.171.121:80 is slow
#
# 1692 proxies left to filter
# 117.196.239.85:8080 is good
# average conn time: 4.2336812731
#
# 1691 proxies left to filter
# 103.42.154.2:3128 is good
# average conn time: 4.24262913775
#
# 1690 proxies left to filter
# 117.191.11.71:8080 is slow
#
# 1689 proxies left to filter
# 132.232.133.25:1080 is slow
#
# 1688 proxies left to filter
# 118.172.51.206:38313 is bad
#
# 1687 proxies left to filter
# 114.67.237.32:808 is slow
#
# 1686 proxies left to filter
# 142.93.248.9:3128 is slow
#
# 1685 proxies left to filter
# 128.1.136.37:3128 is good
# average conn time: 4.27569565878
#
# 1684 proxies left to filter
# 110.232.81.69:54022 is slow
#
# 1683 proxies left to filter
# 117.204.255.43:8080 is slow
#
# 1682 proxies left to filter
# 103.194.248.166:39557 is slow
#
# 1681 proxies left to filter
# 117.186.214.74:9999 is slow
#
# 1680 proxies left to filter
# 117.4.243.172:40870 is bad
#
# 1679 proxies left to filter
# 118.175.93.105:38819 is slow
#
# 1678 proxies left to filter
# 138.68.166.224:8080 is bad
#
# 1677 proxies left to filter
# 140.227.204.5:3128 is bad
#
# 1676 proxies left to filter
# 110.232.83.115:8080 is slow
#
# 1675 proxies left to filter
# 118.175.93.69:54242 is bad
#
# 1674 proxies left to filter
# 101.50.1.2:80 is slow
#
# 1673 proxies left to filter
# 138.68.174.231:80 is slow
#
# 1672 proxies left to filter
# 115.124.86.169:8080 is good
# average conn time: 4.32098073333
#
# 1671 proxies left to filter
# 115.159.109.103:1080 is slow
#
# 1670 proxies left to filter
# 122.154.151.52:8080 is good
# average conn time: 4.3117387433
#
# 1669 proxies left to filter
# 143.202.72.188:8080 is slow
#
# 1668 proxies left to filter
# 118.175.93.103:42759 is slow
#
# 1667 proxies left to filter
# 124.41.240.171:30881 is bad
#
# 1666 proxies left to filter
# 104.248.7.88:80 is bad
#
# 1665 proxies left to filter
# 103.231.253.129:3128 is slow
#
# 1664 proxies left to filter
# 209.97.180.250:8080 is good
# average conn time: 4.28599137883
#
# 1663 proxies left to filter
# 115.127.65.61:34053 is bad
#
# 1662 proxies left to filter
# 110.74.222.97:41865 is slow
#
# 1661 proxies left to filter
# 103.111.56.69:50148 is good
# average conn time: 4.2743077193
#
# 1660 proxies left to filter
# 117.196.238.255:8080 is slow
#
# 1659 proxies left to filter
# 118.173.232.43:53586 is bad
#
# 1658 proxies left to filter
# 103.108.128.1:8080 is slow
#
# 1657 proxies left to filter
# 115.159.147.221:1080 is slow
#
# 1656 proxies left to filter
# 145.239.169.41:1080 is slow
#
# 1655 proxies left to filter
# 138.91.124.31:80 is slow
#
# 1654 proxies left to filter
# 117.196.237.232:31272 is slow
#
# 1653 proxies left to filter
# 124.200.105.154:8118 is slow
#
# 1652 proxies left to filter
# 103.26.55.86:8080 is good
# average conn time: 4.28848160074
#
# 1651 proxies left to filter
# 119.190.185.35:8060 is slow
#
# 1650 proxies left to filter
# 82.196.5.200:3128 is good
# average conn time: 4.26315919446
#
# 1649 proxies left to filter
# 139.255.79.131:3128 is slow
#
# 1648 proxies left to filter
# 118.175.207.183:42517 is good
# average conn time: 4.26713153532
#
# 1647 proxies left to filter
# 118.174.65.137:30931 is slow
#
# 1646 proxies left to filter
# 144.217.74.227:1080 is slow
#
# 1645 proxies left to filter
# 14.139.120.234:80 is slow
#
# 1644 proxies left to filter
# 148.70.243.93:1080 is slow
#
# 1643 proxies left to filter
# 119.63.132.90:30759 is slow
#
# 1642 proxies left to filter
# 138.99.19.134:80 is slow
#
# 1641 proxies left to filter
# 128.201.77.110:8080 is good
# average conn time: 4.24914353755
#
# 1640 proxies left to filter
# 134.119.214.199:8080 is slow
#
# 1639 proxies left to filter
# 103.46.232.1:83 is slow
#
# 1638 proxies left to filter
# 115.159.219.194:1080 is good
# average conn time: 4.28814508668
#
# 1637 proxies left to filter
# 145.239.93.131:80 is slow
#
# 1636 proxies left to filter
# 104.248.230.168:8080 is slow
#
# 1635 proxies left to filter
# 118.99.102.60:8080 is good
# average conn time: 4.28780860607
#
# 1634 proxies left to filter
# 101.255.64.197:36588 is slow
#
# 1633 proxies left to filter
# 118.175.93.91:52142 is slow
#
# 1632 proxies left to filter
# 129.28.127.3:1080 is slow
#
# 1631 proxies left to filter
# 139.0.27.26:55762 is slow
#
# 1630 proxies left to filter
# 134.119.188.152:8080 is slow
#
# 1629 proxies left to filter
# 110.77.134.106:8080 is good
# average conn time: 4.2784310036
#
# 1628 proxies left to filter
# 128.199.133.218:8000 is good
# average conn time: 4.26342059148
#
# 1627 proxies left to filter
# 109.234.112.250:46675 is good
# average conn time: 4.2614556959
#
# 1626 proxies left to filter
# 143.202.72.206:8080 is good
# average conn time: 4.28212323189
#
# 1625 proxies left to filter
# 1.202.245.84:8080 is slow
#
# 1624 proxies left to filter
# 139.99.18.179:443 is slow
#
# 1623 proxies left to filter
# 103.73.224.196:8080 is slow
#
# 1622 proxies left to filter
# 1.179.164.233:58387 is bad
#
# 1621 proxies left to filter
# 147.135.226.213:8080 is slow
#
# 1620 proxies left to filter
# 103.22.173.230:8080 is good
# average conn time: 4.2687520444
#
# 1619 proxies left to filter
# 103.87.48.138:8080 is good
# average conn time: 4.26138280724
#
# 1618 proxies left to filter
# 117.191.11.111:8080 is slow
#
# 1617 proxies left to filter
# 1.20.100.18:55348 is good
# average conn time: 4.24863761858
#
# 1616 proxies left to filter
# 114.199.115.244:38509 is slow
#
# 1615 proxies left to filter
# 139.224.187.136:3128 is slow
#
# 1614 proxies left to filter
# 103.42.162.58:8080 is good
# average conn time: 4.26228570628
#
# 1613 proxies left to filter
# 103.73.100.146:8080 is good
# average conn time: 4.27278983208
#
# 1612 proxies left to filter
# 125.209.94.182:45304 is slow
#
# 1611 proxies left to filter
# 139.180.138.129:3128 is good
# average conn time: 4.269293429
#
# 1610 proxies left to filter
# 117.74.125.192:8088 is good
# average conn time: 4.2758233942
#
# 1609 proxies left to filter
# 123.115.231.202:8060 is slow
#
# 1608 proxies left to filter
# 148.70.231.232:1080 is slow
#
# 1607 proxies left to filter
# 104.248.85.190:8080 is good
# average conn time: 4.25307723389
#
# 1606 proxies left to filter
# 111.43.70.58:51547 is slow
#
# 1605 proxies left to filter
# 104.248.92.54:3120 is slow
#
# 1604 proxies left to filter
# 138.68.166.224:3128 is bad
#
# 1603 proxies left to filter
# 151.106.8.233:1080 is slow
#
# 1602 proxies left to filter
# 110.44.116.189:32161 is bad
#
# 1601 proxies left to filter
# 103.42.218.94:8080 is good
# average conn time: 4.26220442214
#
# 1600 proxies left to filter
# 103.106.34.1:49714 is good
# average conn time: 4.25299327523
#
# 1599 proxies left to filter
# 106.75.212.2:8080 is slow
#
# 1598 proxies left to filter
# 119.46.146.58:8080 is slow
#
# 1597 proxies left to filter
# 112.198.31.130:8080 is slow
#
# 1596 proxies left to filter
# 139.60.176.62:53281 is bad
#
# 1595 proxies left to filter
# 144.217.229.155:1080 is slow
#
# 1594 proxies left to filter
# 103.69.220.13:8080 is good
# average conn time: 4.24723162858
#
# 1593 proxies left to filter
# 138.97.244.22:8080 is good
# average conn time: 4.24390967981
#
# 1592 proxies left to filter
# 147.91.111.133:55954 is slow
#
# 1591 proxies left to filter
# 152.136.75.107:1080 is slow
#
# 1590 proxies left to filter
# 14.207.215.229:8213 is good
# average conn time: 4.23573678695
#
# 1589 proxies left to filter
# 103.117.213.74:57403 is good
# average conn time: 4.24634850171
#
# 1588 proxies left to filter
# 118.173.233.39:48988 is good
# average conn time: 4.25446036512
#
# 1587 proxies left to filter
# 144.217.229.159:1080 is slow
#
# 1586 proxies left to filter
# 138.219.228.161:8080 is slow
#
# 1585 proxies left to filter
# 131.196.7.6:3128 is slow
#
# 1584 proxies left to filter
# 134.101.6.150:8081 is slow
#
# 1583 proxies left to filter
# 103.82.43.185:52059 is good
# average conn time: 4.28593006191
#
# 1582 proxies left to filter
# 111.230.254.192:1080 is slow
#
# 1581 proxies left to filter
# 1.20.99.89:31799 is bad
#
# 1580 proxies left to filter
# 1.20.96.185:8080 is good
# average conn time: 4.29530204413
#
# 1579 proxies left to filter
# 103.76.170.50:54599 is slow
#
# 1578 proxies left to filter
# 110.93.13.172:8080 is slow
#
# 1577 proxies left to filter
# 121.28.43.212:3128 is good
# average conn time: 4.30084706772
#
# 1576 proxies left to filter
# 104.248.8.35:3128 is slow
#
# 1575 proxies left to filter
# 13.233.182.0:80 is slow
#
# 1574 proxies left to filter
# 125.209.82.78:35087 is slow
#
# 1573 proxies left to filter
# 1.20.101.149:44778 is good
# average conn time: 4.30803734593
#
# 1572 proxies left to filter
# 115.78.73.60:3128 is good
# average conn time: 4.29561158489
#
# 1571 proxies left to filter
# 54.37.84.141:3128 is slow
#
# 1570 proxies left to filter
# 137.59.51.153:8080 is slow
#
# 1569 proxies left to filter
# 1.10.189.7:40518 is good
# average conn time: 4.29008514979
#
# 1568 proxies left to filter
# 137.59.163.14:8080 is slow
#
# 1567 proxies left to filter
# 123.49.51.42:55124 is bad
#
# 1566 proxies left to filter
# 132.232.171.108:1080 is slow
#
# 1565 proxies left to filter
# 119.82.252.29:45736 is slow
#
# 1564 proxies left to filter
# 118.174.233.66:48902 is good
# average conn time: 4.27889795082
#
# 1563 proxies left to filter
# 119.2.49.118:47749 is slow
#
# 1562 proxies left to filter
# 157.230.233.67:8080 is good
# average conn time: 4.25884841357
#
# 1561 proxies left to filter
# 103.111.134.85:31194 is bad
#
# 1560 proxies left to filter
# 117.135.77.30:8060 is slow
#
# 1559 proxies left to filter
# 138.121.32.26:23500 is bad
#
# 1558 proxies left to filter
# 103.3.46.12:8080 is slow
#
# 1557 proxies left to filter
# 103.229.177.51:34508 is good
# average conn time: 4.28498030805
#
# 1556 proxies left to filter
# 128.14.173.214:1080 is slow
#
# 1555 proxies left to filter
# 118.174.220.120:37124 is slow
#
# 1554 proxies left to filter
# 118.175.93.79:59671 is bad
#
# 1553 proxies left to filter
# 103.249.180.220:8080 is slow
#
# 1552 proxies left to filter
# 103.250.166.4:44472 is good
# average conn time: 4.29132857459
#
# 1551 proxies left to filter
# 103.87.207.1:49283 is good
# average conn time: 4.27994819121
#
# 1550 proxies left to filter
# 124.41.211.180:30143 is slow
#
# 1549 proxies left to filter
# 128.199.169.60:3128 is slow
#
# 1548 proxies left to filter
# 120.83.109.197:9999 is slow
#
# 1547 proxies left to filter
# 103.26.54.94:8080 is good
# average conn time: 4.27441094151
#
# 1546 proxies left to filter
# 134.175.163.53:1080 is slow
#
# 1545 proxies left to filter
# 120.210.219.101:8080 is slow
#
# 1544 proxies left to filter
# 103.76.253.156:3128 is good
# average conn time: 4.26395736919
#
# 1543 proxies left to filter
# 140.143.147.224:1080 is slow
#
# 1542 proxies left to filter
# 109.172.57.250:23500 is bad
#
# 1541 proxies left to filter
# 134.119.205.244:8080 is slow
#
# 1540 proxies left to filter
# 103.248.30.42:8080 is slow
#
# 1539 proxies left to filter
# 111.231.113.135:1080 is slow
#
# 1538 proxies left to filter
# 14.207.210.69:8213 is good
# average conn time: 4.25234861347
#
# 1537 proxies left to filter
# 14.102.152.157:8080 is slow
#
# 1536 proxies left to filter
# 151.106.10.109:8080 is slow
#
# 1535 proxies left to filter
# 124.41.240.121:40913 is good
# average conn time: 4.2413739721
#
# 1534 proxies left to filter
# 139.255.31.210:8080 is good
# average conn time: 4.23521583515
#
# 1533 proxies left to filter
# 103.3.77.94:35301 is bad
#
# 1532 proxies left to filter
# 103.70.204.194:46351 is bad
#
# 1531 proxies left to filter
# 145.255.6.171:31252 is bad
#
# 1530 proxies left to filter
# 142.93.96.177:80 is slow
#
# 1529 proxies left to filter
# 185.34.52.117:80 is slow
#
# 1528 proxies left to filter
# 114.57.185.12:58910 is bad
#
# 1527 proxies left to filter
# 119.235.27.42:8080 is good
# average conn time: 4.2413113353
#
# 1526 proxies left to filter
# 122.176.65.143:39841 is bad
#
# 1525 proxies left to filter
# 14.146.95.45:9797 is slow
#
# 1524 proxies left to filter
# 119.51.140.211:8080 is slow
#
# 1523 proxies left to filter
# 110.232.83.117:8080 is slow
#
# 1522 proxies left to filter
# 129.204.192.129:1080 is slow
#
# 1521 proxies left to filter
# 103.57.21.30:53281 is slow
#
# 1520 proxies left to filter
# 138.186.23.9:40340 is bad
#
# 1519 proxies left to filter
# 143.202.252.109:8080 is good
# average conn time: 4.23280295127
#
# 1518 proxies left to filter
# 138.255.165.86:40600 is good
# average conn time: 4.21780454983
#
# 1517 proxies left to filter
# 111.68.115.155:80 is slow
#
# 1516 proxies left to filter
# 103.118.169.81:47842 is bad
#
# 1515 proxies left to filter
# 103.242.184.160:36264 is good
# average conn time: 4.23366995244
#
# 1514 proxies left to filter
# 118.174.220.42:32515 is slow
#
# 1513 proxies left to filter
# 116.203.129.104:8080 is good
# average conn time: 4.23387753963
#
# 1512 proxies left to filter
# 14.207.27.51:8080 is good
# average conn time: 4.24518486905
#
# 1511 proxies left to filter
# 105.112.84.137:8080 is good
# average conn time: 4.24737194371
#
# 1510 proxies left to filter
# 13.210.72.190:3128 is good
# average conn time: 4.26273015567
#
# 1509 proxies left to filter
# 136.228.160.250:8080 is slow
#
# 1508 proxies left to filter
# 103.233.152.140:8080 is bad
#
# 1507 proxies left to filter
# 124.164.36.27:80 is slow
#
# 1506 proxies left to filter
# 122.154.59.6:8080 is good
# average conn time: 4.25825629736
#
# 1505 proxies left to filter
# 114.134.186.59:45997 is bad
#
# 1504 proxies left to filter
# 147.215.150.71:80 is slow
#
# 1503 proxies left to filter
# 144.76.45.24:8080 is slow
#
# 1502 proxies left to filter
# 94.242.58.142:1448 is good
# average conn time: 4.24160906532
#
# 1501 proxies left to filter
# 109.86.190.193:8080 is good
# average conn time: 4.23446709663
#
# 1500 proxies left to filter
# 123.206.45.139:1080 is slow
#
# 1499 proxies left to filter
# 152.136.70.104:1080 is slow
#
# 1498 proxies left to filter
# 122.15.230.17:8080 is slow
#
# 1497 proxies left to filter
# 141.51.61.11:8080 is slow
#
# 1496 proxies left to filter
# 134.119.205.248:8080 is slow
#
# 1495 proxies left to filter
# 103.220.207.242:37358 is bad
#
# 1494 proxies left to filter
# 112.217.199.122:55872 is bad
#
# 1493 proxies left to filter
# 165.22.68.15:8080 is good
# average conn time: 4.21713400258
#
# 1492 proxies left to filter
# 103.239.54.177:53516 is good
# average conn time: 4.22781922891
#
# 1491 proxies left to filter
# 134.175.166.60:1080 is slow
#
# 1490 proxies left to filter
# 134.249.156.3:82 is good
# average conn time: 4.2148159455
#
# 1489 proxies left to filter
# 103.232.25.97:8080 is good
# average conn time: 4.20654302835
#
# 1488 proxies left to filter
# 54.39.53.104:3128 is good
# average conn time: 4.18678383053
#
# 1487 proxies left to filter
# 116.90.236.126:31284 is good
# average conn time: 4.19746549804
#
# 1486 proxies left to filter
# 117.240.59.115:36127 is bad
#
# 1485 proxies left to filter
# 118.174.220.14:43473 is slow
#
# 1484 proxies left to filter
# 101.109.143.97:55085 is bad
#
# 1483 proxies left to filter
# 104.248.67.19:8080 is slow
#
# 1482 proxies left to filter
# 103.253.150.136:8080 is good
# average conn time: 4.19377724849
#
# 1481 proxies left to filter
# 118.175.93.98:55175 is slow
#
# 1480 proxies left to filter
# 151.106.10.58:8080 is good
# average conn time: 4.17694500208
#
# 1479 proxies left to filter
# 144.217.69.149:1080 is slow
#
# 1478 proxies left to filter
# 139.59.67.74:8080 is slow
#
# 1477 proxies left to filter
# 124.41.240.64:23500 is good
# average conn time: 4.1783928029
#
# 1476 proxies left to filter
# 120.210.219.101:80 is slow
#
# 1475 proxies left to filter
# 145.239.169.46:1080 is slow
#
# 1474 proxies left to filter
# 151.80.44.139:3129 is good
# average conn time: 4.16139059492
#
# 1473 proxies left to filter
# 125.27.119.224:8080 is slow
#
# 1472 proxies left to filter
# 124.41.240.205:36752 is bad
#
# 1471 proxies left to filter
# 1.20.99.178:34781 is slow
#
# 1470 proxies left to filter
# 138.185.22.130:8080 is slow
#
# 1469 proxies left to filter
# 111.198.104.169:808 is slow
#
# 1468 proxies left to filter
# 108.61.123.252:80 is slow
#
# 1467 proxies left to filter
# 138.122.143.150:46007 is good
# average conn time: 4.15178804562
#
# 1466 proxies left to filter
# 110.164.58.106:8082 is good
# average conn time: 4.14553159475
#
# 1465 proxies left to filter
# 146.88.77.51:8080 is good
# average conn time: 4.15610221188
#
# 1464 proxies left to filter
# 106.12.147.81:8080 is slow
#
# 1463 proxies left to filter
# 144.48.176.38:36555 is good
# average conn time: 4.15578849686
#
# 1462 proxies left to filter
# 103.88.221.105:39106 is good
# average conn time: 4.14612395291
#
# 1461 proxies left to filter
# 132.232.21.142:1080 is slow
#
# 1460 proxies left to filter
# 117.212.89.207:31917 is slow
#
# 1459 proxies left to filter
# 123.206.9.180:8888 is slow
#
# 1458 proxies left to filter
# 118.174.233.45:44061 is good
# average conn time: 4.13573214526
#
# 1457 proxies left to filter
# 104.248.173.217:3128 is good
# average conn time: 4.11913099129
# 1456 proxies left to filter
# 146.82.236.133:43415 is good
# average conn time: 4.10512762978
#
# 1455 proxies left to filter
# 139.162.41.26:8080 is slow
#
# 1454 proxies left to filter
# 116.114.19.204:443 is slow
#
# 1453 proxies left to filter
# 118.173.232.74:38905 is slow
#
# 1452 proxies left to filter
# 134.209.214.125:3128 is good
# average conn time: 4.0867504373
#
# 1451 proxies left to filter
# 151.106.10.52:8080 is good
# average conn time: 4.0774762518
#
# 1450 proxies left to filter
# 103.220.28.180:44971 is good
# average conn time: 4.09588484697
#
# 1449 proxies left to filter
# 125.26.7.249:43492 is bad
#
# 1448 proxies left to filter
# 103.94.6.18:443 is slow
#
# 1447 proxies left to filter
# 103.105.69.59:80 is good
# average conn time: 4.08957493194
#
# 1446 proxies left to filter
# 1.20.99.32:55064 is good
# average conn time: 4.08517857818
#
# 1445 proxies left to filter
# 109.196.127.35:8888 is slow
#
# 1444 proxies left to filter
# 103.86.155.78:58096 is bad
#
# 1443 proxies left to filter
# 12.8.247.253:43903 is good
# average conn time: 4.10040468198
#
# 1442 proxies left to filter
# 150.95.151.68:8194 is slow
#
# 1441 proxies left to filter
# 131.108.216.44:53011 is bad
#
# 1440 proxies left to filter
# 104.248.67.19:80 is slow
#
# 1439 proxies left to filter
# 103.76.12.90:53281 is good
# average conn time: 4.10380995988
#
# 1438 proxies left to filter
# 120.210.219.105:80 is slow
#
# 1437 proxies left to filter
# 128.0.179.234:41258 is slow
#
# 1436 proxies left to filter
# 103.214.200.142:33423 is slow
#
# 1435 proxies left to filter
# 103.84.145.88:8080 is good
# average conn time: 4.09676759287
#
# 1434 proxies left to filter
# 134.119.214.197:8080 is slow
#
# 1433 proxies left to filter
# 118.185.94.157:30909 is bad
#
# 1432 proxies left to filter
# 103.245.182.5:8080 is good
# average conn time: 4.09894932024
#
# 1431 proxies left to filter
# 151.106.10.51:8080 is slow
#
# 1430 proxies left to filter
# 109.224.22.29:8080 is good
# average conn time: 4.09174062772
#
# 1429 proxies left to filter
# 139.194.67.120:8080 is good
# average conn time: 4.09550607798
#
# 1428 proxies left to filter
# 123.135.219.83:8118 is slow
#
# 1427 proxies left to filter
# 104.248.7.62:8080 is good
# average conn time: 4.0781395822
#
# 1426 proxies left to filter
# 103.111.29.70:42149 is slow
#
# 1425 proxies left to filter
# 14.207.198.13:8213 is slow
#
# 1424 proxies left to filter
# 115.124.85.219:42854 is slow
#
# 1423 proxies left to filter
# 134.119.214.198:1080 is good
# average conn time: 4.06540318027
#
# 1422 proxies left to filter
# 144.217.22.142:8080 is good
# average conn time: 4.05899569286
#
# 1421 proxies left to filter
# 134.119.205.165:1080 is slow
#
# 1420 proxies left to filter
# 103.38.178.114:55502 is bad
#
# 1419 proxies left to filter
# 151.106.10.56:8080 is slow
#
# 1418 proxies left to filter
# 122.201.23.122:35451 is good
# average conn time: 4.06895418803
#
# 1417 proxies left to filter
# 1.2.169.59:31897 is slow
#
# 1416 proxies left to filter
# 128.199.199.108:8080 is good
# average conn time: 4.05976650989
#
# 1415 proxies left to filter
# 148.70.80.221:1080 is slow
#
# 1414 proxies left to filter
# 103.12.246.12:8080 is slow
#
# 1413 proxies left to filter
# 103.252.117.100:8080 is good
# average conn time: 4.05895494469
#
# 1412 proxies left to filter
# 14.102.76.42:8080 is bad
#
# 1411 proxies left to filter
# 142.4.196.108:3128 is good
# average conn time: 4.04618046681
#
# 1410 proxies left to filter
# 103.111.31.230:8080 is good
# average conn time: 4.04665853884
#
# 1409 proxies left to filter
# 14.207.37.231:8080 is slow
#
# 1408 proxies left to filter
# 103.54.36.50:8080 is good
# average conn time: 4.03990541437
#
# 1407 proxies left to filter
# 138.185.193.55:8080 is slow
#
# 1406 proxies left to filter
# 114.245.188.102:8060 is slow
#
# 1405 proxies left to filter
# 143.202.208.177:40560 is bad
#
# 1404 proxies left to filter
# 132.232.32.178:3128 is good
# average conn time: 4.0399338972
#
# 1403 proxies left to filter
# 103.106.148.232:45681 is slow
#
# 1402 proxies left to filter
# 134.119.214.198:8080 is slow
#
# 1401 proxies left to filter
# 103.250.157.43:38641 is good
# average conn time: 4.05345221224
#
# 1400 proxies left to filter
# 122.137.127.135:8080 is slow
#
# 1399 proxies left to filter
# 148.70.235.30:1080 is good
# average conn time: 4.05859437828
#
# 1398 proxies left to filter
# 1.20.100.7:44179 is slow
#
# 1397 proxies left to filter
# 117.254.216.79:8080 is good
# average conn time: 4.06588004389
#
# 1396 proxies left to filter
# 116.58.48.235:45041 is slow
#
# 1395 proxies left to filter
# 138.97.12.150:36570 is bad
#
# 1394 proxies left to filter
# 103.242.15.86:42862 is bad
#
# 1393 proxies left to filter
# 142.93.109.250:3128 is good
# average conn time: 4.05199077484
#
# 1392 proxies left to filter
# 116.196.90.176:3128 is slow
#
# 1391 proxies left to filter
# 138.255.185.40:8080 is good
# average conn time: 4.0705496194
#
# 1390 proxies left to filter
# 103.239.145.109:32807 is good
# average conn time: 4.06403840141
#
# 1389 proxies left to filter
# 116.197.131.74:8080 is good
# average conn time: 4.06678260074
#
# 1388 proxies left to filter
# 134.209.109.196:3128 is slow
#
# 1387 proxies left to filter
# 103.112.212.10:82 is good
# average conn time: 4.07914862373
#
# 1386 proxies left to filter
# 103.37.81.92:41879 is slow
#
# 1385 proxies left to filter
# 104.248.86.127:8080 is good
# average conn time: 4.06559152504
#
# 1384 proxies left to filter
# 103.235.199.93:30697 is good
# average conn time: 4.08808117882
#
# 1383 proxies left to filter
# 123.49.49.98:23500 is bad
#
# 1382 proxies left to filter
# 118.181.226.216:58654 is slow
#
# 1381 proxies left to filter
# 103.26.245.190:43328 is bad
#
# 1380 proxies left to filter
# 110.39.128.90:8080 is bad
#
# 1379 proxies left to filter
# 117.4.246.95:8080 is slow
#
# 1378 proxies left to filter
# 139.5.71.70:23500 is slow
#
# 1377 proxies left to filter
# 140.227.73.118:3128 is bad
#
# 1376 proxies left to filter
# 103.114.88.24:8080 is good
# average conn time: 4.10558938882
#
# 1375 proxies left to filter
# 103.15.226.124:80 is slow
#
# 1374 proxies left to filter
# 134.119.207.6:8080 is slow
#
# 1373 proxies left to filter
# 113.53.83.210:39695 is slow
#
# 1372 proxies left to filter
# 111.95.22.186:3128 is good
# average conn time: 4.10647644035
#
# 1371 proxies left to filter
# 134.119.207.12:1080 is slow
#
# 1370 proxies left to filter
# 110.39.166.146:8080 is good
# average conn time: 4.10790895048
#
# 1369 proxies left to filter
# 103.245.19.222:53281 is slow
#
# 1368 proxies left to filter
# 101.109.255.97:59277 is slow
#
# 1367 proxies left to filter
# 139.199.108.124:1080 is slow
#
# 1366 proxies left to filter
# 103.210.8.126:8080 is slow
#
# 1365 proxies left to filter
# 118.172.201.32:42815 is slow
#
# 1364 proxies left to filter
# 144.217.229.153:1080 is slow
#
# 1363 proxies left to filter
# 125.162.36.5:80 is slow
#
# 1362 proxies left to filter
# 51.77.213.22:3128 is good
# average conn time: 4.09464618722
#
# 1361 proxies left to filter
# 185.204.208.78:8080 is slow
#
# 1360 proxies left to filter
# 1.20.97.216:39363 is good
# average conn time: 4.09589490561
#
# 1359 proxies left to filter
# 103.105.69.59:8080 is good
# average conn time: 4.10225388589
#
# 1358 proxies left to filter
# 103.15.140.142:44759 is bad
#
# 1357 proxies left to filter
# ...
# average conn time: 4.17770187425
#
# 246 proxies left to filter
# 119.187.120.118:8060 is slow
#
# 245 proxies left to filter
# 116.71.136.98:8080 is good
# average conn time: 4.18036166071
#
# 244 proxies left to filter
# 123.206.56.127:1080 is slow
#
# 243 proxies left to filter
# 125.165.179.254:39804 is slow
#
# 242 proxies left to filter
# 115.127.78.122:8080 is good
# average conn time: 4.18153931206
#
# 241 proxies left to filter
# 14.207.34.131:8080 is good
# average conn time: 4.18013647728
#
# 240 proxies left to filter
# 149.56.102.220:3128 is good
# average conn time: 4.17463968614
#
# 239 proxies left to filter
# 117.244.15.243:3128 is slow
#
# 238 proxies left to filter
# 103.49.53.1:81 is slow
#
# 237 proxies left to filter
# 128.14.139.106:1080 is slow
#
# 236 proxies left to filter
# 103.54.93.188:41391 is slow
#
# 235 proxies left to filter
# 134.209.95.77:8080 is good
# average conn time: 4.16981923842
#
# 234 proxies left to filter
# 206.189.25.70:3128 is slow
#
# 233 proxies left to filter
# 103.76.15.138:31196 is bad
#
# 232 proxies left to filter
# 120.29.124.131:8080 is good
# average conn time: 4.17226053288
#
# 231 proxies left to filter
# 139.255.18.37:8080 is good
# average conn time: 4.18083037248
#
# 230 proxies left to filter
# 113.53.29.218:60095 is bad
#
# 229 proxies left to filter
# 132.232.165.116:1080 is slow
#
# 228 proxies left to filter
# 13.233.220.85:3128 is good
# average conn time: 4.17804722738
#
# 227 proxies left to filter
# 117.212.95.144:8080 is good
# average conn time: 4.18164830072
#
# 226 proxies left to filter
# 119.28.31.29:8888 is slow
#
# 225 proxies left to filter
# 138.201.72.117:80 is slow
#
# 224 proxies left to filter
# 103.239.253.255:8080 is slow
#
# 223 proxies left to filter
# 124.41.243.31:30978 is slow
#
# 222 proxies left to filter
# 103.234.254.10:80 is slow
#
# 221 proxies left to filter
# 128.199.155.60:31330 is slow
#
# 220 proxies left to filter
# 124.40.252.138:8080 is good
# average conn time: 4.18496038882
# 219 proxies left to filter
# 144.172.70.191:8888 is good
# average conn time: 4.18041824976
#
# 218 proxies left to filter
# 111.231.109.24:1080 is slow
#
# 217 proxies left to filter
# 110.50.84.95:8080 is good
# average conn time: 4.18166198254
#
# 216 proxies left to filter
# 103.197.92.174:8080 is slow
#
# 215 proxies left to filter
# 1.20.99.129:8080 is good
# average conn time: 4.18137740018
#
# 214 proxies left to filter
# 117.254.57.153:8080 is slow
#
# 213 proxies left to filter
# 125.21.43.82:8080 is slow
#
# 212 proxies left to filter
# 68.183.63.29:8080 is good
# average conn time: 4.17492963389
#
# 211 proxies left to filter
# 142.93.251.20:8080 is slow
#
# 210 proxies left to filter
# 103.124.137.3:8080 is slow
#
# 209 proxies left to filter
# 148.70.80.214:1080 is slow
#
# 208 proxies left to filter
# 148.70.204.205:1080 is slow
#
# 207 proxies left to filter
# 188.166.151.64:1080 is slow
#
# 206 proxies left to filter
# 122.136.212.132:53281 is slow
#
# 205 proxies left to filter
# 142.93.203.191:8080 is good
# average conn time: 4.16870697932
#
# 204 proxies left to filter
# 115.85.86.234:8080 is slow
#
# 203 proxies left to filter
# 138.122.108.202:8080 is slow
#
# 202 proxies left to filter
# 142.93.127.190:8080 is slow
#
# 201 proxies left to filter
# 139.255.40.130:8080 is slow
#
# 200 proxies left to filter
# 159.203.65.214:8080 is good
# average conn time: 4.1622628088
#
# 199 proxies left to filter
# 157.230.233.67:3128 is good
# average conn time: 4.15587333017
#
# 198 proxies left to filter
# 103.85.63.66:53281 is good
# average conn time: 4.1571562125
#
# 197 proxies left to filter
# 111.223.75.178:8080 is slow
#
# 196 proxies left to filter
# 103.219.163.50:8080 is good
# average conn time: 4.16276585447
#
# 195 proxies left to filter
# 14.207.26.152:8080 is good
# average conn time: 4.16460558811
#
# 194 proxies left to filter
# 103.216.82.50:53281 is good
# average conn time: 4.1646231685
#
# 193 proxies left to filter
# 116.209.59.67:9999 is slow
#
# 192 proxies left to filter
# 125.163.157.136:8080 is slow
#
# 191 proxies left to filter
# 103.106.3.97:8080 is slow
#
# 190 proxies left to filter
# 146.0.120.200:53281 is slow
#
# 189 proxies left to filter
# 134.175.102.48:1080 is slow
#
# 188 proxies left to filter
# 119.93.234.41:41731 is slow
#
# 187 proxies left to filter
# 103.88.234.58:34515 is slow
#
# 186 proxies left to filter
# 122.154.151.27:52187 is bad
#
# 185 proxies left to filter
# 1.20.99.85:56378 is good
# average conn time: 4.16620695161
#
# 184 proxies left to filter
# 117.254.57.209:8080 is slow
#
# 183 proxies left to filter
# 103.23.207.106:8080 is good
# average conn time: 4.17467974407
#
# 182 proxies left to filter
# 119.179.128.17:8060 is slow
#
# 181 proxies left to filter
# 101.108.80.252:8080 is slow
#
# 180 proxies left to filter
# 134.119.214.202:1080 is good
# average conn time: 4.17051781626
#
# 179 proxies left to filter
# 122.102.39.225:35564 is good
# average conn time: 4.1750605472
#
# 178 proxies left to filter
# 122.166.166.210:8080 is good
# average conn time: 4.18620114723
#
# 177 proxies left to filter
# 134.175.195.9:1080 is slow
#
# 176 proxies left to filter
# 103.70.204.65:46351 is bad
#
# 175 proxies left to filter
# 120.210.219.103:8080 is slow
#
# 174 proxies left to filter
# 138.68.174.231:3128 is slow
#
# 173 proxies left to filter
# 116.66.197.167:8080 is bad
#
# 172 proxies left to filter
# 125.164.178.242:8080 is good
# average conn time: 4.18840268841
#
# 171 proxies left to filter
# 118.99.118.91:8080 is good
# average conn time: 4.18738356581
#
# 170 proxies left to filter
# 103.210.120.42:44700 is good
# average conn time: 4.19344337833
#
# 169 proxies left to filter
# 139.255.74.125:8080 is good
# average conn time: 4.19126022556
#
# 168 proxies left to filter
# 1.20.100.165:61085 is slow
#
# 167 proxies left to filter
# 118.175.244.91:50507 is slow
#
# 166 proxies left to filter
# 144.172.70.191:8888 is good
# average conn time: 4.18499301824
#
# 165 proxies left to filter
# 151.106.10.54:8080 is bad
#
# 164 proxies left to filter
# 123.108.200.137:83 is good
# average conn time: 4.18586111338
#
# 163 proxies left to filter
# 148.70.206.60:8888 is slow
#
# 162 proxies left to filter
# 134.209.38.212:8080 is slow
#
# 161 proxies left to filter
# 138.0.77.30:80 is bad
#
# 160 proxies left to filter
# 132.255.50.76:49229 is bad
#
# 159 proxies left to filter
# 134.119.214.200:1080 is good
# average conn time: 4.18084683165
#
# 158 proxies left to filter
# 123.120.92.63:8060 is slow
#
# 157 proxies left to filter
# 119.42.118.21:8080 is slow
#
# 156 proxies left to filter
# 113.53.82.92:39726 is slow
#
# 155 proxies left to filter
# 111.118.128.123:8080 is good
# average conn time: 4.17867135925
#
# 154 proxies left to filter
# 103.127.171.26:8080 is slow
#
# 153 proxies left to filter
# 119.51.9.138:8080 is slow
#
# 152 proxies left to filter
# 103.78.80.146:8080 is good
# average conn time: 4.18780727524
#
# 151 proxies left to filter
# 142.93.109.250:3128 is good
# average conn time: 4.18243977007
#
# 150 proxies left to filter
# 151.106.8.237:1080 is slow
#
# 149 proxies left to filter
# 103.83.94.218:808 is slow
#
# 148 proxies left to filter
# 122.152.138.139:8118 is slow
#
# 147 proxies left to filter
# 207.180.242.44:8080 is slow
#
# 146 proxies left to filter
# 103.113.192.9:40761 is slow
#
# 145 proxies left to filter
# 119.252.175.38:4550 is good
# average conn time: 4.1813500248
#
# 144 proxies left to filter
# 144.217.229.154:1080 is slow
#
# 143 proxies left to filter
# 151.237.56.123:52488 is slow
#
# 142 proxies left to filter
# 121.122.90.195:3128 is slow
#
# 141 proxies left to filter
# 138.121.130.189:8080 is slow
#
# 140 proxies left to filter
# 112.133.218.84:8080 is slow
#
# 139 proxies left to filter
# 103.94.120.66:39112 is slow
#
# 138 proxies left to filter
# 146.158.1.63:53281 is bad
#
# 137 proxies left to filter
# 134.249.149.219:35795 is slow
#
# 136 proxies left to filter
# 103.67.196.217:8080 is slow
#
# 135 proxies left to filter
# 128.199.204.6:31330 is slow
#
# 134 proxies left to filter
# 110.172.135.234:52094 is slow
#
# 133 proxies left to filter
# 13.52.42.23:80 is slow
#
# 132 proxies left to filter
# 101.109.245.154:61888 is slow
#
# 131 proxies left to filter
# 134.119.205.246:8080 is slow
#
# 130 proxies left to filter
# 119.15.91.137:50712 is slow
#
# 129 proxies left to filter
# 139.5.71.126:23500 is good
# average conn time: 4.1795277706
#
# 128 proxies left to filter
# 123.200.17.166:8080 is slow
#
# 127 proxies left to filter
# 150.95.151.68:8187 is slow
#
# 126 proxies left to filter
# 103.43.43.48:41375 is slow
#
# 125 proxies left to filter
# 134.175.22.175:1080 is slow
#
# 124 proxies left to filter
# 134.209.24.138:8080 is good
# average conn time: 4.17395971532
#
# 123 proxies left to filter
# 118.175.93.112:52693 is good
# average conn time: 4.17385238295
#
# 122 proxies left to filter
# 144.217.69.152:1080 is slow
#
# 121 proxies left to filter
# 103.107.68.210:8080 is bad
#
# 120 proxies left to filter
# 134.119.188.146:8080 is slow
#
# 119 proxies left to filter
# 129.204.62.235:1080 is slow
#
# 118 proxies left to filter
# 103.103.33.166:8080 is slow
#
# 117 proxies left to filter
# 128.140.225.49:80 is slow
#
# 116 proxies left to filter
# 14.207.28.166:8080 is good
# average conn time: 4.18080385766
#
# 115 proxies left to filter
# 157.230.135.142:80 is slow
#
# 114 proxies left to filter
# 138.122.222.64:8080 is good
# average conn time: 4.1882441498
#
# 113 proxies left to filter
# 131.0.160.150:8080 is good
# average conn time: 4.18912837963
#
# 112 proxies left to filter
# 103.126.148.162:8080 is good
# average conn time: 4.19282975076
#
# 111 proxies left to filter
# 34.74.71.134:3128 is slow
#
# 110 proxies left to filter
# 117.196.236.219:45560 is slow
#
# 109 proxies left to filter
# 118.172.227.89:31083 is good
# average conn time: 4.1958359139
#
# 108 proxies left to filter
# 151.106.8.234:1080 is slow
#
# 107 proxies left to filter
# 110.235.246.26:52136 is bad
#
# 106 proxies left to filter
# 120.50.10.85:8080 is good
# average conn time: 4.19535038862
#
# 105 proxies left to filter
# 125.21.43.122:8080 is slow
#
# 104 proxies left to filter
# 107.172.2.98:80 is slow
#
# 103 proxies left to filter
# 23.97.191.74:80 is slow
#
# 102 proxies left to filter
# 103.224.186.56:43896 is good
# average conn time: 4.1992165787
#
# 101 proxies left to filter
# 128.199.154.158:31330 is bad
#
# 100 proxies left to filter
# 103.122.84.163:50500 is slow
#
# 99 proxies left to filter
# 103.92.152.198:3128 is slow
#
# 98 proxies left to filter
# 146.120.227.1:8080 is slow
#
# 97 proxies left to filter
# 148.70.112.15:1080 is slow
#
# 96 proxies left to filter
# 111.231.105.136:1080 is slow
#
# 95 proxies left to filter
# 124.41.211.211:32070 is bad
#
# 94 proxies left to filter
# 117.197.40.105:31020 is slow
# 93 proxies left to filter
# 112.247.180.30:8060 is slow
#
# 92 proxies left to filter
# 120.234.63.196:3128 is slow
#
# 91 proxies left to filter
# 151.106.10.102:8080 is slow
#
# 90 proxies left to filter
# 103.205.177.113:3128 is bad
#
# 89 proxies left to filter
# 103.19.110.177:8080 is good
# average conn time: 4.20267033427
#
# 88 proxies left to filter
# 134.119.188.153:8080 is slow
#
# 87 proxies left to filter
# 115.79.208.56:38351 is bad
#
# 86 proxies left to filter
# 103.87.104.137:8080 is good
# average conn time: 4.20137579362
#
# 85 proxies left to filter
# 117.4.80.17:36120 is bad
#
# 84 proxies left to filter
# 139.5.26.27:53281 is slow
#
# 83 proxies left to filter
# 103.248.14.178:32400 is slow
#
# 82 proxies left to filter
# 118.99.103.116:8080 is good
# average conn time: 4.20083465472
#
# 81 proxies left to filter
# 1.20.100.42:41089 is slow
#
# 80 proxies left to filter
# 101.255.125.10:8080 is bad
#
# 79 proxies left to filter
# 109.111.94.250:53281 is good
# average conn time: 4.20285057872
#
# 78 proxies left to filter
# 110.74.214.27:37327 is good
# average conn time: 4.20109954178
#
# 77 proxies left to filter
# 109.200.156.102:8080 is good
# average conn time: 4.2020977265
#
# 76 proxies left to filter
# 103.87.16.2:80 is slow
#
# 75 proxies left to filter
# 101.251.215.232:8081 is slow
#
# 74 proxies left to filter
# 118.175.93.157:49498 is bad
#
# 73 proxies left to filter
# 1.179.188.205:58505 is good
# average conn time: 4.20059698727
#
# 72 proxies left to filter
# 118.174.232.185:54023 is good
# average conn time: 4.20184956739
#
# 71 proxies left to filter
# 145.239.7.105:3128 is good
# average conn time: 4.19648540057
#
# 70 proxies left to filter
# 144.217.229.158:1080 is slow
#
# 69 proxies left to filter
# 54.39.24.35:3128 is slow
#
# 68 proxies left to filter
# 142.93.125.101:3128 is good
# average conn time: 4.19045447453
#
# 67 proxies left to filter
# 104.43.251.65:80 is slow
#
# 66 proxies left to filter
# 103.231.218.30:32908 is good
# average conn time: 4.18760630664
#
# 65 proxies left to filter
# 145.239.169.43:1080 is slow
#
# 64 proxies left to filter
# 157.230.135.142:8080 is slow
#
# 63 proxies left to filter
# 1.0.250.98:8080 is slow
#
# 62 proxies left to filter
# 110.232.89.202:3128 is slow
#
# 61 proxies left to filter
# 103.75.32.217:53012 is good
# average conn time: 4.19180625226
#
# 60 proxies left to filter
# 103.206.130.118:8080 is slow
#
# 59 proxies left to filter
# 109.238.222.5:49186 is slow
#
# 58 proxies left to filter
# 134.175.154.217:1080 is slow
#
# 57 proxies left to filter
# 109.245.222.53:56278 is bad
#
# 56 proxies left to filter
# 119.82.253.63:34110 is slow
#
# 55 proxies left to filter
# 188.166.156.70:8080 is good
# average conn time: 4.18642286754
#
# 54 proxies left to filter
# 140.143.169.57:1080 is slow
#
# 53 proxies left to filter
# 14.207.137.56:8080 is slow
#
# 52 proxies left to filter
# 134.119.214.194:8080 is slow
#
# 51 proxies left to filter
# 117.2.155.139:9090 is slow
#
# 50 proxies left to filter
# 151.106.8.234:8080 is slow
#
# 49 proxies left to filter
# 118.172.201.48:32775 is slow
#
# 48 proxies left to filter
# 117.191.11.105:8080 is slow
#
# 47 proxies left to filter
# 134.119.207.10:1080 is slow
#
# 46 proxies left to filter
# 134.209.99.199:8080 is slow
#
# 45 proxies left to filter
# 110.235.198.25:59599 is slow
#
# 44 proxies left to filter
# 104.248.123.136:8080 is slow
#
# 43 proxies left to filter
# 114.130.31.157:59470 is slow
#
# 42 proxies left to filter
# 198.199.122.91:3128 is slow
#
# 41 proxies left to filter
# 128.199.164.241:8080 is good
# average conn time: 4.18308038851
#
# 40 proxies left to filter
# 125.26.109.128:60442 is bad
#
# 39 proxies left to filter
# 152.136.49.128:1080 is slow
#
# 38 proxies left to filter
# 102.164.248.51:63238 is slow
#
# 37 proxies left to filter
# 103.111.55.18:55147 is slow
#
# 36 proxies left to filter
# 152.136.73.220:1080 is slow
#
# 35 proxies left to filter
# 111.125.143.143:8080 is slow
#
# 34 proxies left to filter
# 103.23.103.203:32137 is good
# average conn time: 4.18432889865
#
# 33 proxies left to filter
# 129.205.138.186:52404 is bad
#
# 32 proxies left to filter
# 104.248.8.35:80 is slow
#
# 31 proxies left to filter
# 103.75.161.38:21776 is bad
#
# 30 proxies left to filter
# 101.51.103.131:8080 is good
# average conn time: 4.18088990056
#
# 29 proxies left to filter
# 118.174.233.21:31031 is bad
#
# 28 proxies left to filter
# 124.41.211.132:60924 is good
# average conn time: 4.18268164901
#
# 27 proxies left to filter
# 134.209.123.111:21 is slow
#
# 26 proxies left to filter
# 152.136.43.228:1080 is slow
#
# 25 proxies left to filter
# 103.105.239.1:37021 is slow
#
# 24 proxies left to filter
# 1.10.187.60:55266 is good
# average conn time: 4.18382075224
#
# 23 proxies left to filter
# 112.109.198.118:3128 is bad
#
# 22 proxies left to filter
# 103.56.207.233:8080 is good
# average conn time: 4.18359306281
#
# 21 proxies left to filter
# 150.107.207.137:61954 is bad
#
# 20 proxies left to filter
# 103.228.142.152:8080 is slow
#
# 19 proxies left to filter
# 119.2.53.146:8888 is good
# average conn time: 4.18575321081
#
# 18 proxies left to filter
# 1.196.160.79:9999 is slow
#
# 17 proxies left to filter
# 14.102.50.28:37191 is slow
#
# 16 proxies left to filter
# 128.199.232.195:8080 is bad
#
# 15 proxies left to filter
# 103.75.239.229:8080 is bad
#
# 14 proxies left to filter
# 131.161.45.242:61722 is slow
#
# 13 proxies left to filter
# 114.67.235.233:3128 is bad
#
# 12 proxies left to filter
# 103.53.111.67:41834 is slow
#
# 11 proxies left to filter
# 113.53.91.12:53281 is good
# average conn time: 4.18357002917
#
# 10 proxies left to filter
# 119.54.236.58:8080 is slow
#
# 9 proxies left to filter
# 103.194.251.43:33649 is bad
#
# 8 proxies left to filter
# 109.205.116.50:56932 is slow
#
# 7 proxies left to filter
# 125.166.134.124:8080 is slow
#
# 6 proxies left to filter
# 123.108.201.2:48209 is good
# average conn time: 4.18893396945
#
# 5 proxies left to filter
# 134.209.84.214:6666 is slow
#
# 4 proxies left to filter
# 105.234.154.230:55472 is bad
#
# 3 proxies left to filter
# 1.20.103.248:52574 is good
# average conn time: 4.18564717603
#
# 2 proxies left to filter
# 110.164.91.50:51065 is bad
#
# 1 proxies left to filter
# 122.252.250.0:8080 is good
# average conn time: 4.18625511204
#
# average proxy time:4.18625511204

# %% [markdown]
# # Filter the Http proxies

# %%
url = 'https://www.proxy-list.download/HTTP'
filterProxys(url)
# Out:
# No proxies to text

# %% [markdown]
# # Overwrite the source text file with partially filtered or empty ip list

# %%
# overwrite the existing source of https proxy data with the filtered data
with open('proxyLists/https_proxys_US_part_0.txt', "w") as output:
    for line in testProxies['https']:
        output.write("%s\n" % line)

# %%
# overwrite the existing source of http proxy data with the filtered data
with open('proxyLists/http_proxys_US_part_0.txt', "w") as output:
    for line in testProxies['http']:
        output.write("%s\n" % line)

# %% [markdown]
# # Get all proxys that had connections times less than one second

# %%
df = pd.DataFrame(goodProxy['https'])
fast_proxies_https = list(df['proxy'][df['time']<1])

# %%
df = pd.DataFrame(goodProxy['http'])
fast_proxies_http = list(df['proxy'][df['time']<1])

# %% [markdown]
# # Import the single filtered files of proxys that had connections times less than one second and combine with the new filtered proxys

# %%
# Import
try:
    existing_https_proxies = list(pd.read_csv('../filtered_https_proxys_US.txt', header = None)[0])
except: #If the file is empty
    existing_https_proxies = []
try:
    existing_http_proxies = list(pd.read_csv('../filtered_http_proxys_US.txt', header = None)[0])
except: #If the file is empty
    existing_http_proxies = []

# %%
# add the new proxys to the existing ones if they are not already there
[existing_https_proxies.append(x) 
 for x in fast_proxies_https 
 if x not in existing_https_proxies]

[existing_http_proxies.append(x) 
 for x in fast_proxies_http 
 if x not in existing_http_proxies]
# Out:
# []

# %% [markdown]
# # Rewrite the final proxys text file with the new and old filtered proxies

# %%
#append filtered http proxys to existing .txt file
with open('../filtered_http_proxys_US.txt', "w") as output:
    for line in existing_http_proxies:
        output.write("%s\n" % line)

# %%
# append filtered https proxies to existing text file
with open('../filtered_https_proxys_US.txt', "w") as output:
    for line in existing_https_proxies:
        output.write("%s\n" % line)
