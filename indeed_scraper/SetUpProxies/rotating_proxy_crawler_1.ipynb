# %% [markdown]
# # Ref: https://codelike.pro/create-a-crawler-with-rotating-ip-proxy-in-python/

# %% [markdown]
# # Import Libraries

# %%
# Get the text data from the first job posting
import pandas as pd
import requests # For website connections
from bs4 import BeautifulSoup # For HTML parsing
import time
from fake_useragent import UserAgent
import random

# %% [markdown]
# # Import the Data

# %%
try:
    Https_txt_file = 'proxyLists/https_proxys_US_part_1.txt'
    #Download New HTTPS IPs .txt file from https://www.proxy-list.download/HTTPS
    https_proxys = pd.read_csv(Https_txt_file, sep=" ", header=None)
    #Convert to array
    https_proxys = https_proxys[0].values
    #Convert to list
    https_proxys = list(https_proxys)
except:
    print('There are no https proxies to import')
    
try:
    Http_txt_file = 'proxyLists/http_proxys_US_part_1.txt'
    #Download New HTTPS IPs .txt file from https://www.proxy-list.download/HTTP
    http_proxys = pd.read_csv(Http_txt_file, sep=" ", header=None)
    #Convert to array
    http_proxys = http_proxys[0].values
    #Convert to list
    http_proxys = list(http_proxys)
except:
    print('There are no http proxies to import')

# %%
# Make a dictionary for the proxies to test
testProxies = {'https':https_proxys,'http':http_proxys}

# %%
# Retrieve a random user-agent
header = {}
def randHeader():
    ua = UserAgent()
    header['User-Agent'] = ua.random

# %%
# Retrieve a random index for the https proxy
def randomIndex(conn_type):
    num = random.randint(0, len(testProxies[conn_type]) - 1)
    return num

# %%
proxyDict = {}
def randProx(conn_type):
    # Choose a single random proxy to use
    proxy_index = randomIndex(conn_type)
    proxy = testProxies[conn_type][proxy_index]
    proxyDict[conn_type] = conn_type +'://'+ proxy
    return proxy_index

# %%
# Initialize Dictionary for good proxies 
good_http_proxy = []
good_https_proxy = []
conn_time_http = []
conn_time_https = []
goodProxy = {'https':{'proxy':good_https_proxy,'time':conn_time_https},
             'http':{'proxy':good_http_proxy,'time':conn_time_http}}

# %%
def filterProxys(url):
    timer = 0
    count = 0
    if url[0:5] == 'http:':
        conn_type = 'http'
        
    elif url[0:5] == 'https':
        conn_type = 'https'

    total_proxies = len(testProxies[conn_type])
    for n in range(len(testProxies[conn_type])):
        time.sleep(1)
        print(str(total_proxies-n)+' proxies left to filter')
            
        try:
            # Choose a random header
            randHeader()
            
        except:
            # Sometimes the header reassignment function returns an error
            pass
            
        # Choose a random proxy
        proxy_index = randProx(conn_type)

        try:
            # Try to connect to the url
            t1 = time.time()
            soup = requests.get(url,headers=header,proxies=proxyDict,timeout=5)
            t2 = time.time()
            t = t2-t1
                
            if  str(soup) == '<Response [200]>': # the connection is successful when <Response [200]> is returned
                print(str(testProxies[conn_type][proxy_index])+' is good')
                del testProxies[conn_type][proxy_index]
                timer += t
                count += 1
                print('average conn time: '+str(timer/count)+'\n')
                #Add to the good proxy and its connection time
                goodProxy[conn_type]['proxy'].append(proxyDict[conn_type])
                goodProxy[conn_type]['time'].append(t)
                    
            elif str(soup) != '<Response [200]>': #The connection was bad
                print(str(testProxies[conn_type][proxy_index])+' is bad'+'\n')
                del testProxies[conn_type][proxy_index]
                    
                    
        except: # The connection took too long 
            print(str(testProxies[conn_type][proxy_index])+' is slow'+'\n')
            del testProxies[conn_type][proxy_index]
    try:
        print('average proxy time:'+str(timer/count))
    except:
        print('No proxies to text')

# %% [markdown]
# # Filter the Https proxies

# %%
url = 'https://www.proxy-list.download/HTTPS'
filterProxys(url)
# Out:
# 2030 proxies left to filter
# 197.216.2.14:8080 is good
# average conn time: 2.87374305725
#
# 2029 proxies left to filter
# 177.66.67.185:8080 is good
# average conn time: 5.2086070776
#
# 2028 proxies left to filter
# 170.239.85.245:80 is slow
#
# 2027 proxies left to filter
# 197.221.89.70:8080 is good
# average conn time: 4.47062238057
#
# 2026 proxies left to filter
# 180.92.238.153:8080 is slow
#
# 2025 proxies left to filter
# 177.124.184.72:55072 is bad
#
# 2024 proxies left to filter
# 191.102.85.241:9000 is good
# average conn time: 4.86242878437
#
# 2023 proxies left to filter
# 152.136.66.109:1080 is slow
#
# 2022 proxies left to filter
# 180.183.115.253:8080 is slow
#
# 2021 proxies left to filter
# 175.142.248.161:53281 is good
# average conn time: 4.39915623665
#
# 2020 proxies left to filter
# 186.24.11.165:8080 is bad
#
# 2019 proxies left to filter
# 181.239.46.149:8080 is slow
#
# 2018 proxies left to filter
# 173.212.202.65:80 is slow
#
# 2017 proxies left to filter
# 190.38.65.91:8080 is slow
#
# 2016 proxies left to filter
# 177.125.243.12:3128 is good
# average conn time: 4.56057751179
#
# 2015 proxies left to filter
# 180.214.247.82:8080 is good
# average conn time: 4.83787557057
#
# 2014 proxies left to filter
# 193.112.38.166:1080 is slow
#
# 2013 proxies left to filter
# 193.112.28.205:1080 is slow
#
# 2012 proxies left to filter
# 159.138.20.247:80 is slow
#
# 2011 proxies left to filter
# 178.151.205.154:53040 is bad
#
# 2010 proxies left to filter
# 197.216.2.11:8080 is good
# average conn time: 4.69949275255
#
# 2009 proxies left to filter
# 180.92.238.109:23500 is slow
#
# 2008 proxies left to filter
# 182.53.206.138:8080 is slow
#
# 2007 proxies left to filter
# 165.22.250.224:8080 is good
# average conn time: 4.59587788582
#
# 2006 proxies left to filter
# 189.45.37.250:8080 is bad
#
# 2005 proxies left to filter
# 154.8.193.105:1080 is slow
#
# 2004 proxies left to filter
# 171.244.166.30:8080 is slow
#
# 2003 proxies left to filter
# 165.227.107.218:3128 is slow
#
# 2002 proxies left to filter
# 157.230.33.168:3128 is bad
#
# 2001 proxies left to filter
# 193.86.23.24:8080 is slow
#
# 2000 proxies left to filter
# 181.129.47.162:30454 is slow
#
# 1999 proxies left to filter
# 165.255.74.32:8080 is slow
#
# 1998 proxies left to filter
# 160.242.17.178:45218 is slow
#
# 1997 proxies left to filter
# 197.232.47.83:58680 is bad
#
# 1996 proxies left to filter
# 176.31.69.181:1080 is slow
#
# 1995 proxies left to filter
# 178.32.204.97:80 is slow
#
# 1994 proxies left to filter
# 180.180.218.226:32401 is bad
#
# 1993 proxies left to filter
# 191.102.78.190:9991 is slow
#
# 1992 proxies left to filter
# 186.211.106.227:34334 is good
# average conn time: 4.53716380596
#
# 1991 proxies left to filter
# 177.107.73.177:63141 is good
# average conn time: 4.42528809201
#
# 1990 proxies left to filter
# 157.230.39.180:8080 is good
# average conn time: 4.20538075765
#
# 1989 proxies left to filter
# 169.239.236.27:38302 is slow
#
# 1988 proxies left to filter
# 183.89.6.23:8080 is slow
#
# 1987 proxies left to filter
# 157.230.222.118:8080 is slow
#
# 1986 proxies left to filter
# 182.253.112.179:8080 is good
# average conn time: 4.30597923352
#
# 1985 proxies left to filter
# 164.77.134.10:8080 is good
# average conn time: 4.42936457906
#
# 1984 proxies left to filter
# 196.27.106.112:8080 is good
# average conn time: 4.6808298111
#
# 1983 proxies left to filter
# 197.234.56.89:8083 is slow
#
# 1982 proxies left to filter
# 167.99.165.114:8080 is slow
#
# 1981 proxies left to filter
# 195.206.42.41:49083 is slow
#
# 1980 proxies left to filter
# 189.7.17.100:8080 is good
# average conn time: 5.09007664025
#
# 1979 proxies left to filter
# 176.37.50.238:47260 is slow
#
# 1978 proxies left to filter
# 177.92.17.50:20183 is good
# average conn time: 5.04723935969
#
# 1977 proxies left to filter
# 195.154.106.167:80 is slow
#
# 1976 proxies left to filter
# 192.141.12.70:8080 is slow
#
# 1975 proxies left to filter
# 194.114.139.244:6575 is slow
#
# 1974 proxies left to filter
# 159.89.141.7:8080 is slow
#
# 1973 proxies left to filter
# 175.100.185.151:53281 is slow
#
# 1972 proxies left to filter
# 167.86.97.101:80 is slow
#
# 1971 proxies left to filter
# 200.187.177.105:20183 is good
# average conn time: 4.89134183195
#
# 1970 proxies left to filter
# 152.136.73.65:1080 is slow
#
# 1969 proxies left to filter
# 195.138.83.218:53281 is good
# average conn time: 4.75931816352
#
# 1968 proxies left to filter
# 191.242.230.135:8080 is good
# average conn time: 4.6268276453
#
# 1967 proxies left to filter
# 196.2.15.68:8080 is slow
#
# 1966 proxies left to filter
# 170.81.108.142:50659 is bad
#
# 1965 proxies left to filter
# 181.196.138.218:31630 is good
# average conn time: 4.87991914295
#
# 1964 proxies left to filter
# 200.69.83.50:9991 is good
# average conn time: 4.98190190575
#
# 1963 proxies left to filter
# 181.129.74.218:8080 is good
# average conn time: 4.86591981805
#
# 1962 proxies left to filter
# 200.69.69.162:8080 is slow
#
# 1961 proxies left to filter
# 169.239.45.37:8080 is slow
#
# 1960 proxies left to filter
# 180.183.139.205:8080 is slow
#
# 1959 proxies left to filter
# 200.69.236.53:8080 is slow
#
# 1958 proxies left to filter
# 193.77.45.19:21776 is bad
#
# 1957 proxies left to filter
# 180.180.218.152:60327 is good
# average conn time: 4.87613449494
#
# 1956 proxies left to filter
# 196.202.153.67:3128 is slow
#
# 1955 proxies left to filter
# 171.255.192.118:8080 is slow
#
# 1954 proxies left to filter
# 186.96.102.254:9991 is slow
#
# 1953 proxies left to filter
# 168.253.115.14:8080 is slow
#
# 1952 proxies left to filter
# 187.60.163.242:8081 is slow
#
# 1951 proxies left to filter
# 180.247.5.10:8080 is slow
#
# 1950 proxies left to filter
# 189.196.168.78:30880 is slow
#
# 1949 proxies left to filter
# 192.140.28.69:8080 is slow
#
# 1948 proxies left to filter
# 185.15.108.152:8080 is bad
#
# 1947 proxies left to filter
# 181.129.133.74:56827 is slow
#
# 1946 proxies left to filter
# 157.230.157.60:8080 is slow
#
# 1945 proxies left to filter
# 186.226.175.116:8080 is good
# average conn time: 4.85082659721
#
# 1944 proxies left to filter
# 189.5.233.5:8080 is good
# average conn time: 4.98470919866
#
# 1943 proxies left to filter
# 195.29.239.34:57278 is good
# average conn time: 4.97673074404
#
# 1942 proxies left to filter
# 181.40.122.102:8080 is good
# average conn time: 4.94211700133
#
# 1941 proxies left to filter
# 172.104.111.191:8082 is slow
#
# 1940 proxies left to filter
# 192.162.62.197:59246 is slow
#
# 1939 proxies left to filter
# 182.253.101.98:8080 is bad
#
# 1938 proxies left to filter
# 158.255.51.213:49031 is slow
#
# 1937 proxies left to filter
# 186.122.186.223:8080 is slow
#
# 1936 proxies left to filter
# 157.230.80.42:80 is slow
#
# 1935 proxies left to filter
# 170.239.87.226:80 is slow
#
# 1934 proxies left to filter
# 194.114.139.81:6575 is slow
#
# 1933 proxies left to filter
# 191.36.158.170:8080 is slow
#
# 1932 proxies left to filter
# 177.126.216.149:57128 is good
# average conn time: 5.00041500453
#
# 1931 proxies left to filter
# 201.205.227.144:80 is slow
#
# 1930 proxies left to filter
# 185.32.181.153:8080 is good
# average conn time: 4.95174694061
#
# 1929 proxies left to filter
# 159.224.44.19:60767 is slow
#
# 1928 proxies left to filter
# 171.6.174.240:8080 is slow
#
# 1927 proxies left to filter
# 182.253.153.10:8080 is slow
#
# 1926 proxies left to filter
# 186.64.121.220:8080 is slow
#
# 1925 proxies left to filter
# 186.219.183.254:8080 is slow
#
# 1924 proxies left to filter
# 190.52.34.67:8082 is slow
#
# 1923 proxies left to filter
# 182.52.51.33:56059 is bad
#
# 1922 proxies left to filter
# 183.89.27.15:8080 is slow
#
# 1921 proxies left to filter
# 194.125.255.126:3128 is slow
#
# 1920 proxies left to filter
# 201.158.63.174:55287 is slow
#
# 1919 proxies left to filter
# 150.107.243.18:41787 is bad
#
# 1918 proxies left to filter
# 198.50.145.28:80 is slow
#
# 1917 proxies left to filter
# 198.27.67.35:3128 is good
# average conn time: 4.83116907458
#
# 1916 proxies left to filter
# 182.254.204.42:1080 is slow
#
# 1915 proxies left to filter
# 192.99.191.235:1080 is slow
#
# 1914 proxies left to filter
# 160.119.129.94:8080 is slow
#
# 1913 proxies left to filter
# 162.248.247.153:32592 is bad
#
# 1912 proxies left to filter
# 176.192.16.203:8081 is good
# average conn time: 4.79554769397
#
# 1911 proxies left to filter
# 180.250.182.50:8080 is slow
#
# 1910 proxies left to filter
# 187.4.249.6:80 is slow
#
# 1909 proxies left to filter
# 188.212.28.160:8080 is good
# average conn time: 4.69359228105
#
# 1908 proxies left to filter
# 187.115.10.50:20183 is good
# average conn time: 4.65195471399
#
# 1907 proxies left to filter
# 159.65.120.133:3128 is slow
#
# 1906 proxies left to filter
# 186.188.220.58:58187 is slow
# 1905 proxies left to filter
# 185.162.128.135:9016 is good
# average conn time: 4.56993840763
#
# 1904 proxies left to filter
# 159.89.190.135:8080 is slow
#
# 1903 proxies left to filter
# 187.73.106.26:61569 is slow
#
# 1902 proxies left to filter
# 183.89.75.146:8080 is slow
#
# 1901 proxies left to filter
# 160.16.226.83:3128 is good
# average conn time: 4.47791256507
#
# 1900 proxies left to filter
# 194.114.139.51:6575 is slow
#
# 1899 proxies left to filter
# 201.148.238.222:34646 is slow
#
# 1898 proxies left to filter
# 162.245.213.92:54494 is bad
#
# 1897 proxies left to filter
# 202.138.254.188:8080 is slow
#
# 1896 proxies left to filter
# 191.252.186.238:8080 is slow
#
# 1895 proxies left to filter
# 198.50.172.161:1080 is slow
#
# 1894 proxies left to filter
# 157.230.228.82:8080 is slow
#
# 1893 proxies left to filter
# 185.146.112.142:8080 is good
# average conn time: 4.43034979459
#
# 1892 proxies left to filter
# 185.93.240.132:8080 is good
# average conn time: 4.36044764519
#
# 1891 proxies left to filter
# 192.99.191.237:1080 is slow
#
# 1890 proxies left to filter
# 181.129.52.154:61976 is slow
#
# 1889 proxies left to filter
# 187.185.15.35:53281 is slow
#
# 1888 proxies left to filter
# 181.211.57.10:53281 is good
# average conn time: 4.31586552278
#
# 1887 proxies left to filter
# 197.234.55.9:8083 is slow
#
# 1886 proxies left to filter
# 193.112.79.182:1080 is slow
#
# 1885 proxies left to filter
# 176.113.116.70:55589 is bad
#
# 1884 proxies left to filter
# 186.216.81.21:31773 is bad
#
# 1883 proxies left to filter
# 188.168.75.254:56899 is slow
#
# 1882 proxies left to filter
# 201.54.31.77:55282 is bad
#
# 1881 proxies left to filter
# 151.106.10.108:8080 is slow
#
# 1880 proxies left to filter
# 187.111.112.10:8080 is slow
#
# 1879 proxies left to filter
# 192.99.70.52:8080 is slow
#
# 1878 proxies left to filter
# 202.142.185.150:53281 is slow
#
# 1877 proxies left to filter
# 159.138.3.119:80 is slow
#
# 1876 proxies left to filter
# 178.32.80.237:1080 is slow
#
# 1875 proxies left to filter
# 185.132.133.211:8080 is good
# average conn time: 4.36085228324
#
# 1874 proxies left to filter
# 182.253.197.60:8080 is slow
#
# 1873 proxies left to filter
# 191.7.209.196:54191 is bad
#
# 1872 proxies left to filter
# 197.234.56.169:8083 is slow
#
# 1871 proxies left to filter
# 178.124.152.84:53879 is slow
#
# 1870 proxies left to filter
# 177.193.9.203:3128 is slow
#
# 1869 proxies left to filter
# 168.90.168.43:20183 is slow
#
# 1868 proxies left to filter
# 180.180.218.227:48768 is good
# average conn time: 4.31311673653
#
# 1867 proxies left to filter
# 196.44.105.90:8080 is slow
#
# 1866 proxies left to filter
# 195.201.106.71:8080 is good
# average conn time: 4.32327538445
#
# 1865 proxies left to filter
# 151.236.203.24:8080 is good
# average conn time: 4.28641655833
#
# 1864 proxies left to filter
# 143.137.149.21:48098 is slow
#
# 1863 proxies left to filter
# 194.114.139.98:6575 is slow
#
# 1862 proxies left to filter
# 198.50.172.166:1080 is slow
#
# 1861 proxies left to filter
# 178.155.105.14:8081 is slow
#
# 1860 proxies left to filter
# 200.0.46.50:37232 is bad
#
# 1859 proxies left to filter
# 183.88.240.126:8080 is slow
#
# 1858 proxies left to filter
# 195.62.70.22:8080 is good
# average conn time: 4.32346238331
#
# 1857 proxies left to filter
# 185.252.103.103:80 is slow
#
# 1856 proxies left to filter
# 176.31.69.182:1080 is slow
#
# 1855 proxies left to filter
# 188.152.10.230:34674 is bad
#
# 1854 proxies left to filter
# 182.53.205.102:8080 is slow
#
# 1853 proxies left to filter
# 177.38.181.82:8080 is slow
#
# 1852 proxies left to filter
# 190.144.3.137:8080 is slow
#
# 1851 proxies left to filter
# 198.50.172.165:1080 is slow
#
# 1850 proxies left to filter
# 200.150.86.138:44677 is good
# average conn time: 4.34488433202
#
# 1849 proxies left to filter
# 154.118.52.216:55877 is slow
#
# 1848 proxies left to filter
# 197.255.152.43:59270 is bad
#
# 1847 proxies left to filter
# 178.32.80.235:1080 is slow
#
# 1846 proxies left to filter
# 180.250.54.27:53281 is good
# average conn time: 4.34230750022
#
# 1845 proxies left to filter
# 171.100.2.154:8080 is slow
#
# 1844 proxies left to filter
# 180.180.156.45:50597 is slow
#
# 1843 proxies left to filter
# 200.216.227.141:53281 is good
# average conn time: 4.32843601957
#
# 1842 proxies left to filter
# 181.171.245.50:8080 is good
# average conn time: 4.29012062152
#
# 1841 proxies left to filter
# 154.79.242.86:34771 is bad
#
# 1840 proxies left to filter
# 178.47.139.50:8080 is good
# average conn time: 4.39889268972
#
# 1839 proxies left to filter
# 194.114.139.128:6575 is slow
#
# 1838 proxies left to filter
# 182.176.103.68:8080 is slow
#
# 1837 proxies left to filter
# 169.255.126.231:55325 is slow
#
# 1836 proxies left to filter
# 186.64.121.235:3128 is slow
#
# 1835 proxies left to filter
# 183.82.35.136:41269 is slow
#
# 1834 proxies left to filter
# 200.195.15.150:8080 is slow
#
# 1833 proxies left to filter
# 186.178.10.138:8080 is slow
#
# 1832 proxies left to filter
# 177.73.170.149:8080 is slow
#
# 1831 proxies left to filter
# 191.6.228.1:53281 is good
# average conn time: 4.43721063614
#
# 1830 proxies left to filter
# 158.195.148.169:35558 is slow
#
# 1829 proxies left to filter
# 165.22.250.226:8080 is good
# average conn time: 4.38647340793
#
# 1828 proxies left to filter
# 193.194.123.62:80 is slow
#
# 1827 proxies left to filter
# 190.185.114.93:8080 is good
# average conn time: 4.32422586129
#
# 1826 proxies left to filter
# 189.199.112.138:8080 is slow
#
# 1825 proxies left to filter
# 201.148.238.232:48688 is slow
#
# 1824 proxies left to filter
# 181.52.85.249:30950 is slow
#
# 1823 proxies left to filter
# 192.144.139.130:1080 is slow
#
# 1822 proxies left to filter
# 200.123.6.26:8080 is good
# average conn time: 4.33910893944
#
# 1821 proxies left to filter
# 157.230.33.25:3128 is bad
#
# 1820 proxies left to filter
# 178.32.80.232:1080 is slow
#
# 1819 proxies left to filter
# 18.217.49.2:8080 is slow
#
# 1818 proxies left to filter
# 180.180.218.201:30611 is good
# average conn time: 4.3974076068
#
# 1817 proxies left to filter
# 159.89.190.135:80 is slow
#
# 1816 proxies left to filter
# 159.203.169.239:3128 is slow
#
# 1815 proxies left to filter
# 165.22.32.67:1080 is slow
#
# 1814 proxies left to filter
# 197.210.130.46:54032 is slow
#
# 1813 proxies left to filter
# 170.80.149.240:8080 is good
# average conn time: 4.42422523499
#
# 1812 proxies left to filter
# 193.86.229.230:8080 is bad
#
# 1811 proxies left to filter
# 170.231.128.35:8080 is slow
#
# 1810 proxies left to filter
# 186.96.121.178:44554 is slow
#
# 1809 proxies left to filter
# 169.239.46.169:54292 is slow
#
# 1808 proxies left to filter
# 185.15.90.82:49468 is slow
#
# 1807 proxies left to filter
# 177.87.14.83:42245 is slow
#
# 1806 proxies left to filter
# 182.53.96.215:34627 is good
# average conn time: 4.42105624931
#
# 1805 proxies left to filter
# 191.241.38.42:42104 is good
# average conn time: 4.4099394564
#
# 1804 proxies left to filter
# 175.100.5.52:61822 is slow
#
# 1803 proxies left to filter
# 186.96.99.202:53281 is bad
#
# 1802 proxies left to filter
# 189.212.103.237:8080 is good
# average conn time: 4.34796712316
#
# 1801 proxies left to filter
# 170.82.228.42:8080 is slow
#
# 1800 proxies left to filter
# 157.230.156.47:8080 is slow
#
# 1799 proxies left to filter
# 167.114.67.78:80 is slow
#
# 1798 proxies left to filter
# 177.11.113.156:8080 is slow
#
# 1797 proxies left to filter
# 178.20.137.178:43980 is bad
#
# 1796 proxies left to filter
# 187.109.181.75:8080 is slow
#
# 1795 proxies left to filter
# 198.199.122.218:3128 is slow
#
# 1794 proxies left to filter
# 179.234.156.137:3128 is slow
#
# 1793 proxies left to filter
# 187.111.192.198:45826 is bad
#
# 1792 proxies left to filter
# 170.247.156.71:8080 is good
# average conn time: 4.37259142278
#
# 1791 proxies left to filter
# 186.138.166.96:50219 is slow
#
# 1790 proxies left to filter
# 176.114.16.171:8080 is slow
#
# 1789 proxies left to filter
# 188.247.39.14:53703 is bad
#
# 1788 proxies left to filter
# 187.45.127.87:20183 is slow
#
# 1787 proxies left to filter
# 190.60.69.202:8080 is slow
#
# 1786 proxies left to filter
# 178.169.64.76:8081 is slow
#
# 1785 proxies left to filter
# 182.23.69.136:8080 is slow
#
# 1784 proxies left to filter
# 193.112.2.242:1080 is slow
#
# 1783 proxies left to filter
# 156.67.84.75:49850 is slow
#
# 1782 proxies left to filter
# 169.255.106.90:8080 is good
# average conn time: 4.42969834805
#
# 1781 proxies left to filter
# 185.41.248.161:8080 is slow
#
# 1780 proxies left to filter
# 180.175.168.227:8060 is slow
#
# 1779 proxies left to filter
# 200.69.70.238:8080 is good
# average conn time: 4.44634337503
#
# 1778 proxies left to filter
# 180.183.134.243:8080 is slow
#
# 1777 proxies left to filter
# 183.88.240.216:8080 is good
# average conn time: 4.47257535304
#
# 1776 proxies left to filter
# 190.128.225.14:3128 is good
# average conn time: 4.49557490197
#
# 1775 proxies left to filter
# 181.112.58.22:65238 is good
# average conn time: 4.48920445144
#
# 1774 proxies left to filter
# 178.210.129.11:8080 is slow
#
# 1773 proxies left to filter
# 179.189.225.58:41881 is good
# average conn time: 4.48831373361
#
# 1772 proxies left to filter
# 181.29.206.71:8080 is good
# average conn time: 4.4655192368
#
# 1771 proxies left to filter
# 157.230.140.12:8080 is slow
#
# 1770 proxies left to filter
# 179.213.35.25:8080 is slow
#
# 1769 proxies left to filter
# 197.255.244.70:53281 is bad
#
# 1768 proxies left to filter
# 185.234.15.79:3128 is good
# average conn time: 4.42978851475
#
# 1767 proxies left to filter
# 190.61.40.166:53281 is good
# average conn time: 4.42852190312
#
# 1766 proxies left to filter
# 190.186.58.238:65301 is good
# average conn time: 4.50512561591
#
# 1765 proxies left to filter
# 190.96.214.59:8080 is slow
#
# 1764 proxies left to filter
# 196.216.220.201:53281 is slow
#
# 1763 proxies left to filter
# 182.52.51.66:56827 is slow
#
# 1762 proxies left to filter
# 185.252.103.100:80 is slow
#
# 1761 proxies left to filter
# 191.242.182.132:8081 is bad
#
# 1760 proxies left to filter
# 157.230.149.54:80 is slow
#
# 1759 proxies left to filter
# 159.192.222.15:8080 is slow
#
# 1758 proxies left to filter
# 178.210.130.82:41258 is bad
#
# 1757 proxies left to filter
# 165.22.72.139:8080 is good
# average conn time: 4.48241329193
#
# 1756 proxies left to filter
# 158.69.104.195:1080 is slow
#
# 1755 proxies left to filter
# 186.148.191.50:9991 is slow
#
# 1754 proxies left to filter
# 190.0.244.5:9991 is slow
#
# 1753 proxies left to filter
# 160.20.75.26:56125 is slow
#
# 1752 proxies left to filter
# 157.230.227.116:80 is slow
#
# 1751 proxies left to filter
# 192.162.192.148:53281 is good
# average conn time: 4.46491165228
#
# 1750 proxies left to filter
# 195.112.197.210:41036 is slow
#
# 1749 proxies left to filter
# 194.114.139.177:6575 is slow
#
# 1748 proxies left to filter
# 185.109.54.227:31280 is bad
#
# 1747 proxies left to filter
# 182.16.189.18:60818 is slow
#
# 1746 proxies left to filter
# 197.211.38.187:44128 is good
# average conn time: 4.4351730744
#
# 1745 proxies left to filter
# 167.99.80.74:3128 is slow
#
# 1744 proxies left to filter
# 187.180.17.52:3128 is slow
#
# 1743 proxies left to filter
# 161.49.186.218:8080 is good
# average conn time: 4.42335327684
#
# 1742 proxies left to filter
# 177.38.69.68:8080 is slow
#
# 1741 proxies left to filter
# 170.246.152.82:8080 is good
# average conn time: 4.48002696359
#
# 1740 proxies left to filter
# 168.181.240.134:8080 is slow
#
# 1739 proxies left to filter
# 164.132.141.225:8080 is slow
#
# 1738 proxies left to filter
# 197.234.55.161:8083 is slow
#
# 1737 proxies left to filter
# 176.118.49.54:53281 is bad
#
# 1736 proxies left to filter
# 185.162.128.135:9006 is slow
#
# 1735 proxies left to filter
# 177.11.113.115:8080 is slow
#
# 1734 proxies left to filter
# 189.76.239.81:52536 is good
# average conn time: 4.46451473554
#
# 1733 proxies left to filter
# 172.104.169.82:3128 is slow
#
# 1732 proxies left to filter
# 185.23.82.39:59248 is bad
#
# 1731 proxies left to filter
# 157.230.149.189:8080 is slow
#
# 1730 proxies left to filter
# 184.105.143.66:3128 is good
# average conn time: 4.41426942537
#
# 1729 proxies left to filter
# 200.127.220.21:8080 is slow
#
# 1728 proxies left to filter
# 171.4.61.72:8080 is slow
#
# 1727 proxies left to filter
# 159.192.101.8:80 is slow
#
# 1726 proxies left to filter
# 182.52.31.58:8080 is slow
#
# 1725 proxies left to filter
# 193.112.137.134:1080 is slow
#
# 1724 proxies left to filter
# 154.113.86.75:3128 is slow
#
# 1723 proxies left to filter
# 200.165.72.98:32346 is good
# average conn time: 4.38571912282
#
# 1722 proxies left to filter
# 181.197.143.74:8080 is slow
#
# 1721 proxies left to filter
# 186.249.213.101:53482 is slow
#
# 1720 proxies left to filter
# 176.101.221.119:80 is good
# average conn time: 4.39854253255
#
# 1719 proxies left to filter
# 157.230.240.78:3128 is bad
#
# 1718 proxies left to filter
# 178.88.119.150:32275 is slow
#
# 1717 proxies left to filter
# 169.159.150.148:8080 is good
# average conn time: 4.39808836164
#
# 1716 proxies left to filter
# 168.232.135.204:8080 is slow
#
# 1715 proxies left to filter
# 191.36.155.3:8080 is slow
#
# 1714 proxies left to filter
# 195.46.122.165:36869 is slow
#
# 1713 proxies left to filter
# 190.202.18.126:53281 is bad
#
# 1712 proxies left to filter
# 182.52.51.48:32425 is slow
#
# 1711 proxies left to filter
# 185.132.228.102:8080 is bad
#
# 1710 proxies left to filter
# 181.56.255.137:36127 is good
# average conn time: 4.41316114366
#
# 1709 proxies left to filter
# 175.20.219.253:8080 is slow
#
# 1708 proxies left to filter
# 185.65.163.175:36104 is slow
#
# 1707 proxies left to filter
# 177.85.78.4:8080 is good
# average conn time: 4.42400341269
#
# 1706 proxies left to filter
# 197.210.187.170:8080 is slow
#
# 1705 proxies left to filter
# 181.55.127.107:8080 is slow
#
# 1704 proxies left to filter
# 182.52.134.88:36625 is slow
#
# 1703 proxies left to filter
# 165.255.118.125:8080 is slow
#
# 1702 proxies left to filter
# 171.97.10.223:8080 is slow
#
# 1701 proxies left to filter
# 202.129.251.39:23500 is slow
#
# 1700 proxies left to filter
# 163.47.34.114:8080 is good
# average conn time: 4.53439583429
#
# 1699 proxies left to filter
# 196.201.10.174:8080 is slow
#
# 1698 proxies left to filter
# 178.128.186.2:8080 is slow
#
# 1697 proxies left to filter
# 194.114.139.104:6575 is slow
#
# 1696 proxies left to filter
# 158.69.104.199:1080 is slow
#
# 1695 proxies left to filter
# 177.36.188.18:8080 is slow
#
# 1694 proxies left to filter
# 186.237.219.96:8080 is slow
#
# 1693 proxies left to filter
# 200.159.250.2:3128 is bad
#
# 1692 proxies left to filter
# 197.216.2.12:8080 is good
# average conn time: 4.52574569346
#
# 1691 proxies left to filter
# 177.238.248.99:54419 is slow
#
# 1690 proxies left to filter
# 198.71.161.133:80 is slow
#
# 1689 proxies left to filter
# 188.166.170.113:3128 is slow
#
# 1688 proxies left to filter
# 175.20.41.213:8080 is slow
#
# 1687 proxies left to filter
# 193.150.117.31:8000 is good
# average conn time: 4.51034486578
#
# 1686 proxies left to filter
# 191.232.167.197:80 is slow
#
# 1685 proxies left to filter
# 192.99.191.239:1080 is slow
#
# 1684 proxies left to filter
# 18.228.243.92:8080 is bad
#
# 1683 proxies left to filter
# 154.72.197.106:41586 is slow
#
# 1682 proxies left to filter
# 200.49.54.182:80 is good
# average conn time: 4.47513286647
#
# 1681 proxies left to filter
# 185.37.211.222:52304 is slow
#
# 1680 proxies left to filter
# 190.15.205.50:8080 is good
# average conn time: 4.50680384525
#
# 1679 proxies left to filter
# 18.217.49.2:3128 is slow
#
# 1678 proxies left to filter
# 179.95.232.131:3128 is good
# average conn time: 4.48231580066
#
# 1677 proxies left to filter
# 191.252.185.161:8090 is good
# average conn time: 4.4489341324
#
# 1676 proxies left to filter
# 159.65.236.197:80 is slow
#
# 1675 proxies left to filter
# 178.134.107.50:8080 is good
# average conn time: 4.464962603
#
# 1674 proxies left to filter
# 187.108.38.10:20183 is good
# average conn time: 4.49636151791
#
# 1673 proxies left to filter
# 193.188.254.67:53281 is slow
#
# 1672 proxies left to filter
# 157.230.33.25:8080 is good
# average conn time: 4.46538864387
#
# 1671 proxies left to filter
# 185.175.95.46:49065 is bad
#
# 1670 proxies left to filter
# 188.168.27.71:36733 is bad
#
# 1669 proxies left to filter
# 183.89.53.29:8080 is slow
#
# 1668 proxies left to filter
# 177.53.59.96:61752 is bad
#
# 1667 proxies left to filter
# 188.166.156.70:8080 is good
# average conn time: 4.42671144009
#
# 1666 proxies left to filter
# 177.8.216.106:8080 is bad
#
# 1665 proxies left to filter
# 197.234.55.249:8083 is slow
#
# 1664 proxies left to filter
# 191.5.0.79:53281 is slow
#
# 1663 proxies left to filter
# 164.163.232.170:49615 is slow
#
# 1662 proxies left to filter
# 185.148.220.11:8081 is slow
#
# 1661 proxies left to filter
# 181.196.245.78:8080 is slow
#
# 1660 proxies left to filter
# 196.13.208.23:8080 is slow
#
# 1659 proxies left to filter
# 198.50.172.163:1080 is slow
#
# 1658 proxies left to filter
# 177.53.8.83:31720 is good
# average conn time: 4.41853740138
#
# 1657 proxies left to filter
# 175.180.136.139:30753 is slow
#
# 1656 proxies left to filter
# 191.103.218.9:53281 is good
# average conn time: 4.41121335233
#
# 1655 proxies left to filter
# 192.144.147.90:1080 is slow
#
# 1654 proxies left to filter
# 178.216.0.168:33364 is bad
#
# 1653 proxies left to filter
# 182.16.162.250:8080 is good
# average conn time: 4.41056904291
#
# 1652 proxies left to filter
# 178.128.151.27:80 is slow
#
# 1651 proxies left to filter
# 190.85.153.141:37680 is slow
#
# 1650 proxies left to filter
# 190.221.174.130:8080 is good
# average conn time: 4.38472972065
#
# 1649 proxies left to filter
# 178.217.168.77:37392 is bad
#
# 1648 proxies left to filter
# 190.52.162.108:59536 is slow
#
# 1647 proxies left to filter
# 189.51.101.126:39108 is bad
#
# 1646 proxies left to filter
# 187.95.33.154:80 is slow
#
# 1645 proxies left to filter
# 168.228.178.90:41069 is slow
#
# 1644 proxies left to filter
# 186.236.237.243:56126 is bad
#
# 1643 proxies left to filter
# 186.225.91.223:59723 is slow
#
# 1642 proxies left to filter
# 171.43.8.99:9999 is slow
#
# 1641 proxies left to filter
# 177.185.156.241:8080 is slow
#
# 1640 proxies left to filter
# 178.128.229.221:8080 is good
# average conn time: 4.34999508464
#
# 1639 proxies left to filter
# 193.112.10.212:1080 is slow
#
# 1638 proxies left to filter
# 202.112.237.102:3128 is slow
#
# 1637 proxies left to filter
# 187.44.177.178:41178 is bad
#
# 1636 proxies left to filter
# 193.112.169.90:1080 is slow
#
# 1635 proxies left to filter
# 162.155.10.150:53281 is bad
#
# 1634 proxies left to filter
# 190.186.1.46:36751 is good
# average conn time: 4.38582599163
#
# 1633 proxies left to filter
# 189.186.184.215:53281 is good
# average conn time: 4.41775832513
#
# 1632 proxies left to filter
# 195.9.160.250:8080 is slow
#
# 1631 proxies left to filter
# 167.99.1.61:80 is slow
#
# 1630 proxies left to filter
# 197.234.55.177:8083 is slow
#
# 1629 proxies left to filter
# 194.114.139.80:6575 is slow
#
# 1628 proxies left to filter
# 190.0.57.250:48049 is slow
#
# 1627 proxies left to filter
# 200.241.44.110:20183 is slow
#
# 1626 proxies left to filter
# 156.155.189.49:8080 is good
# average conn time: 4.43509276152
#
# 1625 proxies left to filter
# 201.20.64.210:8080 is good
# average conn time: 4.46321805161
#
# 1624 proxies left to filter
# 159.89.194.77:8080 is good
# average conn time: 4.43756794462
#
# 1623 proxies left to filter
# 160.119.131.114:33590 is bad
#
# 1622 proxies left to filter
# 186.228.147.58:20183 is slow
#
# 1621 proxies left to filter
# 185.228.119.21:8080 is slow
#
# 1620 proxies left to filter
# 194.114.139.152:6575 is slow
#
# 1619 proxies left to filter
# 186.193.10.2:8080 is good
# average conn time: 4.42878990497
#
# 1618 proxies left to filter
# 179.0.130.137:80 is slow
#
# 1617 proxies left to filter
# 170.247.202.152:8080 is slow
#
# 1616 proxies left to filter
# 191.7.192.106:8080 is bad
#
# 1615 proxies left to filter
# 157.230.35.194:8080 is good
# average conn time: 4.40414717564
#
# 1614 proxies left to filter
# 158.58.133.106:41258 is slow
#
# 1613 proxies left to filter
# 190.124.34.221:30753 is bad
#
# 1612 proxies left to filter
# 167.250.65.210:33393 is bad
#
# 1611 proxies left to filter
# 157.230.227.116:8080 is slow
#
# 1610 proxies left to filter
# 186.125.59.8:59050 is slow
#
# 1609 proxies left to filter
# 190.249.157.89:42969 is slow
#
# 1608 proxies left to filter
# 158.255.27.179:55837 is slow
#
# 1607 proxies left to filter
# 185.132.133.209:8080 is slow
#
# 1606 proxies left to filter
# 177.72.164.164:53281 is bad
#
# 1605 proxies left to filter
# 181.129.58.203:40206 is bad
#
# 1604 proxies left to filter
# 201.184.151.58:45718 is slow
#
# 1603 proxies left to filter
# 200.125.33.106:8080 is good
# average conn time: 4.40005141213
#
# 1602 proxies left to filter
# 179.43.81.135:80 is slow
#
# 1601 proxies left to filter
# 171.100.72.102:8080 is slow
#
# 1600 proxies left to filter
# 191.37.50.24:8080 is good
# average conn time: 4.40000648319
#
# 1599 proxies left to filter
# 157.119.118.122:45351 is slow
#
# 1598 proxies left to filter
# 169.239.46.73:32231 is bad
#
# 1597 proxies left to filter
# 177.158.152.239:8080 is slow
#
# 1596 proxies left to filter
# 190.18.207.58:53281 is good
# average conn time: 4.4173655354
#
# 1595 proxies left to filter
# 194.156.231.189:80 is slow
#
# 1594 proxies left to filter
# 159.203.118.239:8080 is slow
#
# 1593 proxies left to filter
# 176.193.255.162:8080 is good
# average conn time: 4.41497741805
#
# 1592 proxies left to filter
# 201.22.59.42:3128 is good
# average conn time: 4.40329412145
#
# 1591 proxies left to filter
# 181.129.75.100:999 is slow
#
# 1590 proxies left to filter
# 185.68.153.147:42940 is slow
#
# 1589 proxies left to filter
# 165.22.248.190:8080 is good
# average conn time: 4.37911476655
#
# 1588 proxies left to filter
# 180.250.45.26:3128 is slow
#
# 1587 proxies left to filter
# 189.90.255.36:8080 is slow
#
# 1586 proxies left to filter
# 200.8.26.41:8080 is slow
#
# 1585 proxies left to filter
# 190.211.188.14:8181 is slow
#
# 1584 proxies left to filter
# 183.87.75.5:8080 is bad
#
# 1583 proxies left to filter
# 197.245.157.72:8080 is slow
#
# 1582 proxies left to filter
# 180.183.46.232:8080 is slow
#
# 1581 proxies left to filter
# 157.230.233.67:8080 is good
# average conn time: 4.34841461654
#
# 1580 proxies left to filter
# 177.128.138.36:8080 is good
# average conn time: 4.34323983533
#
# 1579 proxies left to filter
# 178.128.108.61:8080 is good
# average conn time: 4.3186542608
#
# 1578 proxies left to filter
# 185.162.128.135:8888 is good
# average conn time: 4.29614230206
#
# 1577 proxies left to filter
# 177.44.82.232:8080 is slow
#
# 1576 proxies left to filter
# 185.173.245.127:44267 is bad
#
# 1575 proxies left to filter
# 177.85.119.204:36179 is slow
#
# 1574 proxies left to filter
# 194.114.128.149:61213 is bad
#
# 1573 proxies left to filter
# 190.214.56.238:35933 is slow
#
# 1572 proxies left to filter
# 180.180.170.188:8080 is good
# average conn time: 4.3178818371
#
# 1571 proxies left to filter
# 157.230.160.64:8888 is good
# average conn time: 4.28418147564
#
# 1570 proxies left to filter
# 159.89.83.140:80 is slow
#
# 1569 proxies left to filter
# 189.58.100.98:8080 is good
# average conn time: 4.30405063303
#
# 1568 proxies left to filter
# 190.210.40.129:36282 is slow
#
# 1567 proxies left to filter
# 180.211.193.34:8080 is slow
#
# 1566 proxies left to filter
# 158.69.104.192:1080 is slow
#
# 1565 proxies left to filter
# 194.114.139.205:6575 is slow
#
# 1564 proxies left to filter
# 177.75.4.34:80 is bad
#
# 1563 proxies left to filter
# 157.230.37.104:8888 is good
# average conn time: 4.2815220255
#
# 1562 proxies left to filter
# 177.71.77.202:20183 is good
# average conn time: 4.29436799258
#
# 1561 proxies left to filter
# 157.230.244.215:8080 is good
# average conn time: 4.2710578839
#
# 1560 proxies left to filter
# 189.91.157.21:8080 is good
# average conn time: 4.28984028249
#
# 1559 proxies left to filter
# 186.148.190.78:999 is slow
#
# 1558 proxies left to filter
# 192.99.191.233:1080 is slow
#
# 1557 proxies left to filter
# 194.114.139.110:6575 is slow
#
# 1556 proxies left to filter
# 181.119.69.27:32889 is slow
#
# 1555 proxies left to filter
# 201.182.120.230:8080 is slow
#
# 1554 proxies left to filter
# 187.17.146.25:8080 is bad
#
# 1553 proxies left to filter
# 169.239.46.92:8080 is slow
#
# 1552 proxies left to filter
# 180.246.219.213:8080 is slow
#
# 1551 proxies left to filter
# 200.128.3.116:80 is slow
#
# 1550 proxies left to filter
# 195.34.242.74:47324 is good
# average conn time: 4.27378589403
#
# 1549 proxies left to filter
# 194.114.139.38:6575 is slow
#
# 1548 proxies left to filter
# 191.253.105.134:53281 is slow
#
# 1547 proxies left to filter
# 157.230.228.82:3128 is slow
#
# 1546 proxies left to filter
# 165.227.107.218:8080 is slow
#
# 1545 proxies left to filter
# 175.210.152.77:8197 is slow
#
# 1544 proxies left to filter
# 189.4.222.28:53281 is slow
#
# 1543 proxies left to filter
# 177.220.188.213:8080 is good
# average conn time: 4.28442388046
#
# 1542 proxies left to filter
# 200.80.22.47:8080 is good
# average conn time: 4.2881331886
#
# 1541 proxies left to filter
# 185.108.141.49:8080 is slow
#
# 1540 proxies left to filter
# 182.48.72.146:8080 is slow
#
# 1539 proxies left to filter
# 197.232.63.162:53433 is bad
#
# 1538 proxies left to filter
# 178.128.108.19:8080 is good
# average conn time: 4.26670623398
#
# 1537 proxies left to filter
# 185.181.52.213:3129 is slow
#
# 1536 proxies left to filter
# 195.239.100.30:3128 is good
# average conn time: 4.25040200211
#
# 1535 proxies left to filter
# 154.70.135.198:8080 is good
# average conn time: 4.23847628578
#
# 1534 proxies left to filter
# 185.14.250.204:58185 is slow
#
# 1533 proxies left to filter
# 176.56.181.154:3128 is good
# average conn time: 4.25797186978
#
# 1532 proxies left to filter
# 187.109.210.153:31725 is bad
#
# 1531 proxies left to filter
# 178.219.86.106:44262 is slow
#
# 1530 proxies left to filter
# 171.4.87.73:8080 is slow
#
# 1529 proxies left to filter
# 197.234.56.17:8083 is slow
#
# 1528 proxies left to filter
# 200.212.2.94:45612 is slow
#
# 1527 proxies left to filter
# 177.53.217.246:60902 is bad
# 1526 proxies left to filter
# 185.107.70.98:3128 is good
# average conn time: 4.23070213407
#
# 1525 proxies left to filter
# 191.102.93.82:8181 is slow
#
# 1524 proxies left to filter
# 182.23.69.141:8080 is slow
#
# 1523 proxies left to filter
# 200.159.149.26:58160 is slow
#
# 1522 proxies left to filter
# 168.228.51.238:8080 is good
# average conn time: 4.21981944121
#
# 1521 proxies left to filter
# 167.114.164.13:8080 is slow
#
# 1520 proxies left to filter
# 200.69.67.74:9991 is slow
#
# 1519 proxies left to filter
# 160.19.245.59:43463 is good
# average conn time: 4.21016755177
#
# 1518 proxies left to filter
# 177.234.161.202:8080 is good
# average conn time: 4.21766446395
#
# 1517 proxies left to filter
# 157.230.163.11:80 is slow
#
# 1516 proxies left to filter
# 178.44.192.246:8081 is slow
#
# 1515 proxies left to filter
# 164.115.43.209:80 is slow
#
# 1514 proxies left to filter
# 182.253.209.205:3128 is good
# average conn time: 4.2085774393
#
# 1513 proxies left to filter
# 157.230.233.67:3128 is good
# average conn time: 4.17980311522
#
# 1512 proxies left to filter
# 178.32.218.91:80 is slow
#
# 1511 proxies left to filter
# 194.114.139.219:6575 is slow
#
# 1510 proxies left to filter
# 188.211.226.118:53281 is slow
#
# 1509 proxies left to filter
# 180.183.243.4:8080 is bad
#
# 1508 proxies left to filter
# 197.155.111.52:8080 is slow
#
# 1507 proxies left to filter
# 192.99.191.234:1080 is slow
#
# 1506 proxies left to filter
# 159.192.97.181:23500 is good
# average conn time: 4.18454409352
#
# 1505 proxies left to filter
# 181.113.225.114:8080 is good
# average conn time: 4.1870419383
#
# 1504 proxies left to filter
# 177.91.127.56:53975 is slow
#
# 1503 proxies left to filter
# 171.43.8.102:9999 is slow
#
# 1502 proxies left to filter
# 182.254.200.21:1080 is slow
#
# 1501 proxies left to filter
# 200.32.51.179:8080 is good
# average conn time: 4.16781884388
#
# 1500 proxies left to filter
# 182.52.110.182:8080 is slow
#
# 1499 proxies left to filter
# 180.250.159.34:56979 is slow
#
# 1498 proxies left to filter
# 177.159.110.42:8080 is slow
#
# 1497 proxies left to filter
# 165.22.32.183:3128 is slow
#
# 1496 proxies left to filter
# 154.126.115.74:8080 is slow
#
# 1495 proxies left to filter
# 189.89.231.218:8080 is slow
#
# 1494 proxies left to filter
# 175.103.41.238:8080 is slow
#
# 1493 proxies left to filter
# 187.45.13.190:39914 is bad
#
# 1492 proxies left to filter
# 177.136.185.200:80 is good
# average conn time: 4.15082935147
#
# 1491 proxies left to filter
# 176.31.69.183:1080 is slow
#
# 1490 proxies left to filter
# 191.36.192.196:3128 is good
# average conn time: 4.14999619834
#
# 1489 proxies left to filter
# 197.234.56.65:8083 is slow
#
# 1488 proxies left to filter
# 176.9.19.49:3128 is slow
#
# 1487 proxies left to filter
# 188.32.96.131:8081 is slow
#
# 1486 proxies left to filter
# 200.206.70.162:20183 is good
# average conn time: 4.15327821118
#
# 1485 proxies left to filter
# 2.139.187.123:3128 is slow
#
# 1484 proxies left to filter
# 183.89.73.86:8080 is slow
#
# 1483 proxies left to filter
# 189.30.181.98:8080 is slow
#
# 1482 proxies left to filter
# 195.246.54.66:53281 is good
# average conn time: 4.13578945863
#
# 1481 proxies left to filter
# 185.158.219.47:53281 is slow
#
# 1480 proxies left to filter
# 186.64.120.107:8080 is slow
#
# 1479 proxies left to filter
# 194.87.148.177:36854 is slow
#
# 1478 proxies left to filter
# 182.16.173.102:8080 is good
# average conn time: 4.14115516065
#
# 1477 proxies left to filter
# 185.108.123.245:3128 is good
# average conn time: 4.17135939065
#
# 1476 proxies left to filter
# 18.228.141.44:80 is slow
#
# 1475 proxies left to filter
# 175.116.74.123:8197 is slow
#
# 1474 proxies left to filter
# 187.19.62.7:59010 is bad
#
# 1473 proxies left to filter
# 177.52.55.19:60901 is good
# average conn time: 4.16921813124
#
# 1472 proxies left to filter
# 178.74.92.230:8080 is slow
#
# 1471 proxies left to filter
# 182.53.186.160:8080 is slow
#
# 1470 proxies left to filter
# 196.0.109.146:37810 is slow
#
# 1469 proxies left to filter
# 201.182.223.16:37492 is bad
#
# 1468 proxies left to filter
# 177.46.149.9:41273 is bad
#
# 1467 proxies left to filter
# 157.230.57.151:80 is slow
#
# 1466 proxies left to filter
# 190.96.91.242:8080 is good
# average conn time: 4.17312660053
#
# 1465 proxies left to filter
# 194.44.160.246:61465 is bad
#
# 1464 proxies left to filter
# 195.164.152.106:8181 is slow
#
# 1463 proxies left to filter
# 201.164.62.94:8080 is slow
#
# 1462 proxies left to filter
# 200.58.84.165:57120 is slow
#
# 1461 proxies left to filter
# 190.234.3.138:8080 is slow
#
# 1460 proxies left to filter
# 193.112.162.137:1080 is slow
#
# 1459 proxies left to filter
# 181.129.147.26:32945 is slow
#
# 1458 proxies left to filter
# 190.104.195.210:53281 is slow
#
# 1457 proxies left to filter
# 188.133.172.216:8080 is slow
#
# 1456 proxies left to filter
# 180.248.30.157:8080 is slow
#
# 1455 proxies left to filter
# 180.180.170.67:8080 is good
# average conn time: 4.18247254254
#
# 1454 proxies left to filter
# 186.1.40.199:44335 is slow
#
# 1453 proxies left to filter
# 190.0.244.3:9991 is slow
#
# 1452 proxies left to filter
# 190.215.117.50:53281 is good
# average conn time: 4.19404517874
#
# 1451 proxies left to filter
# 173.249.35.163:1448 is good
# average conn time: 4.17341826574
#
# 1450 proxies left to filter
# 186.159.3.217:60498 is good
# average conn time: 4.16863260653
#
# 1449 proxies left to filter
# 185.198.184.14:48122 is good
# average conn time: 4.16137857596
#
# 1448 proxies left to filter
# 185.212.221.11:80 is slow
#
# 1447 proxies left to filter
# 182.53.206.157:44382 is good
# average conn time: 4.17246441336
#
# 1446 proxies left to filter
# 157.230.39.180:3128 is good
# average conn time: 4.15479748343
#
# 1445 proxies left to filter
# 190.215.118.170:35186 is bad
#
# 1444 proxies left to filter
# 200.126.215.135:8181 is good
# average conn time: 4.17243628408
#
# 1443 proxies left to filter
# 185.62.190.60:80 is slow
#
# 1442 proxies left to filter
# 184.183.3.211:8080 is slow
#
# 1441 proxies left to filter
# 186.10.80.226:80 is slow
#
# 1440 proxies left to filter
# 152.204.128.46:57549 is slow
#
# 1439 proxies left to filter
# 167.99.84.71:8080 is bad
#
# 1438 proxies left to filter
# 180.180.218.111:43785 is slow
#
# 1437 proxies left to filter
# 180.242.88.128:8080 is slow
#
# 1436 proxies left to filter
# 190.64.177.70:53567 is slow
#
# 1435 proxies left to filter
# 168.90.227.121:63238 is slow
#
# 1434 proxies left to filter
# 158.69.138.9:1080 is slow
#
# 1433 proxies left to filter
# 200.233.92.222:20183 is good
# average conn time: 4.17502450324
#
# 1432 proxies left to filter
# 176.111.10.136:33222 is slow
#
# 1431 proxies left to filter
# 182.72.147.154:23500 is slow
#
# 1430 proxies left to filter
# 176.31.69.178:1080 is slow
#
# 1429 proxies left to filter
# 182.253.26.196:8080 is slow
#
# 1428 proxies left to filter
# 165.227.255.220:3128 is slow
#
# 1427 proxies left to filter
# 186.1.206.138:8080 is good
# average conn time: 4.18679018944
#
# 1426 proxies left to filter
# 18.196.2.154:80 is slow
#
# 1425 proxies left to filter
# 176.118.48.118:59905 is bad
#
# 1424 proxies left to filter
# 175.18.213.114:8080 is slow
#
# 1423 proxies left to filter
# 200.255.122.174:8080 is bad
#
# 1422 proxies left to filter
# 193.41.79.210:8080 is slow
#
# 1421 proxies left to filter
# 185.132.133.179:8080 is slow
#
# 1420 proxies left to filter
# 202.153.231.147:3128 is slow
#
# 1419 proxies left to filter
# 177.125.20.35:38602 is slow
#
# 1418 proxies left to filter
# 190.210.28.194:52651 is slow
#
# 1417 proxies left to filter
# 177.135.114.164:3128 is slow
#
# 1416 proxies left to filter
# 168.228.191.185:8080 is slow
#
# 1415 proxies left to filter
# 163.172.153.70:8080 is slow
#
# 1414 proxies left to filter
# 189.10.97.147:30036 is slow
#
# 1413 proxies left to filter
# 187.95.28.44:8080 is slow
#
# 1412 proxies left to filter
# 186.206.200.170:3128 is good
# average conn time: 4.19077805372
#
# 1411 proxies left to filter
# 177.85.114.209:3128 is slow
#
# 1410 proxies left to filter
# 196.50.247.122:49663 is slow
#
# 1409 proxies left to filter
# 202.148.20.218:80 is slow
#
# 1408 proxies left to filter
# 202.138.243.8:8080 is good
# average conn time: 4.21267902168
#
# 1407 proxies left to filter
# 194.182.86.108:8000 is slow
#
# 1406 proxies left to filter
# 175.100.180.131:53281 is good
# average conn time: 4.21665323082
#
# 1405 proxies left to filter
# 195.175.63.230:53281 is slow
#
# 1404 proxies left to filter
# 185.226.160.20:80 is slow
#
# 1403 proxies left to filter
# 187.111.192.146:44737 is bad
#
# 1402 proxies left to filter
# 185.7.168.142:8080 is good
# average conn time: 4.21151899692
#
# 1401 proxies left to filter
# 194.28.222.1:31227 is bad
#
# 1400 proxies left to filter
# 197.89.213.19:8080 is slow
#
# 1399 proxies left to filter
# 186.237.221.37:8080 is good
# average conn time: 4.23567119092
#
# 1398 proxies left to filter
# 185.62.224.17:4550 is good
# average conn time: 4.23948594206
#
# 1397 proxies left to filter
# 186.193.229.38:8080 is slow
#
# 1396 proxies left to filter
# 162.223.89.92:8080 is bad
#
# 1395 proxies left to filter
# 200.35.56.161:35945 is bad
#
# 1394 proxies left to filter
# 181.225.109.133:8181 is good
# average conn time: 4.25686762068
#
# 1393 proxies left to filter
# 167.99.1.61:23 is slow
#
# 1392 proxies left to filter
# 165.73.128.190:8080 is slow
#
# 1391 proxies left to filter
# 181.119.69.28:32889 is bad
#
# 1390 proxies left to filter
# 195.211.231.243:31167 is slow
#
# 1389 proxies left to filter
# 177.10.97.161:8080 is slow
#
# 1388 proxies left to filter
# 182.23.69.131:8080 is slow
#
# 1387 proxies left to filter
# 170.0.92.83:46629 is slow
#
# 1386 proxies left to filter
# 182.253.199.182:80 is slow
#
# 1385 proxies left to filter
# 193.95.228.13:53281 is slow
#
# 1384 proxies left to filter
# 191.241.224.78:20183 is good
# average conn time: 4.25149896101
#
# 1383 proxies left to filter
# 177.92.20.182:50973 is good
# average conn time: 4.27836952849
#
# 1382 proxies left to filter
# 177.73.53.153:8080 is good
# average conn time: 4.33319538579
#
# 1381 proxies left to filter
# 187.16.4.126:8080 is good
# average conn time: 4.3186620402
#
# 1380 proxies left to filter
# 175.10.221.153:8060 is slow
#
# 1379 proxies left to filter
# 200.170.220.218:8080 is good
# average conn time: 4.32739599308
#
# 1378 proxies left to filter
# 198.11.178.14:8080 is good
# average conn time: 4.34229487465
#
# 1377 proxies left to filter
# 186.148.170.26:30353 is good
# average conn time: 4.32788882171
#
# 1376 proxies left to filter
# 167.99.71.37:8080 is good
# average conn time: 4.31070218787
#
# 1375 proxies left to filter
# 164.132.98.72:3128 is slow
#
# 1374 proxies left to filter
# 154.0.2.210:8080 is slow
#
# 1373 proxies left to filter
# 159.138.22.112:80 is slow
#
# 1372 proxies left to filter
# 181.129.180.242:55136 is slow
#
# 1371 proxies left to filter
# 165.22.242.235:8080 is good
# average conn time: 4.2949821461
#
# 1370 proxies left to filter
# 191.102.83.146:80 is slow
#
# 1369 proxies left to filter
# 176.241.95.68:51166 is slow
#
# 1368 proxies left to filter
# 188.225.9.121:8080 is slow
#
# 1367 proxies left to filter
# 186.5.117.18:3128 is good
# average conn time: 4.27763240559
#
# 1366 proxies left to filter
# 195.9.61.22:54549 is good
# average conn time: 4.28496208632
#
# 1365 proxies left to filter
# 159.65.236.197:8080 is slow
#
# 1364 proxies left to filter
# 195.69.135.78:46704 is bad
#
# 1363 proxies left to filter
# 185.103.21.53:3333 is slow
#
# 1362 proxies left to filter
# 185.189.208.185:61360 is slow
#
# 1361 proxies left to filter
# 190.109.167.98:60273 is bad
#
# 1360 proxies left to filter
# 201.16.212.79:80 is slow
#
# 1359 proxies left to filter
# 200.69.95.106:999 is bad
#
# 1358 proxies left to filter
# 200.24.84.4:39136 is bad
#
# 1357 proxies left to filter
# 200.123.240.1:46445 is bad
#
# 1356 proxies left to filter
# 190.82.76.58:42600 is slow
#
# 1355 proxies left to filter
# 175.18.68.69:8080 is slow
#
# 1354 proxies left to filter
# 190.63.134.220:32435 is slow
#
# 1353 proxies left to filter
# 185.132.179.115:1080 is slow
#
# 1352 proxies left to filter
# 157.230.212.27:3128 is slow
#
# 1351 proxies left to filter
# 185.132.179.111:1080 is slow
#
# 1350 proxies left to filter
# 175.184.232.62:6666 is slow
#
# 1349 proxies left to filter
# 159.192.234.87:8080 is slow
#
# 1348 proxies left to filter
# 190.157.247.65:53281 is good
# average conn time: 4.28628819427
#
# 1347 proxies left to filter
# 187.198.53.12:8080 is slow
#
# 1346 proxies left to filter
# 177.44.175.204:8080 is slow
#
# 1345 proxies left to filter
# 191.252.195.136:3128 is slow
#
# 1344 proxies left to filter
# 190.102.134.98:3128 is slow
#
# 1343 proxies left to filter
# 181.196.254.202:53281 is good
# average conn time: 4.29955242838
#
# 1342 proxies left to filter
# 188.121.183.5:8082 is good
# average conn time: 4.29097553275
#
# 1341 proxies left to filter
# 190.14.235.50:37154 is good
# average conn time: 4.29602653563
#
# 1340 proxies left to filter
# 202.138.248.73:8080 is bad
#
# 1339 proxies left to filter
# 182.52.229.166:56480 is good
# average conn time: 4.29787124677
#
# 1338 proxies left to filter
# 202.143.121.245:80 is slow
#
# 1337 proxies left to filter
# 177.38.69.94:8080 is slow
#
# 1336 proxies left to filter
# 177.84.120.202:30574 is good
# average conn time: 4.29752063085
#
# 1335 proxies left to filter
# 167.114.34.23:3128 is slow
#
# 1334 proxies left to filter
# 185.15.252.41:8080 is good
# average conn time: 4.2834156341
#
# 1333 proxies left to filter
# 186.96.103.123:999 is good
# average conn time: 4.30751826618
#
# 1332 proxies left to filter
# 177.11.113.88:8080 is slow
#
# 1331 proxies left to filter
# 186.219.96.47:60426 is bad
#
# 1330 proxies left to filter
# 165.22.242.233:8080 is good
# average conn time: 4.29222367229
#
# 1329 proxies left to filter
# 190.2.21.148:9991 is slow
#
# 1328 proxies left to filter
# 183.87.125.1:43502 is slow
#
# 1327 proxies left to filter
# 178.211.225.7:80 is slow
#
# 1326 proxies left to filter
# 165.22.244.163:80 is slow
#
# 1325 proxies left to filter
# 187.190.64.42:50035 is slow
#
# 1324 proxies left to filter
# 139.224.187.136:3128 is slow
#
# 1323 proxies left to filter
# 202.150.132.98:63141 is slow
#
# 1322 proxies left to filter
# 176.221.165.250:31820 is slow
#
# 1321 proxies left to filter
# 182.52.132.37:8080 is good
# average conn time: 4.28482849481
#
# 1320 proxies left to filter
# 177.128.224.2:8080 is slow
#
# 1319 proxies left to filter
# 157.230.250.149:3128 is bad
#
# 1318 proxies left to filter
# 182.76.7.5:53281 is good
# average conn time: 4.28270415508
#
# 1317 proxies left to filter
# 182.53.206.47:47592 is good
# average conn time: 4.29050016532
#
# 1316 proxies left to filter
# 177.189.244.11:36068 is slow
#
# 1315 proxies left to filter
# 158.69.104.197:1080 is slow
#
# 1314 proxies left to filter
# 159.65.236.197:3128 is slow
#
# 1313 proxies left to filter
# 183.179.199.232:8080 is good
# average conn time: 4.27476991248
#
# 1312 proxies left to filter
# 164.77.147.93:53281 is good
# average conn time: 4.26970728706
#
# 1311 proxies left to filter
# 175.16.48.75:8080 is slow
#
# 1310 proxies left to filter
# 177.92.160.254:54868 is bad
#
# 1309 proxies left to filter
# 196.25.63.190:8080 is good
# average conn time: 4.26955562576
#
# 1308 proxies left to filter
# 194.9.26.243:38391 is slow
#
# 1307 proxies left to filter
# 168.205.250.1:53281 is good
# average conn time: 4.28788660569
#
# 1306 proxies left to filter
# 188.131.199.9:1080 is slow
#
# 1305 proxies left to filter
# 171.100.204.102:8080 is bad
#
# 1304 proxies left to filter
# 200.116.198.177:47021 is good
# average conn time: 4.28141192261
#
# 1303 proxies left to filter
# 200.212.2.125:45612 is slow
#
# 1302 proxies left to filter
# 180.242.62.190:8080 is slow
#
# 1301 proxies left to filter
# 157.230.220.233:3128 is slow
#
# 1300 proxies left to filter
# 169.255.40.106:36886 is slow
#
# 1299 proxies left to filter
# 167.99.148.235:8080 is slow
#
# 1298 proxies left to filter
# 157.230.29.234:8080 is slow
#
# 1297 proxies left to filter
# 159.89.200.0:8080 is good
# average conn time: 4.26752478165
#
# 1296 proxies left to filter
# 185.132.133.185:8080 is slow
#
# 1295 proxies left to filter
# ...
# 190.53.46.62:58473 is slow
#
# 258 proxies left to filter
# 170.79.16.19:8080 is good
# average conn time: 4.33467324253
#
# 257 proxies left to filter
# 188.244.189.11:32326 is bad
#
# 256 proxies left to filter
# 175.23.134.70:8080 is slow
#
# 255 proxies left to filter
# 165.22.157.83:80 is slow
#
# 254 proxies left to filter
# 187.11.216.80:8080 is good
# average conn time: 4.33377817387
#
# 253 proxies left to filter
# 149.56.82.220:80 is bad
#
# 252 proxies left to filter
# 200.85.39.138:46219 is slow
#
# 251 proxies left to filter
# 200.145.14.130:21320 is slow
#
# 250 proxies left to filter
# 175.106.18.74:37603 is slow
#
# 249 proxies left to filter
# 177.87.12.5:34228 is bad
#
# 248 proxies left to filter
# 186.101.255.146:8081 is slow
#
# 247 proxies left to filter
# 194.28.89.94:45773 is slow
#
# 246 proxies left to filter
# 158.69.138.12:1080 is slow
#
# 245 proxies left to filter
# 195.53.237.122:3128 is good
# average conn time: 4.33496983137
#
# 244 proxies left to filter
# 202.144.201.35:44091 is slow
#
# 243 proxies left to filter
# 200.232.56.171:3128 is slow
#
# 242 proxies left to filter
# 193.92.85.51:8080 is bad
#
# 241 proxies left to filter
# 190.80.11.32:8080 is slow
#
# 240 proxies left to filter
# 189.4.65.147:8080 is slow
#
# 239 proxies left to filter
# 194.28.42.11:8080 is slow
#
# 238 proxies left to filter
# 187.121.184.222:20183 is slow
#
# 237 proxies left to filter
# 187.111.255.129:30286 is bad
#
# 236 proxies left to filter
# 197.232.55.114:49109 is good
# average conn time: 4.33684063867
#
# 235 proxies left to filter
# 192.99.191.238:1080 is slow
#
# 234 proxies left to filter
# 193.112.132.144:1080 is slow
#
# 233 proxies left to filter
# 185.72.111.249:8080 is slow
#
# 232 proxies left to filter
# 186.225.102.218:3128 is good
# average conn time: 4.33103806675
#
# 231 proxies left to filter
# 154.65.94.37:8080 is slow
#
# 230 proxies left to filter
# 144.48.111.214:8080 is slow
#
# 229 proxies left to filter
# 177.85.200.254:53095 is slow
#
# 228 proxies left to filter
# 157.230.43.22:8080 is good
# average conn time: 4.32547490607
#
# 227 proxies left to filter
# 157.230.43.97:8080 is good
# average conn time: 4.32124965969
#
# 226 proxies left to filter
# 185.73.206.205:40662 is slow
#
# 225 proxies left to filter
# 170.244.190.133:8080 is slow
#
# 224 proxies left to filter
# 157.230.159.32:80 is slow
#
# 223 proxies left to filter
# 188.131.184.78:1080 is slow
#
# 222 proxies left to filter
# 181.115.185.42:8080 is good
# average conn time: 4.31868756619
#
# 221 proxies left to filter
# 190.214.13.90:21776 is bad
#
# 220 proxies left to filter
# 170.244.105.129:53281 is slow
#
# 219 proxies left to filter
# 163.53.198.54:42787 is good
# average conn time: 4.32652334497
#
# 218 proxies left to filter
# 178.32.80.236:1080 is slow
#
# 217 proxies left to filter
# 191.35.114.41:8080 is slow
#
# 216 proxies left to filter
# 197.255.253.210:51633 is slow
#
# 215 proxies left to filter
# 177.244.28.170:57035 is bad
#
# 214 proxies left to filter
# 187.188.46.172:53455 is bad
#
# 213 proxies left to filter
# 177.69.214.155:53281 is good
# average conn time: 4.34476064987
#
# 212 proxies left to filter
# 195.230.115.241:8080 is slow
#
# 211 proxies left to filter
# 190.92.5.158:53281 is slow
#
# 210 proxies left to filter
# 197.254.38.250:40853 is slow
#
# 209 proxies left to filter
# 191.7.20.134:3128 is good
# average conn time: 4.33996153774
#
# 208 proxies left to filter
# 173.193.163.130:3128 is slow
#
# 207 proxies left to filter
# 165.227.42.16:80 is slow
#
# 206 proxies left to filter
# 182.52.22.58:8080 is slow
#
# 205 proxies left to filter
# 200.195.188.2:46329 is slow
#
# 204 proxies left to filter
# 191.102.70.82:999 is good
# average conn time: 4.33589768906
#
# 203 proxies left to filter
# 175.103.46.82:8080 is slow
#
# 202 proxies left to filter
# 176.110.121.90:21776 is slow
#
# 201 proxies left to filter
# 180.211.172.151:50115 is slow
#
# 200 proxies left to filter
# 178.219.171.43:45637 is bad
#
# 199 proxies left to filter
# 178.162.140.227:3128 is slow
#
# 198 proxies left to filter
# 176.108.47.38:3128 is slow
#
# 197 proxies left to filter
# 186.59.248.111:80 is slow
#
# 196 proxies left to filter
# 187.62.222.201:8080 is good
# average conn time: 4.33518603934
#
# 195 proxies left to filter
# 165.22.252.189:8080 is slow
#
# 194 proxies left to filter
# 157.230.163.11:8080 is slow
#
# 193 proxies left to filter
# 187.188.162.136:8080 is slow
#
# 192 proxies left to filter
# 183.89.117.43:8080 is slow
#
# 191 proxies left to filter
# 179.185.89.225:80 is good
# average conn time: 4.33646287958
#
# 190 proxies left to filter
# 189.196.14.203:8080 is slow
#
# 189 proxies left to filter
# 194.114.139.88:6575 is slow
#
# 188 proxies left to filter
# 200.142.120.90:41508 is bad
#
# 187 proxies left to filter
# 182.253.82.156:32453 is slow
#
# 186 proxies left to filter
# 194.8.146.167:47496 is slow
#
# 185 proxies left to filter
# 183.195.145.174:53281 is slow
#
# 184 proxies left to filter
# 178.169.196.87:48834 is good
# average conn time: 4.33420873922
#
# 183 proxies left to filter
# 165.22.244.163:8080 is slow
#
# 182 proxies left to filter
# 158.69.104.196:1080 is slow
#
# 181 proxies left to filter
# 187.111.192.54:56325 is bad
#
# 180 proxies left to filter
# 200.41.150.83:54958 is bad
#
# 179 proxies left to filter
# 157.230.35.71:8080 is good
# average conn time: 4.32883308101
#
# 178 proxies left to filter
# 200.53.220.253:37396 is slow
#
# 177 proxies left to filter
# 190.63.160.98:46784 is slow
#
# 176 proxies left to filter
# 194.28.5.25:8080 is good
# average conn time: 4.33150398412
#
# 175 proxies left to filter
# 185.190.105.179:80 is slow
#
# 174 proxies left to filter
# 198.134.28.37:38966 is bad
#
# 173 proxies left to filter
# 159.138.1.185:80 is slow
#
# 172 proxies left to filter
# 190.2.8.193:8080 is bad
#
# 171 proxies left to filter
# 178.77.206.146:41759 is slow
#
# 170 proxies left to filter
# 197.81.195.28:3128 is good
# average conn time: 4.34060138734
#
# 169 proxies left to filter
# 159.203.169.239:8080 is slow
#
# 168 proxies left to filter
# 186.148.188.66:9991 is slow
#
# 167 proxies left to filter
# 158.255.23.146:54540 is slow
#
# 166 proxies left to filter
# 191.36.244.230:51377 is slow
#
# 165 proxies left to filter
# 149.28.20.37:808 is good
# average conn time: 4.33890813822
#
# 164 proxies left to filter
# 176.30.210.170:8080 is slow
#
# 163 proxies left to filter
# 168.227.229.102:56655 is slow
#
# 162 proxies left to filter
# 197.248.60.21:60509 is slow
#
# 161 proxies left to filter
# 195.224.107.162:8080 is good
# average conn time: 4.33337255189
#
# 160 proxies left to filter
# 201.184.93.218:30310 is slow
#
# 159 proxies left to filter
# 182.253.31.153:8080 is slow
#
# 158 proxies left to filter
# 193.213.89.72:51024 is slow
#
# 157 proxies left to filter
# 182.253.204.66:58217 is slow
#
# 156 proxies left to filter
# 186.192.20.159:8080 is slow
#
# 155 proxies left to filter
# 185.72.253.10:8080 is good
# average conn time: 4.33513626048
#
# 154 proxies left to filter
# 190.90.63.98:57995 is bad
#
# 153 proxies left to filter
# 191.252.186.238:3128 is slow
#
# 152 proxies left to filter
# 187.95.236.240:20183 is good
# average conn time: 4.33152101672
#
# 151 proxies left to filter
# 193.112.107.94:1080 is slow
#
# 150 proxies left to filter
# 170.84.93.106:35012 is slow
#
# 149 proxies left to filter
# 177.36.60.241:20183 is slow
#
# 148 proxies left to filter
# 190.60.222.59:9991 is bad
#
# 147 proxies left to filter
# 186.4.137.53:53281 is bad
#
# 146 proxies left to filter
# 198.50.172.167:1080 is slow
#
# 145 proxies left to filter
# 177.66.61.128:8080 is slow
#
# 144 proxies left to filter
# 177.184.63.232:8080 is slow
#
# 143 proxies left to filter
# 167.99.165.114:3128 is slow
#
# 142 proxies left to filter
# 179.109.1.93:8080 is good
# average conn time: 4.35273212279
#
# 141 proxies left to filter
# 167.205.28.225:8080 is slow
#
# 140 proxies left to filter
# 191.252.195.136:8080 is slow
#
# 139 proxies left to filter
# 188.255.4.92:8081 is slow
#
# 138 proxies left to filter
# 201.62.125.229:8080 is slow
#
# 137 proxies left to filter
# 154.72.95.242:63141 is slow
#
# 136 proxies left to filter
# 160.119.130.102:8080 is slow
#
# 135 proxies left to filter
# 157.230.253.105:8080 is good
# average conn time: 4.34693338086
#
# 134 proxies left to filter
# 157.230.149.54:8080 is slow
#
# 133 proxies left to filter
# 175.184.250.94:80 is good
# average conn time: 4.35731040247
#
# 132 proxies left to filter
# 193.112.214.81:1080 is slow
# 131 proxies left to filter
# 189.126.78.65:23500 is slow
#
# 130 proxies left to filter
# 177.200.72.214:20183 is good
# average conn time: 4.35815572739
#
# 129 proxies left to filter
# 200.202.198.98:8080 is slow
#
# 128 proxies left to filter
# 177.87.240.49:42521 is good
# average conn time: 4.35941233009
#
# 127 proxies left to filter
# 186.227.252.8:8080 is slow
#
# 126 proxies left to filter
# 185.132.133.213:8080 is bad
#
# 125 proxies left to filter
# 190.14.203.109:3128 is bad
#
# 124 proxies left to filter
# 190.0.18.179:9991 is slow
#
# 123 proxies left to filter
# 197.216.2.9:8080 is good
# average conn time: 4.3553464182
#
# 122 proxies left to filter
# 185.194.27.238:8080 is slow
#
# 121 proxies left to filter
# 188.131.132.179:1080 is slow
#
# 120 proxies left to filter
# 177.87.42.165:40511 is slow
#
# 119 proxies left to filter
# 159.89.35.245:3128 is slow
#
# 118 proxies left to filter
# 185.76.215.54:80 is slow
#
# 117 proxies left to filter
# 177.234.161.42:8080 is good
# average conn time: 4.36099987395
#
# 116 proxies left to filter
# 195.88.16.155:37217 is slow
#
# 115 proxies left to filter
# 193.112.53.68:1080 is slow
#
# 114 proxies left to filter
# 182.16.177.249:8080 is slow
#
# 113 proxies left to filter
# 195.70.107.138:3128 is slow
#
# 112 proxies left to filter
# 177.103.186.7:40770 is good
# average conn time: 4.36103274162
#
# 111 proxies left to filter
# 164.132.98.72:8080 is slow
#
# 110 proxies left to filter
# 185.162.128.135:9024 is slow
#
# 109 proxies left to filter
# 165.227.168.49:3128 is good
# average conn time: 4.35388854988
#
# 108 proxies left to filter
# 201.148.224.114:8080 is good
# average conn time: 4.37532247877
#
# 107 proxies left to filter
# 170.238.41.16:31208 is bad
#
# 106 proxies left to filter
# 180.183.139.141:8080 is slow
#
# 105 proxies left to filter
# 181.143.17.37:8080 is good
# average conn time: 4.38275044978
#
# 104 proxies left to filter
# 168.232.49.223:80 is slow
#
# 103 proxies left to filter
# 178.69.191.120:34953 is slow
#
# 102 proxies left to filter
# 201.219.213.228:8080 is slow
#
# 101 proxies left to filter
# 157.230.240.140:3128 is bad
#
# 100 proxies left to filter
# 157.230.241.29:8080 is slow
#
# 99 proxies left to filter
# 170.81.141.249:51713 is slow
#
# 98 proxies left to filter
# 155.93.123.26:8080 is slow
#
# 97 proxies left to filter
# 181.129.148.142:33043 is slow
#
# 96 proxies left to filter
# 196.250.176.140:8080 is slow
#
# 95 proxies left to filter
# 184.82.75.234:8080 is slow
#
# 94 proxies left to filter
# 180.250.113.53:8080 is good
# average conn time: 4.38564036519
#
# 93 proxies left to filter
# 201.184.233.179:8080 is slow
#
# 92 proxies left to filter
# 202.138.249.12:8080 is slow
#
# 91 proxies left to filter
# 175.101.80.225:8080 is slow
#
# 90 proxies left to filter
# 159.203.20.110:80 is slow
#
# 89 proxies left to filter
# 183.89.38.134:8080 is slow
#
# 88 proxies left to filter
# 181.196.242.126:53281 is good
# average conn time: 4.38518226313
#
# 87 proxies left to filter
# 179.106.88.162:80 is slow
#
# 86 proxies left to filter
# 177.244.28.77:53281 is good
# average conn time: 4.38077164169
#
# 85 proxies left to filter
# 170.79.95.171:8080 is slow
#
# 84 proxies left to filter
# 181.188.166.74:8080 is slow
#
# 83 proxies left to filter
# 187.204.248.232:53281 is slow
#
# 82 proxies left to filter
# 175.18.28.123:8080 is slow
#
# 81 proxies left to filter
# 197.210.246.30:8080 is slow
#
# 80 proxies left to filter
# 176.102.48.105:61687 is slow
#
# 79 proxies left to filter
# 154.118.243.18:53685 is slow
#
# 78 proxies left to filter
# 187.108.36.250:20183 is slow
#
# 77 proxies left to filter
# 177.154.16.75:8080 is slow
#
# 76 proxies left to filter
# 165.22.72.253:8080 is good
# average conn time: 4.3736344243
#
# 75 proxies left to filter
# 176.227.188.66:53281 is slow
#
# 74 proxies left to filter
# 175.111.114.10:8080 is slow
#
# 73 proxies left to filter
# 190.108.252.187:8080 is slow
#
# 72 proxies left to filter
# 182.93.95.146:8080 is slow
#
# 71 proxies left to filter
# 181.129.41.163:8080 is slow
#
# 70 proxies left to filter
# 200.89.183.164:8080 is slow
#
# 69 proxies left to filter
# 198.199.122.218:80 is slow
#
# 68 proxies left to filter
# 154.72.202.62:53281 is slow
#
# 67 proxies left to filter
# 154.127.32.89:60020 is slow
#
# 66 proxies left to filter
# 188.131.248.52:1080 is slow
#
# 65 proxies left to filter
# 194.114.139.17:6575 is slow
#
# 64 proxies left to filter
# 193.112.49.21:1080 is slow
#
# 63 proxies left to filter
# 186.225.45.146:37179 is good
# average conn time: 4.37534168257
#
# 62 proxies left to filter
# 154.126.37.134:8080 is slow
#
# 61 proxies left to filter
# 197.149.92.138:8080 is slow
#
# 60 proxies left to filter
# 167.99.1.61:8080 is slow
#
# 59 proxies left to filter
# 159.138.62.138:1080 is slow
#
# 58 proxies left to filter
# 185.138.69.110:55520 is good
# average conn time: 4.3766763041
#
# 57 proxies left to filter
# 185.132.133.186:8080 is slow
#
# 56 proxies left to filter
# 188.255.252.143:43072 is bad
#
# 55 proxies left to filter
# 157.230.57.151:3128 is slow
#
# 54 proxies left to filter
# 178.128.186.2:3128 is slow
#
# 53 proxies left to filter
# 176.36.217.6:57863 is bad
#
# 52 proxies left to filter
# 182.53.201.55:80 is slow
#
# 51 proxies left to filter
# 190.184.144.50:35353 is good
# average conn time: 4.37299842956
#
# 50 proxies left to filter
# 165.227.37.166:3128 is slow
#
# 49 proxies left to filter
# 175.139.190.165:52890 is good
# average conn time: 4.37647180239
#
# 48 proxies left to filter
# 185.101.236.76:63141 is slow
#
# 47 proxies left to filter
# 194.186.135.74:3130 is good
# average conn time: 4.37405381857
#
# 46 proxies left to filter
# 163.172.100.3:8123 is slow
#
# 45 proxies left to filter
# 185.18.64.106:53281 is bad
#
# 44 proxies left to filter
# 200.208.159.56:3128 is slow
#
# 43 proxies left to filter
# 194.114.139.2:6575 is slow
#
# 42 proxies left to filter
# 157.230.43.58:8080 is slow
#
# 41 proxies left to filter
# 193.112.136.220:1080 is slow
#
# 40 proxies left to filter
# 198.199.123.59:3128 is slow
#
# 39 proxies left to filter
# 181.111.235.203:8080 is good
# average conn time: 4.37868374248
#
# 38 proxies left to filter
# 183.89.164.30:8080 is slow
#
# 37 proxies left to filter
# 163.53.209.7:35278 is slow
#
# 36 proxies left to filter
# 181.191.106.126:43716 is slow
#
# 35 proxies left to filter
# 178.211.225.19:80 is slow
#
# 34 proxies left to filter
# 194.114.139.183:6575 is slow
#
# 33 proxies left to filter
# 20.41.41.145:3128 is slow
#
# 32 proxies left to filter
# 188.213.25.145:3128 is slow
#
# 31 proxies left to filter
# 185.46.199.147:8080 is slow
#
# 30 proxies left to filter
# 177.12.133.254:44663 is slow
#
# 29 proxies left to filter
# 201.148.23.117:43501 is slow
#
# 28 proxies left to filter
# 178.211.225.25:80 is slow
#
# 27 proxies left to filter
# 181.113.135.254:52058 is slow
#
# 26 proxies left to filter
# 186.227.69.184:38164 is slow
#
# 25 proxies left to filter
# 187.60.166.90:35773 is slow
#
# 24 proxies left to filter
# 186.159.1.217:56875 is slow
#
# 23 proxies left to filter
# 182.48.101.100:80 is slow
#
# 22 proxies left to filter
# 188.131.228.233:1080 is slow
#
# 21 proxies left to filter
# 167.99.231.73:8080 is good
# average conn time: 4.3706374676
#
# 20 proxies left to filter
# 177.139.174.239:80 is bad
#
# 19 proxies left to filter
# 182.253.75.66:8080 is slow
#
# 18 proxies left to filter
# 188.186.186.146:45121 is slow
#
# 17 proxies left to filter
# 177.99.162.210:34020 is slow
#
# 16 proxies left to filter
# 178.75.27.131:41879 is good
# average conn time: 4.3739682364
#
# 15 proxies left to filter
# 172.92.73.61:53281 is slow
#
# 14 proxies left to filter
# 185.20.115.114:57236 is bad
#
# 13 proxies left to filter
# 190.92.40.194:8080 is good
# average conn time: 4.37623697496
#
# 12 proxies left to filter
# 200.229.238.42:20183 is good
# average conn time: 4.37783014612
#
# 11 proxies left to filter
# 191.240.156.154:36127 is bad
#
# 10 proxies left to filter
# 175.110.97.86:8080 is good
# average conn time: 4.37528455304
#
# 9 proxies left to filter
# 197.211.238.220:49740 is slow
#
# 8 proxies left to filter
# 178.255.175.222:8080 is bad
#
# 7 proxies left to filter
# 194.114.139.108:6575 is slow
#
# 6 proxies left to filter
# 189.1.97.44:3128 is good
# average conn time: 4.36995666401
#
# 5 proxies left to filter
# 201.204.46.10:39371 is good
# average conn time: 4.37059828259
#
# 4 proxies left to filter
# 170.80.49.21:52464 is slow
#
# 3 proxies left to filter
# 190.110.114.32:8080 is slow
#
# 2 proxies left to filter
# 134.119.214.199:1080 is slow
#
# 1 proxies left to filter
# 181.115.168.35:39253 is slow
#
# average proxy time:4.37059828259

# %% [markdown]
# # Filter the Http proxies

# %%
url = 'https://www.proxy-list.download/HTTP'
filterProxys(url)

# %% [markdown]
# # Overwrite the source text file with partially filtered or empty ip list

# %%
# overwrite the existing source of https proxy data with the filtered data
with open('proxyLists/https_proxys_US_part_1.txt', "w") as output:
    for line in testProxies['https']:
        output.write("%s\n" % line)

# %%
# overwrite the existing source of http proxy data with the filtered data
with open('proxyLists/http_proxys_US_part_1.txt', "w") as output:
    for line in testProxies['http']:
        output.write("%s\n" % line)

# %% [markdown]
# # Get all proxies that had connections times less than one second

# %%
df = pd.DataFrame(goodProxy['https'])
fast_proxies_https = list(df['proxy'][df['time']<1])

# %%
df = pd.DataFrame(goodProxy['http'])
fast_proxies_http = list(df['proxy'][df['time']<1])

# %% [markdown]
# # Import the single filtered files of proxys that had connections times less than one second and combine with the new filtered proxys

# %%
# Import
try:
    existing_https_proxies = list(pd.read_csv('../filtered_https_proxys_US.txt', header = None)[0])
except: #If the file is empty
    existing_https_proxies = []
try:
    existing_http_proxies = list(pd.read_csv('../filtered_http_proxys_US.txt', header = None)[0])
except: #If the file is empty
    existing_http_proxies = []

# %%
# add the new proxys to the existing ones if they are not already there
[existing_https_proxies.append(x) 
 for x in fast_proxies_https 
 if x not in existing_https_proxies]

[existing_http_proxies.append(x) 
 for x in fast_proxies_http 
 if x not in existing_http_proxies]

# %% [markdown]
# # Rewrite the final proxys text file with the new and old filtered proxies

# %%
#append filtered http proxys to existing .txt file
with open('../filtered_http_proxys_US.txt', "w") as output:
    for line in existing_http_proxies:
        output.write("%s\n" % line)

# %%
# append filtered https proxies to existing text file
with open('../filtered_https_proxys_US.txt', "w") as output:
    for line in existing_https_proxies:
        output.write("%s\n" % line)
